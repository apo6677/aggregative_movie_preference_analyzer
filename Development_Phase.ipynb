# %%
import math
import random

###################################################################################################################################################################################
###-----------------------------------------------------------------------------------RATING ---------------------------------------------------------------------------------
###################################################################################################################################################################################

def find_movies_between_T1_T2(T1, T2):
    filtered_ratings = dict()
    average_ratings = dict()
    movies = dict()

    with open("movies.dat","r", encoding="utf-8") as Mov:
        for line in Mov:
            data = line.strip().split('::')

            MovieID = data[0]
            Title = data[1]
            
            movies[MovieID] = Title

    with open("ratings.dat","r") as ratings:
        for line in ratings:
            data = line.strip().split('::')

            MovieID = data[1]
            Rating = float(data[2])
            
            if MovieID in average_ratings:
                average_ratings[MovieID]['Total_Rating'] +=Rating
                average_ratings[MovieID]['Count'] += 1
            else:
                average_ratings[MovieID] = {'Total_Rating': Rating, 'Count': 1}

    for MovieID in movies:
        if MovieID in average_ratings.keys():
            Title = movies[MovieID]
            average_rating = average_ratings[MovieID]['Total_Rating']/average_ratings[MovieID]['Count']
            if T1 <= average_rating <= T2:
                filtered_ratings[Title] = average_rating

    for Title in filtered_ratings:
        print("Movie Title:", Title, "Average Rating:", filtered_ratings[Title], "\n")

###################################################################################################################################################################################
###-----------------------------------------------------------------------------------TOP MOVIES ---------------------------------------------------------------------------------
###################################################################################################################################################################################

def find_top_movies(K):

    filtered_ratings = dict()
    average_ratings = dict()
    movies = dict()

    with open("movies.dat","r", encoding="utf-8") as Mov:
        for line in Mov:
            data = line.strip().split('::')

            MovieID = data[0]
            Title = data[1]
            
            movies[MovieID] = Title

    with open("ratings.dat","r") as ratings:
        for line in ratings:
            data = line.strip().split('::')

            MovieID = data[1]
            Rating = float(data[2])
            
            if MovieID in average_ratings:
                average_ratings[MovieID]['Total_Rating'] +=Rating
                average_ratings[MovieID]['Count'] += 1
            else:
                average_ratings[MovieID] = {'Total_Rating': Rating, 'Count': 1}
        
    for MovieID in movies:
        if MovieID in average_ratings.keys():
            Title = movies[MovieID]
            average_rating = average_ratings[MovieID]['Total_Rating']/average_ratings[MovieID]['Count']
            filtered_ratings[Title] = average_rating

    sorted_ratings = sorted(filtered_ratings.items(), key=lambda x: x[1], reverse=True)

    top_K_movies = sorted_ratings[:K]
    
    for Title, Average_Rating in top_K_movies:
        print("Movie Title:", Title, "Average Rating:", Average_Rating, "\n")

###################################################################################################################################################################################
###-----------------------------------------------------------------------------------USER PAIRS ---------------------------------------------------------------------------------
###################################################################################################################################################################################

def find_user_pairs(K):
    user_pairs = dict()
    filtered_pairs = dict()
    movies = dict()
    MovieIds = []

    with open("movies.dat","r", encoding="utf-8") as Mov:
        for line in Mov:
            data = line.strip().split('::')

            MovieID = data[0]
            Title = data[1]
            
            movies[MovieID] = Title
            MovieIds.append(MovieID)


    with open("ratings.dat","r") as ratings:
        for line in ratings:
            data = line.strip().split('::')

            MovieID = data[1]
            UserID = data[0]
            
            if MovieID in user_pairs:
                if len(user_pairs[MovieID]) == 2:
                    continue;
                else:
                    user_pairs[MovieID].append(int(UserID))    
            else:
                user_pairs[MovieID] = [int(UserID)]

    chosen_movies = random.sample(MovieIds, min(K, len(MovieIds)))
  
    for MovieID in chosen_movies:
        if MovieID in user_pairs.keys():
            Title = movies[MovieID]
            filtered_pairs[Title] = user_pairs[MovieID]

    for Title in filtered_pairs:
        print("Movie Title:", Title, "Users:", filtered_pairs[Title], "\n")

###################################################################################################################################################################################
###-----------------------------------------------------------------------------------ICEBERG ---------------------------------------------------------------------------------
###################################################################################################################################################################################

def iceberg(K,T):

    iceberg_movies = dict()
    filtered_movies = dict()
    movies = dict()

    with open("movies.dat","r", encoding="utf-8") as Mov:
        for line in Mov:
            data = line.strip().split('::')

            MovieID = data[0]
            Title = data[1]
            
            movies[MovieID] = Title


    with open("ratings.dat","r") as ratings:
        for line in ratings:
            data = line.strip().split('::')

            MovieID = data[1]
            Rating = float(data[2])
            
            if MovieID in iceberg_movies:
                iceberg_movies[MovieID]['Total_Rating'] +=Rating
                iceberg_movies[MovieID]['Count'] += 1   
            else:
                iceberg_movies[MovieID] = {'Movie': MovieID, 'Total_Rating': Rating, 'Count': 1}

  
    for MovieID in movies:
        if MovieID in iceberg_movies.keys():
            average_rating = iceberg_movies[MovieID]['Total_Rating']/iceberg_movies[MovieID]['Count']
            iceberg_movies[MovieID]['Total_Rating'] = average_rating
            if iceberg_movies[MovieID]['Count'] < K or average_rating < T:
                del iceberg_movies[MovieID]
            else:
                Title = movies[MovieID]
                filtered_movies[Title] = iceberg_movies[MovieID]

    for Title in filtered_movies:
        print("Movie Title:", Title, "Number of critics:", filtered_movies[Title]['Count'], "Average Rating:", filtered_movies[Title]['Total_Rating'], "\n")

###################################################################################################################################################################################
###-----------------------------------------------------------------------------------TOP USER---------------------------------------------------------------------------------
###################################################################################################################################################################################

def top_users(K):
    users = dict()
   
    with open("ratings.dat","r") as ratings:
        for line in ratings:
            data = line.strip().split('::')

            UserID = data[0]
            
            if UserID in users:
                users[UserID]+=1    
            else:
                users[UserID] = 1

    sorted_users = sorted(users.items(), key=lambda x: x[1], reverse=True)


    top_K_users = sorted_users[:K]

    for UserID, Movies in top_K_users:
        print("User:", UserID, "Movies:", Movies, "\n")
###################################################################################################################################################################################
###-----------------------------------------------------------------------------------MOVIE SAMPLE---------------------------------------------------------------------------------
###################################################################################################################################################################################


def movie_sample(S):
   movies = dict()
   categorised_movies = dict()

   with open("movies.dat","r", encoding="utf-8") as Mov:
    for line in Mov:
        data = line.strip().split('::')

        Categories = data[2].split('|')
        Title = data[1]
            
        movies[Title] = Categories

    for Title in movies:
        for Category in movies[Title]:
            if  Category in categorised_movies.keys():
                categorised_movies[Category].append(Title)
            else: categorised_movies[Category] = [Title]

    for Category in categorised_movies:
        size = math.ceil(int((S/100)*len(categorised_movies[Category])))
        categorised_movies[Category] = categorised_movies[Category][:size]
        print("Category:", Category, "Movies:", categorised_movies[Category], "\n")

###################################################################################################################################################################################
###-----------------------------------------------------------------------------------COSINE SIMILARITY---------------------------------------------------------------------------------
###################################################################################################################################################################################
def cosine_similarity(Thetta):
    users_with_same_movies = dict()
    users = dict()
    user_movies = dict()
    cosine_users = dict()

    with open("ratings.dat","r") as ratings:
        for line in ratings:
            data = line.strip().split('::')

            UserID = data[0]
            MovieID = data[1]
            Rating = float(data[2])
            
            if UserID not in users:
                users[UserID] = []
            rating_entry = {MovieID: Rating}
            users[UserID].append(rating_entry)

            if UserID not in user_movies:
                user_movies[UserID] = []
            user_movies[UserID].append(MovieID)

    common_user_ids = list(set(users.keys()))
    selected_user_ids = random.sample(common_user_ids, 100)

    trimmed_users = {user_id: users[user_id] for user_id in selected_user_ids}
    trimmed_user_movies = {user_id: user_movies[user_id] for user_id in selected_user_ids}

    for UserID1 in trimmed_user_movies:
        for UserID2 in trimmed_user_movies:
            if UserID1 != UserID2: 
                common_movies = [movie for movie in trimmed_user_movies[UserID1] if movie in trimmed_user_movies[UserID2]]

                if len(common_movies) != 0:
                    if (UserID1, UserID2) not in users_with_same_movies:
                        if (UserID2, UserID1) not in users_with_same_movies:
                            users_with_same_movies[(UserID1, UserID2)] = []

                            for MovieID in common_movies:
                                users_with_same_movies[(UserID1, UserID2)].append(MovieID)
    

    for (UserID1, UserID2) in users_with_same_movies:
        cos_similar = 0
        sum_cos_sim_nominator = 0
        sum_cos_sim_denominator_user1 = 0
        sum_cos_sim_denominator_user2 = 0

        for MovieID in users_with_same_movies[(UserID1, UserID2)]:

            ratings_user1 = {list(movie.keys())[0]: list(movie.values())[0] for movie in trimmed_users[UserID1]}
            print(ratings_user1)

            rating1 = 0
            for rating_entry in trimmed_users[UserID1]:
                rating1 = ratings_user1.get(MovieID, 0)

            ratings_user2 = {list(movie.keys())[0]: list(movie.values())[0] for movie in trimmed_users[UserID2]}

            rating2 = 0
            for rating_entry in trimmed_users[UserID2]:
                rating2 = ratings_user2.get(MovieID, 0)

            sum_cos_sim_nominator += rating1*rating2
            sum_cos_sim_denominator_user1 += rating1**2
            sum_cos_sim_denominator_user2 += rating2**2

        cos_similar = sum_cos_sim_nominator/(math.sqrt(sum_cos_sim_denominator_user1)*math.sqrt(sum_cos_sim_denominator_user2)) if (math.sqrt(sum_cos_sim_denominator_user1)*math.sqrt(sum_cos_sim_denominator_user2))!=0 else 0

        cosine_users[(UserID1, UserID2)] = cos_similar

    sorted_users = sorted(cosine_users.items(), key=lambda x: x[1], reverse=True)

    final_cosine_users = dict()
    for ((UserID1, UserID2), similarity) in sorted_users:
        if similarity >= Thetta:
            final_cosine_users[(UserID1, UserID2)] = similarity

    for (UserID1, UserID2) in final_cosine_users:
        print("Users:", UserID1, UserID2, "Cosine Similarity:", final_cosine_users[(UserID1, UserID2)], "\n")
###################################################################################################################################################################################
###-----------------------------------------------------------------------------------DOMINANCE---------------------------------------------------------------------------------
###################################################################################################################################################################################
def dominance():
    movies_that_are_not_dominated = dict()
    average_ratings = dict()
    movies = dict()

    with open("movies.dat","r", encoding="utf-8") as Mov:
        for line in Mov:
            data = line.strip().split('::')

            MovieID = data[0]
            Title = data[1]
            
            movies[MovieID] = Title

    with open("ratings.dat","r") as ratings:
        for line in ratings:
            data = line.strip().split('::')

            MovieID = data[1]
            Rating = float(data[2])
            
            if MovieID in average_ratings:
                average_ratings[MovieID]['Total_Rating'] +=Rating
                average_ratings[MovieID]['Count'] += 1
            else:
                average_ratings[MovieID] = {'Total_Rating': Rating, 'Count': 1}

    for MovieID in movies:
        if MovieID in average_ratings.keys():
            Title = movies[MovieID]
            average_rating = average_ratings[MovieID]['Total_Rating']/average_ratings[MovieID]['Count']
            count = average_ratings[MovieID]['Count']
            movies_that_are_not_dominated[Title] = [count, average_rating]
            for MovieID2 in movies:
                if MovieID2!=MovieID:
                    if MovieID2 in average_ratings.keys():
                        average_rating2 = average_ratings[MovieID2]['Total_Rating']/average_ratings[MovieID2]['Count']
                        count2 = average_ratings[MovieID2]['Count']
                        if average_rating2 >= average_rating and count2>=count:
                            del movies_that_are_not_dominated[Title]
                            break;

    for Title in movies_that_are_not_dominated:
        count, average_rating = movies_that_are_not_dominated[Title]
        print("Movie Title:", Title, "Average Rating:", average_rating, "Total Votes:", count, "\n")    

###################################################################################################################################################################################
###-----------------------------------------------------------------------------------MAIN---------------------------------------------------------------------------------
###################################################################################################################################################################################
def main():
    while(True):
        print("\nChoose\n\n 1) rating T1 T2: find all movies with rating between T1 and T2\n\n 2) top_movies K: find all movies with rating over K \n\n 3) user_pairs K: find all user pairs that have given rating to the same movie\n\n\
 4) dominance: find users that aren't dominated from other movies\n\n 5) iceberg K T: find movies that have been rated at least K times with average score over T\n\n 6) top_user K: find the K users that have rated the most movies\n\n\
 7) movie_sample S: find a percentage of movies from all categories\n\n 8) similar_users Θ: find users that have similar tastes in movies based on cosine similarity\n\n 9) S to stop\n\n")
        mode = [i for i in input(" ").split(' ')]
        if mode[0] == "S":
            break;

        if mode[0] == "rating":
            find_movies_between_T1_T2(float(mode[1]), float(mode[2]))
        elif mode[0] == "top_movies":
            find_top_movies(int(mode[1]))
        elif mode[0]== "user_pairs":
            find_user_pairs(int(mode[1]))
        elif mode[0]== "iceberg":
            iceberg(int(mode[1]), float(mode[2]))
        elif mode[0]== "top_user":
            top_users(int(mode[1]))
        elif mode[0]== "movie_sample":
            movie_sample(int(mode[1]))
        elif mode[0]== "similar_users":
            cosine_similarity(float(mode[1]))
        elif mode[0]== "dominance":
            dominance()
        else : print("not a choice, choose again")

if __name__ == "__main__":
    main()
# Out:
# Choose
#
#  1) rating T1 T2: find all movies with rating between T1 and T2
#
#  2) top_movies K: find all movies with rating over K
#
#  3) user_pairs K: find all user pairs that have given rating to the same movie
#
#  4) dominance: find users that aren't dominated from other movies
#
#  5) iceberg K T: find movies that have been rated at least K times with average score over T
#
#  6) top_user K: find the K users that have rated the most movies
#
#  7) movie_sample S: find a percentage of movies from all categories
#
#  8) similar_users Θ: find users that have similar tastes in movies based on cosine similarity
#
#  9) S to stop

# %% [markdown]
# LOGGING PHASE

# %%
# %%file log_config.conf
#
# [loggers]
# keys=root, myLogger
#
# [handlers]
# keys=myHandler
#
# [formatters]
# keys=myFormatter
#
# [logger_root]
# level=INFO
# handlers=myHandler
#
# [logger_myLogger]
# level=INFO
# handlers=myHandler
# qualname=myLogger
# propagate=0
#
# [handler_myHandler]
# class=FileHandler
# level=INFO
# formatter=myFormatter
# args=('dev_phase_logger.log','w')
#
# [formatter_myFormatter]
# format=%(asctime)s | %(levelname)-7s | %(name)s - %(message)s
# Out:
# Overwriting log_config.conf

# %%
import math
import random


import logging
import logging.config

logging.config.fileConfig('log_config.conf')

logger = logging.getLogger('myLogger')

###################################################################################################################################################################################
###-----------------------------------------------------------------------------------RATING ---------------------------------------------------------------------------------
###################################################################################################################################################################################

def find_movies_between_T1_T2(T1, T2):
    filtered_ratings = dict()
    average_ratings = dict()
    movies = dict()

    with open("movies.dat","r", encoding="utf-8") as Mov:
        for line in Mov:
            data = line.strip().split('::')

            MovieID = data[0]
            Title = data[1]
            
            movies[MovieID] = Title

    with open("ratings.dat","r") as ratings:
        for line in ratings:
            data = line.strip().split('::')

            MovieID = data[1]
            Rating = float(data[2])
            
            if MovieID in average_ratings:
                average_ratings[MovieID]['Total_Rating'] +=Rating
                average_ratings[MovieID]['Count'] += 1
            else:
                average_ratings[MovieID] = {'Total_Rating': Rating, 'Count': 1}

    for MovieID in movies:
        if MovieID in average_ratings.keys():
            Title = movies[MovieID]
            average_rating = average_ratings[MovieID]['Total_Rating']/average_ratings[MovieID]['Count']
            if T1 <= average_rating <= T2:
                filtered_ratings[Title] = average_rating

    for Title in filtered_ratings:
        print("Movie Title:", Title, "Average Rating:", filtered_ratings[Title], "\n")

###################################################################################################################################################################################
###-----------------------------------------------------------------------------------TOP MOVIES ---------------------------------------------------------------------------------
###################################################################################################################################################################################

def find_top_movies(K):

    filtered_ratings = dict()
    average_ratings = dict()
    movies = dict()

    with open("movies.dat","r", encoding="utf-8") as Mov:
        for line in Mov:
            data = line.strip().split('::')

            MovieID = data[0]
            Title = data[1]
            
            movies[MovieID] = Title

    with open("ratings.dat","r") as ratings:
        for line in ratings:
            data = line.strip().split('::')

            MovieID = data[1]
            Rating = float(data[2])
            
            if MovieID in average_ratings:
                average_ratings[MovieID]['Total_Rating'] +=Rating
                average_ratings[MovieID]['Count'] += 1
            else:
                average_ratings[MovieID] = {'Total_Rating': Rating, 'Count': 1}
        
    for MovieID in movies:
        if MovieID in average_ratings.keys():
            Title = movies[MovieID]
            average_rating = average_ratings[MovieID]['Total_Rating']/average_ratings[MovieID]['Count']
            filtered_ratings[Title] = average_rating

    sorted_ratings = sorted(filtered_ratings.items(), key=lambda x: x[1], reverse=True)

    top_K_movies = sorted_ratings[:K]
    
    for Title, Average_Rating in top_K_movies:
        print("Movie Title:", Title, "Average Rating:", Average_Rating, "\n")

###################################################################################################################################################################################
###-----------------------------------------------------------------------------------USER PAIRS ---------------------------------------------------------------------------------
###################################################################################################################################################################################

def find_user_pairs(K):
    user_pairs = dict()
    filtered_pairs = dict()
    movies = dict()

    with open("movies.dat","r", encoding="utf-8") as Mov:
        for line in Mov:
            data = line.strip().split('::')

            MovieID = data[0]
            Title = data[1]
            
            movies[MovieID] = Title


    with open("ratings.dat","r") as ratings:
        for line in ratings:
            data = line.strip().split('::')

            MovieID = data[1]
            UserID = data[0]
            
            if MovieID in user_pairs:
                if len(user_pairs[MovieID]['Users']) == 2*K:
                    continue;
                else:
                    user_pairs[MovieID]['Users'].append(int(UserID))    
            else:
                user_pairs[MovieID] = {'Movie': MovieID, 'Users': [int(UserID)]}

  
    for MovieID in movies:
        if MovieID in user_pairs.keys():
            Title = movies[MovieID]
            filtered_pairs[Title] = user_pairs[MovieID]

    for Title in filtered_pairs:
        print("Movie Title:", Title, "Users:", filtered_pairs[Title]['Users'], "\n")

###################################################################################################################################################################################
###-----------------------------------------------------------------------------------ICEBERG ---------------------------------------------------------------------------------
###################################################################################################################################################################################

def iceberg(K,T):

    iceberg_movies = dict()
    filtered_movies = dict()
    movies = dict()

    with open("movies.dat","r", encoding="utf-8") as Mov:
        for line in Mov:
            data = line.strip().split('::')

            MovieID = data[0]
            Title = data[1]
            
            movies[MovieID] = Title


    with open("ratings.dat","r") as ratings:
        for line in ratings:
            data = line.strip().split('::')

            MovieID = data[1]
            Rating = float(data[2])
            
            if MovieID in iceberg_movies:
                iceberg_movies[MovieID]['Total_Rating'] +=Rating
                iceberg_movies[MovieID]['Count'] += 1   
            else:
                iceberg_movies[MovieID] = {'Movie': MovieID, 'Total_Rating': Rating, 'Count': 1}

  
    for MovieID in movies:
        if MovieID in iceberg_movies.keys():
            average_rating = iceberg_movies[MovieID]['Total_Rating']/iceberg_movies[MovieID]['Count']
            iceberg_movies[MovieID]['Total_Rating'] = average_rating
            if iceberg_movies[MovieID]['Count'] < K or average_rating < T:
                del iceberg_movies[MovieID]
            else:
                Title = movies[MovieID]
                filtered_movies[Title] = iceberg_movies[MovieID]

    for Title in filtered_movies:
        print("Movie Title:", Title, "Number of critics:", filtered_movies[Title]['Count'], "Average Rating:", filtered_movies[Title]['Total_Rating'], "\n")

###################################################################################################################################################################################
###-----------------------------------------------------------------------------------TOP USER---------------------------------------------------------------------------------
###################################################################################################################################################################################

def top_users(K):
    users = dict()
   
    with open("ratings.dat","r") as ratings:
        for line in ratings:
            data = line.strip().split('::')

            UserID = data[0]
            
            if UserID in users:
                users[UserID]+=1    
            else:
                users[UserID] = 1

    sorted_users = sorted(users.items(), key=lambda x: x[1], reverse=True)


    top_K_users = sorted_users[:K]

    for UserID, Movies in top_K_users:
        print("User:", UserID, "Movies:", Movies, "\n")
###################################################################################################################################################################################
###-----------------------------------------------------------------------------------MOVIE SAMPLE---------------------------------------------------------------------------------
###################################################################################################################################################################################


def movie_sample(S):
   movies = dict()
   categorised_movies = dict()

   with open("movies.dat","r", encoding="utf-8") as Mov:
    for line in Mov:
        data = line.strip().split('::')

        Categories = data[2].split('|')
        Title = data[1]
            
        movies[Title] = Categories

    for Title in movies:
        for Category in movies[Title]:
            if  Category in categorised_movies.keys():
                categorised_movies[Category].append(Title)
            else: categorised_movies[Category] = [Title]

    for Category in categorised_movies:
        size = int(S/len(categorised_movies[Category]))
        categorised_movies[Category][:size]
        print("Category:", Category, "Movies:", categorised_movies[Category], "\n")

###################################################################################################################################################################################
###-----------------------------------------------------------------------------------COSINE SIMILARITY---------------------------------------------------------------------------------
###################################################################################################################################################################################
def cosine_similarity(Thetta):
    users_with_same_movies = dict()
    users = dict()
    user_movies = dict()
    cosine_users = dict()

    with open("ratings.dat","r") as ratings:
        for line in ratings:
            data = line.strip().split('::')

            UserID = data[0]
            MovieID = data[1]
            Rating = float(data[2])
            
            if UserID not in users:
                users[UserID] = []
            rating_entry = {MovieID: Rating}
            users[UserID].append(rating_entry)

            if UserID not in user_movies:
                user_movies[UserID] = []
            user_movies[UserID].append(MovieID)

    common_user_ids = list(set(users.keys()))
    selected_user_ids = random.sample(common_user_ids, 100)

    trimmed_users = {user_id: users[user_id] for user_id in selected_user_ids}
    trimmed_user_movies = {user_id: user_movies[user_id] for user_id in selected_user_ids}

    for UserID1 in trimmed_user_movies:
        for UserID2 in trimmed_user_movies:
            if UserID1 != UserID2: 
                common_movies = [movie for movie in trimmed_user_movies[UserID1] if movie in trimmed_user_movies[UserID2]]

                if len(common_movies) != 0:
                    if (UserID1, UserID2) not in users_with_same_movies:
                        if (UserID2, UserID1) not in users_with_same_movies:
                            users_with_same_movies[(UserID1, UserID2)] = []

                            for MovieID in common_movies:
                                users_with_same_movies[(UserID1, UserID2)].append(MovieID)
    

    for (UserID1, UserID2) in users_with_same_movies:
        cos_similar = 0
        sum_cos_sim_nominator = 0
        sum_cos_sim_denominator_user1 = 0
        sum_cos_sim_denominator_user2 = 0

        for MovieID in users_with_same_movies[(UserID1, UserID2)]:

            ratings_user1 = {list(movie.keys())[0]: list(movie.values())[0] for movie in trimmed_users[UserID1]}

            rating1 = 0
            for rating_entry in trimmed_users[UserID1]:
                rating1 = ratings_user1.get(MovieID, 0)

            ratings_user2 = {list(movie.keys())[0]: list(movie.values())[0] for movie in trimmed_users[UserID2]}

            rating2 = 0
            for rating_entry in trimmed_users[UserID2]:
                rating2 = ratings_user2.get(MovieID, 0)

            sum_cos_sim_nominator += rating1*rating2
            sum_cos_sim_denominator_user1 += rating1**2
            sum_cos_sim_denominator_user2 += rating2**2

        cos_similar = sum_cos_sim_nominator/(math.sqrt(sum_cos_sim_denominator_user1)*math.sqrt(sum_cos_sim_denominator_user2)) if (math.sqrt(sum_cos_sim_denominator_user1)*math.sqrt(sum_cos_sim_denominator_user2))!=0 else 0

        cosine_users[(UserID1, UserID2)] = cos_similar

    sorted_users = sorted(cosine_users.items(), key=lambda x: x[1], reverse=True)

    final_cosine_users = dict()
    for ((UserID1, UserID2), similarity) in sorted_users:
        if similarity >= Thetta:
            final_cosine_users[(UserID1, UserID2)] = similarity

    for (UserID1, UserID2) in final_cosine_users:
        print("Users:", UserID1, UserID2, "Cosine Similarity:", final_cosine_users[(UserID1, UserID2)], "\n")
###################################################################################################################################################################################
###-----------------------------------------------------------------------------------DOMINANCE---------------------------------------------------------------------------------
###################################################################################################################################################################################
def dominance():
    movies_that_are_not_dominated = dict()
    average_ratings = dict()
    movies = dict()

    with open("movies.dat","r", encoding="utf-8") as Mov:
        for line in Mov:
            data = line.strip().split('::')

            MovieID = data[0]
            Title = data[1]
            
            movies[MovieID] = Title

    with open("ratings.dat","r") as ratings:
        for line in ratings:
            data = line.strip().split('::')

            MovieID = data[1]
            Rating = float(data[2])
            
            if MovieID in average_ratings:
                average_ratings[MovieID]['Total_Rating'] +=Rating
                average_ratings[MovieID]['Count'] += 1
            else:
                average_ratings[MovieID] = {'Total_Rating': Rating, 'Count': 1}

    for MovieID in movies:
        if MovieID in average_ratings.keys():
            Title = movies[MovieID]
            average_rating = average_ratings[MovieID]['Total_Rating']/average_ratings[MovieID]['Count']
            count = average_ratings[MovieID]['Count']
            movies_that_are_not_dominated[Title] = [count, average_rating]
            for MovieID2 in movies:
                if MovieID2!=MovieID:
                    if MovieID2 in average_ratings.keys():
                        average_rating2 = average_ratings[MovieID2]['Total_Rating']/average_ratings[MovieID2]['Count']
                        count2 = average_ratings[MovieID2]['Count']
                        if average_rating2 >= average_rating and count2>=count:
                            del movies_that_are_not_dominated[Title]
                            break;

    for Title in movies_that_are_not_dominated:
        count, average_rating = movies_that_are_not_dominated[Title]
        print("Movie Title:", Title, "Average Rating:", average_rating, "Total Votes:", count, "\n")     

###################################################################################################################################################################################
###-----------------------------------------------------------------------------------MAIN---------------------------------------------------------------------------------
###################################################################################################################################################################################
def main():
    while(True):
        print("\nChoose\n\n 1) rating T1 T2: find all movies with rating between T1 and T2\n\n 2) top_movies K: find all movies with rating over K \n\n 3) user_pairs K: find all user pairs that have given rating to the same movie\n\n\
 4) dominance: find users that aren't dominated from other movies\n\n 5) iceberg K T: find movies that have been rated at least K times with average score over T\n\n 6) top_user K: find the K users that have rated the most movies\n\n\
 7) movie_sample S: find a percentage of movies from all categories\n\n 8) similar_users Θ: find users that have similar tastes in movies based on cosine similarity\n\n 9) S to stop\n\n")
        mode = [i for i in input(" ").split(' ')]
        if mode[0] == "S":
            logger.info('User chose to stop the application')
            break;

        if mode[0] == "rating":
            logger.info('User entered: rating with T1=%s, T2=%s', float(mode[1]), float(mode[2]))
            find_movies_between_T1_T2(float(mode[1]), float(mode[2]))
        
        elif mode[0] == "top_movies":
            logger.info('User entered: top_movies with K=%s', int(mode[1]))
            find_top_movies(int(mode[1]))
        
        elif mode[0]== "user_pairs":
            logger.info('User entered: user_pairs with K=%s', int(mode[1]))
            find_user_pairs(int(mode[1]))
        
        elif mode[0]== "iceberg":
            logger.info('User entered: iceberg with K=%s, T=%s', int(mode[1]), float(mode[2]))
            iceberg(int(mode[1]), float(mode[2]))
        
        elif mode[0]== "top_user":
            logger.info('User entered: top_user with K=%s', int(mode[1]))
            top_users(int(mode[1]))
        
        elif mode[0]== "movie_sample":
            logger.info('User entered: movie_sample with S=%s', int(mode[1]))
            movie_sample(int(mode[1]))
        
        elif mode[0]== "similar_users":
            logger.info('User entered: similar_users with Thetta=%s', float(mode[1]))
            cosine_similarity(float(mode[1]))
        
        elif mode[0]== "dominance":
            logger.info('User entered: dominance')
            dominance()
        
        else : 
            logger.error('User did not enter a valid choice')
            print("not a choice, choose again")


if __name__ == "__main__":
    main()
# Out:
# Choose
#
#  1) rating T1 T2: find all movies with rating between T1 and T2
#
#  2) top_movies K: find all movies with rating over K
#
#  3) user_pairs K: find all user pairs that have given rating to the same movie
#
#  4) dominance: find users that aren't dominated from other movies
#
#  5) iceberg K T: find movies that have been rated at least K times with average score over T
#
#  6) top_user K: find the K users that have rated the most movies
#
#  7) movie_sample S: find a percentage of movies from all categories
#
#  8) similar_users Θ: find users that have similar tastes in movies based on cosine similarity
#
#  9) S to stop
#
#
# Movie Title: Jumanji (1995) Average Rating: 3.208070146276596
#
# Movie Title: Sabrina (1995) Average Rating: 3.365017361111111
#
# Movie Title: Four Rooms (1995) Average Rating: 3.328038674033149
#
# Movie Title: Copycat (1995) Average Rating: 3.331163612986178
#
# Movie Title: Powder (1995) Average Rating: 3.2332330180567497
#
# Movie Title: Now and Then (1995) Average Rating: 3.3802889576883386
#
# Movie Title: Dangerous Minds (1995) Average Rating: 3.273417471899034
#
# Movie Title: To Die For (1995) Average Rating: 3.373673036093418
#
# Movie Title: How to Make an American Quilt (1995) Average Rating: 3.2653508771929824
#
# Movie Title: Georgia (1995) Average Rating: 3.221690590111643
#
# Movie Title: Home for the Holidays (1995) Average Rating: 3.3258499037844773
#
# Movie Title: Eye for an Eye (1996) Average Rating: 3.3204607046070462
#
# Movie Title: Two Bits (1995) Average Rating: 3.3940677966101696
#
# Movie Title: From Dusk Till Dawn (1996) Average Rating: 3.25031605562579
#
# Movie Title: Bed of Roses (1996) Average Rating: 3.3109032846715327
#
# Movie Title: Nico Icon (1995) Average Rating: 3.388111888111888
#
# Movie Title: Things to Do in Denver When You're Dead (1995) Average Rating: 3.283578431372549
#
# Movie Title: Last Summer in the Hamptons (1995) Average Rating: 3.389473684210526
#
# Movie Title: Journey of August King, The (1995) Average Rating: 3.242857142857143
#
# Movie Title: City Hall (1996) Average Rating: 3.2231060606060606
#
# Movie Title: Unforgettable (1996) Average Rating: 3.2880886426592797
#
# Movie Title: Bridges of Madison County, The (1995) Average Rating: 3.323026779422128
#
# Movie Title: Muppet Treasure Island (1996) Average Rating: 3.201384796700059
#
# Movie Title: Silence of the Palace, The (Saimt el Qusur) (1994) Average Rating: 3.3392857142857144
#
# Movie Title: Pie in the Sky (1996) Average Rating: 3.231707317073171
#
# Movie Title: Frankie Starlight (1995) Average Rating: 3.334507042253521
#
# Movie Title: From the Journals of Jean Seberg (1995) Average Rating: 3.3970588235294117
#
# Movie Title: Man of the Year (1995) Average Rating: 3.3197278911564627
#
# Movie Title: Neon Bible, The (1995) Average Rating: 3.2204301075268815
#
# Movie Title: Target (1995) Average Rating: 3.274193548387097
#
# Movie Title: Up Close and Personal (1996) Average Rating: 3.296533416614616
#
# Movie Title: Bad Boys (1995) Average Rating: 3.260667479427004
#
# Movie Title: Mute Witness (1994) Average Rating: 3.349502487562189
#
# Movie Title: Prophecy, The (1995) Average Rating: 3.323510150622135
#
# Movie Title: Walk in the Clouds, A (1995) Average Rating: 3.385341726618705
#
# Movie Title: Billy Madison (1995) Average Rating: 3.2765649365114724
#
# Movie Title: Boys on the Side (1995) Average Rating: 3.2961666052340584
#
# Movie Title: Disclosure (1994) Average Rating: 3.291509196271101
#
# Movie Title: French Kiss (1995) Average Rating: 3.3247282608695654
#
# Movie Title: Forget Paris (1995) Average Rating: 3.2295667159034958
#
# Movie Title: Farinelli: il castrato (1994) Average Rating: 3.397632311977716
#
# Movie Title: I.Q. (1994) Average Rating: 3.228026400515132
#
# Movie Title: Enfer, L' (1994) Average Rating: 3.3537735849056602
#
# Movie Title: Little Odessa (1994) Average Rating: 3.294297352342159
#
# Movie Title: Losing Isaiah (1995) Average Rating: 3.324882075471698
#
# Movie Title: Nina Takes a Lover (1994) Average Rating: 3.29040404040404
#
# Movie Title: Only You (1994) Average Rating: 3.337912087912088
#
# Movie Title: Perez Family, The (1995) Average Rating: 3.2329545454545454
#
# Movie Title: Roommates (1995) Average Rating: 3.241489361702128
#
# Movie Title: Stargate (1994) Average Rating: 3.3493527080581242
#
# Movie Title: Suture (1993) Average Rating: 3.2219512195121953
#
# Movie Title: Star Trek: Generations (1994) Average Rating: 3.3362714170841836
#
# Movie Title: Tom & Viv (1994) Average Rating: 3.28494623655914
#
# Movie Title: Tommy Boy (1995) Average Rating: 3.353798733755415
#
# Movie Title: Underneath (1995) Average Rating: 3.313953488372093
#
# Movie Title: War, The (1994) Average Rating: 3.3825363825363826
#
# Movie Title: Bitter Moon (1992) Average Rating: 3.3581632653061226
#
# Movie Title: Corrina, Corrina (1994) Average Rating: 3.3066841415465267
#
# Movie Title: Crooklyn (1994) Average Rating: 3.2581967213114753
#
# Movie Title: Higher Learning (1995) Average Rating: 3.24609375
#
# Movie Title: I Like It Like That (1994) Average Rating: 3.2768361581920904
#
# Movie Title: It Could Happen to You (1994) Average Rating: 3.3324095207042714
#
# Movie Title: Mrs. Parker and the Vicious Circle (1994) Average Rating: 3.3178807947019866
#
# Movie Title: Paper, The (1994) Average Rating: 3.2510018214936247
#
# Movie Title: Reality Bites (1994) Average Rating: 3.2413645140527785
#
# Movie Title: Safe Passage (1994) Average Rating: 3.231707317073171
#
# Movie Title: River Wild, The (1994) Average Rating: 3.278003482298317
#
# Movie Title: Faster Pussycat! Kill! Kill! (1965) Average Rating: 3.397216274089936
#
# Movie Title: Secret Adventures of Tom Thumb, The (1993) Average Rating: 3.3076923076923075
#
# Movie Title: Coldblooded (1995) Average Rating: 3.3933333333333335
#
# Movie Title: Desert Winds (1995) Average Rating: 3.25
#
# Movie Title: Mirage (1995) Average Rating: 3.3214285714285716
#
# Movie Title: 8 Seconds (1994) Average Rating: 3.211021505376344
#
# Movie Title: Black Beauty (1994) Average Rating: 3.2962786259541983
#
# Movie Title: Blink (1994) Average Rating: 3.2474518686296716
#
# Movie Title: Endless Summer 2, The (1994) Average Rating: 3.385752688172043
#
# Movie Title: With Honors (1994) Average Rating: 3.3379310344827586
#
# Movie Title: Go Fish (1994) Average Rating: 3.377568493150685
#
# Movie Title: Heaven & Earth (1993) Average Rating: 3.2277904328018225
#
# Movie Title: Englishman Who Went Up a Hill But Came Down a Mountain, The (1995) Average Rating: 3.317463848720801
#
# Movie Title: House of the Spirits, The (1993) Average Rating: 3.2410604192355117
#
# Movie Title: Kalifornia (1993) Average Rating: 3.3251483190507582
#
# Movie Title: Malice (1993) Average Rating: 3.3628498727735368
#
# Movie Title: Executive Decision (1996) Average Rating: 3.3630631814002365
#
# Movie Title: What Happened Was... (1994) Average Rating: 3.2985611510791366
#
# Movie Title: Romeo Is Bleeding (1993) Average Rating: 3.32977207977208
#
# Movie Title: Saint of Fort Washington, The (1993) Average Rating: 3.3963963963963963
#
# Movie Title: Savage Nights (Nuits fauves, Les) (1992) Average Rating: 3.2093023255813953
#
# Movie Title: Second Best (1994) Average Rating: 3.210526315789474
#
# Movie Title: Simple Twist of Fate, A (1994) Average Rating: 3.252783964365256
#
# Movie Title: So I Married an Axe Murderer (1993) Average Rating: 3.2515256588072123
#
# Movie Title: Three Musketeers, The (1993) Average Rating: 3.228933733296973
#
# Movie Title: Kika (1993) Average Rating: 3.376923076923077
#
# Movie Title: Spanking the Monkey (1994) Average Rating: 3.33
#
# Movie Title: Métisse (Café au Lait) (1993) Average Rating: 3.3658536585365852
#
# Movie Title: Batman (1989) Average Rating: 3.3865572677433695
#
# Movie Title: Wooden Man's Bride, The (Yan shen) (1994) Average Rating: 3.3513513513513513
#
# Movie Title: One Fine Day (1996) Average Rating: 3.28719806763285
#
# Movie Title: Heavy Metal (1981) Average Rating: 3.380611795774648
#
# Movie Title: Aristocats, The (1970) Average Rating: 3.3823024054982818
#
# Movie Title: Asfour Stah (1990) Average Rating: 3.323529411764706
#
# Movie Title: Rude (1995) Average Rating: 3.4
#
# Movie Title: Carried Away (1996) Average Rating: 3.263157894736842
#
# Movie Title: Denise Calls Up (1995) Average Rating: 3.3915929203539825
#
# Movie Title: Jack and Sarah (1995) Average Rating: 3.3306451612903225
#
# Movie Title: Mission: Impossible (1996) Average Rating: 3.386744130898743
#
# Movie Title: Dragonheart (1996) Average Rating: 3.2238334697696174
#
# Movie Title: Und keiner weint mir nach (1996) Average Rating: 3.269230769230769
#
# Movie Title: James and the Giant Peach (1996) Average Rating: 3.3458940632776395
#
# Movie Title: Fear (1996) Average Rating: 3.224926686217009
#
# Movie Title: Kids in the Hall: Brain Candy (1996) Average Rating: 3.380479926165205
#
# Movie Title: Run of the Country, The (1995) Average Rating: 3.3970588235294117
#
# Movie Title: Promise, The (Das Versprechen) (1995) Average Rating: 3.324074074074074
#
# Movie Title: Angus (1995) Average Rating: 3.240498034076016
#
# Movie Title: Daens (1992) Average Rating: 3.3442622950819674
#
# Movie Title: Oliver & Company (1988) Average Rating: 3.2693950177935944
#
# Movie Title: Institute Benjamenta, or This Dream People Call Human Life (1995) Average Rating: 3.3135593220338984
#
# Movie Title: Twister (1996) Average Rating: 3.2202010531354714
#
# Movie Title: Careful (1992) Average Rating: 3.361111111111111
#
# Movie Title: Month by the Lake, A (1995) Average Rating: 3.286908077994429
#
# Movie Title: Kim (1950) Average Rating: 3.33
#
# Movie Title: Heavy (1995) Average Rating: 3.3759590792838874
#
# Movie Title: Life Is Rosy (a.k.a. Life Is Beautiful) (La Vie est belle) (1987) Average Rating: 3.2760416666666665
#
# Movie Title: Independence Day (a.k.a. ID4) (1996) Average Rating: 3.3759311880807927
#
# Movie Title: Hunchback of Notre Dame, The (1996) Average Rating: 3.245648802343615
#
# Movie Title: Kingpin (1996) Average Rating: 3.2968150742037685
#
# Movie Title: Midnight Dancers (Sibak) (1994) Average Rating: 3.3857142857142857
#
# Movie Title: Somebody to Love (1994) Average Rating: 3.212121212121212
#
# Movie Title: Old Lady Who Walked in the Sea, The (Vieille qui marchait dans la mer, La) (1991) Average Rating: 3.3641975308641974
#
# Movie Title: Frighteners, The (1996) Average Rating: 3.3645594965675056
#
# Movie Title: Rendezvous in Paris (Rendez-vous de Paris, Les) (1995) Average Rating: 3.3114754098360657
#
# Movie Title: Alaska (1996) Average Rating: 3.237051792828685
#
# Movie Title: Boy Called Hate, A (1995) Average Rating: 3.2777777777777777
#
# Movie Title: Two Deaths (1995) Average Rating: 3.2142857142857144
#
# Movie Title: Foxfire (1996) Average Rating: 3.218855218855219
#
# Movie Title: Lotto Land (1995) Average Rating: 3.383720930232558
#
# Movie Title: Dingo (1991) Average Rating: 3.3445945945945947
#
# Movie Title: Mille bolle blu (1993) Average Rating: 3.371794871794872
#
# Movie Title: Wife, The (1995) Average Rating: 3.2413793103448274
#
# Movie Title: Small Faces (1996) Average Rating: 3.379032258064516
#
# Movie Title: Reluctant Debutante, The (1958) Average Rating: 3.25
#
# Movie Title: Scarlet Letter, The (1926) Average Rating: 3.2857142857142856
#
# Movie Title: Little Lord Fauntleroy (1936) Average Rating: 3.365771812080537
#
# Movie Title: They Made Me a Criminal (1939) Average Rating: 3.3559322033898304
#
# Movie Title: Last Time I Saw Paris, The (1954) Average Rating: 3.2803030303030303
#
# Movie Title: Nothing Personal (1995) Average Rating: 3.303030303030303
#
# Movie Title: Grace of My Heart (1996) Average Rating: 3.3304347826086955
#
# Movie Title: Set It Off (1996) Average Rating: 3.209839357429719
#
# Movie Title: 2 Days in the Valley (1996) Average Rating: 3.2913956978489245
#
# Movie Title: Curdled (1996) Average Rating: 3.2109375
#
# Movie Title: Chamber, The (1996) Average Rating: 3.270938446014127
#
# Movie Title: Davy Crockett, King of the Wild Frontier (1955) Average Rating: 3.288187372708758
#
# Movie Title: Pollyanna (1960) Average Rating: 3.3245
#
# Movie Title: Homeward Bound: The Incredible Journey (1993) Average Rating: 3.255614973262032
#
# Movie Title: Cool Runnings (1993) Average Rating: 3.240216121495327
#
# Movie Title: Robin Hood: Prince of Thieves (1991) Average Rating: 3.2681807199806716
#
# Movie Title: Bedknobs and Broomsticks (1971) Average Rating: 3.3295896328293737
#
# Movie Title: Unhook the Stars (1996) Average Rating: 3.2933333333333334
#
# Movie Title: Normal Life (1996) Average Rating: 3.2131782945736433
#
# Movie Title: Bitter Sugar (Azúcar amarga) (1996) Average Rating: 3.268421052631579
#
# Movie Title: Johns (1996) Average Rating: 3.360576923076923
#
# Movie Title: Damsel in Distress, A (1937) Average Rating: 3.375
#
# Movie Title: For the Moment (1994) Average Rating: 3.2162162162162162
#
# Movie Title: Madame Butterfly (1995) Average Rating: 3.375
#
# Movie Title: Basic Instinct (1992) Average Rating: 3.359633327876903
#
# Movie Title: Doors, The (1991) Average Rating: 3.3425468904244817
#
# Movie Title: Charm's Incidents (Charms Zwischenfälle) (1996) Average Rating: 3.375
#
# Movie Title: Palookaville (1996) Average Rating: 3.376953125
#
# Movie Title: Associate, The (1996) Average Rating: 3.2286585365853657
#
# Movie Title: Funeral, The (1996) Average Rating: 3.2933333333333334
#
# Movie Title: Sleepover (1995) Average Rating: 3.2708333333333335
#
# Movie Title: Drunks (1997) Average Rating: 3.256
#
# Movie Title: Howling, The (1980) Average Rating: 3.228369384359401
#
# Movie Title: Johnny 100 Pesos (Johnny cien pesos) (1993) Average Rating: 3.2
#
# Movie Title: Hustler White (1996) Average Rating: 3.231707317073171
#
# Movie Title: Dadetown (1995) Average Rating: 3.3125
#
# Movie Title: Curtis's Charm (1995) Average Rating: 3.230769230769231
#
# Movie Title: Raw Deal (1948) Average Rating: 3.353932584269663
#
# Movie Title: T-Men (1947) Average Rating: 3.34
#
# Movie Title: Children Are Watching Us, The (Bambini ci guardano, I) (1944) Average Rating: 3.236842105263158
#
# Movie Title: Six of a Kind (1934) Average Rating: 3.2083333333333335
#
# Movie Title: Breathing Room (1996) Average Rating: 3.2115384615384617
#
# Movie Title: Nightmare on Elm Street, A (1984) Average Rating: 3.296437994722955
#
# Movie Title: Nosferatu in Venice (a.k.a. Vampire in Venice) (Nosferatu a Venezia) (1986) Average Rating: 3.21875
#
# Movie Title: Identification of a Woman (Identificazione di una donna) (1982) Average Rating: 3.274193548387097
#
# Movie Title: Die Hard 2 (1990) Average Rating: 3.3985599078341013
#
# Movie Title: Star Trek VI: The Undiscovered Country (1991) Average Rating: 3.291080912214933
#
# Movie Title: Star Trek III: The Search for Spock (1984) Average Rating: 3.2341528683726377
#
# Movie Title: Young Guns (1988) Average Rating: 3.294395116537181
#
# Movie Title: Grease (1978) Average Rating: 3.31844861318909
#
# Movie Title: My Fellow Americans (1996) Average Rating: 3.2939453125
#
# Movie Title: Tin Men (1987) Average Rating: 3.3765971755211837
#
# Movie Title: Marvin's Room (1996) Average Rating: 3.3992117117117115
#
# Movie Title: Night Falls on Manhattan (1996) Average Rating: 3.220319634703196
#
# Movie Title: Scream (1996) Average Rating: 3.3065618221258135
#
# Movie Title: Evita (1996) Average Rating: 3.2015258652772607
#
# Movie Title: Fierce Creatures (1997) Average Rating: 3.230740181268882
#
# Movie Title: Jackie Chan's First Strike (Police Story 4: First Strike) (Jing cha gu shi IV: Jian dan ren wu) (1996) Average Rating: 3.3365657521286662
#
# Movie Title: Prefontaine (1997) Average Rating: 3.366740088105727
#
# Movie Title: Gridlock'd (1997) Average Rating: 3.2376373626373627
#
# Movie Title: SubUrbia (1997) Average Rating: 3.203157894736842
#
# Movie Title: Absolute Power (1997) Average Rating: 3.350505536831969
#
# Movie Title: Rhyme & Reason (1997) Average Rating: 3.3472222222222223
#
# Movie Title: Private Parts (1997) Average Rating: 3.3922651933701657
#
# Movie Title: Love Jones (1997) Average Rating: 3.33953488372093
#
# Movie Title: Smilla's Sense of Snow (1997) Average Rating: 3.2510008006405124
#
# Movie Title: Liar Liar (1997) Average Rating: 3.225168076339189
#
# Movie Title: Kissed (1996) Average Rating: 3.3549382716049383
#
# Movie Title: Hollow Reed (1996) Average Rating: 3.345679012345679
#
# Movie Title: Traveller (1997) Average Rating: 3.302325581395349
#
# Movie Title: Breakdown (1997) Average Rating: 3.2891976927110647
#
# Movie Title: Broken English (1996) Average Rating: 3.3
#
# Movie Title: Losing Chase (1996) Average Rating: 3.3529411764705883
#
# Movie Title: Bonheur, Le (1965) Average Rating: 3.3260869565217392
#
# Movie Title: Shiloh (1997) Average Rating: 3.34375
#
# Movie Title: Late Bloomers (1996) Average Rating: 3.3181818181818183
#
# Movie Title: Dream With the Fishes (1997) Average Rating: 3.342857142857143
#
# Movie Title: Hercules (1997) Average Rating: 3.251063829787234
#
# Movie Title: My Best Friend's Wedding (1997) Average Rating: 3.318019205422708
#
# Movie Title: Tetsuo II: Body Hammer (1992) Average Rating: 3.2277486910994764
#
# Movie Title: Face/Off (1997) Average Rating: 3.3452472211575315
#
# Movie Title: Mondo (1996) Average Rating: 3.323529411764706
#
# Movie Title: Love Serenade (1996) Average Rating: 3.3307086614173227
#
# Movie Title: Conan the Barbarian (1982) Average Rating: 3.2382243791036256
#
# Movie Title: Cop Land (1997) Average Rating: 3.2780766644250168
#
# Movie Title: Career Girls (1997) Average Rating: 3.3706624605678233
#
# Movie Title: Conspiracy Theory (1997) Average Rating: 3.311925810365748
#
# Movie Title: Air Force One (1997) Average Rating: 3.3222643896268185
#
# Movie Title: Kiss Me, Guido (1997) Average Rating: 3.2127659574468086
#
# Movie Title: Seven Years in Tibet (1997) Average Rating: 3.381759483454399
#
# Movie Title: Kiss the Girls (1997) Average Rating: 3.3535514764565044
#
# Movie Title: MatchMaker, The (1997) Average Rating: 3.2092819614711035
#
# Movie Title: FairyTale: A True Story (1997) Average Rating: 3.321695760598504
#
# Movie Title: Wonderland (1997) Average Rating: 3.287037037037037
#
# Movie Title: Tango Lesson, The (1997) Average Rating: 3.375
#
# Movie Title: Anastasia (1997) Average Rating: 3.3264576457645765
#
# Movie Title: Man Who Knew Too Little, The (1997) Average Rating: 3.202209005947324
#
# Movie Title: Midnight in the Garden of Good and Evil (1997) Average Rating: 3.229093464511595
#
# Movie Title: Titanic (1997) Average Rating: 3.321596101127018
#
# Movie Title: Tomorrow Never Dies (1997) Average Rating: 3.2552619449992317
#
# Movie Title: Winter Guest, The (1997) Average Rating: 3.3817567567567566
#
# Movie Title: Afterglow (1997) Average Rating: 3.288793103448276
#
# Movie Title: Half Baked (1998) Average Rating: 3.240680713128039
#
# Movie Title: Music From Another Room (1998) Average Rating: 3.239669421487603
#
# Movie Title: Wild Things (1998) Average Rating: 3.2728726020659122
#
# Movie Title: Cool, Dry Place, A (1998) Average Rating: 3.2736842105263158
#
# Movie Title: Niagara, Niagara (1997) Average Rating: 3.2211538461538463
#
# Movie Title: Price Above Rubies, A (1998) Average Rating: 3.3175675675675675
#
# Movie Title: City of Angels (1998) Average Rating: 3.222821896684657
#
# Movie Title: Last Days of Disco, The (1998) Average Rating: 3.280922431865828
#
# Movie Title: He Got Game (1998) Average Rating: 3.356466876971609
#
# Movie Title: Junk Mail (Budbringeren) (1997) Average Rating: 3.282051282051282
#
# Movie Title: Dancer, Texas Pop. 81 (1998) Average Rating: 3.392
#
# Movie Title: Friend of the Deceased, A (Priyatel pokonika) (1997) Average Rating: 3.37
#
# Movie Title: Clockwatchers (1997) Average Rating: 3.3914327917282128
#
# Movie Title: Bulworth (1998) Average Rating: 3.377109200891436
#
# Movie Title: Perfect Murder, A (1998) Average Rating: 3.345914558274575
#
# Movie Title: Land Girls, The (1998) Average Rating: 3.2285714285714286
#
# Movie Title: Dream for an Insomniac (1996) Average Rating: 3.3034682080924855
#
# Movie Title: X-Files: Fight the Future, The (1998) Average Rating: 3.3631676158226873
#
# Movie Title: I Went Down (1997) Average Rating: 3.385
#
# Movie Title: Whatever (1998) Average Rating: 3.2580645161290325
#
# Movie Title: Broadway Melody, The (1929) Average Rating: 3.257425742574257
#
# Movie Title: Greatest Show on Earth, The (1952) Average Rating: 3.2583586626139818
#
# Movie Title: Lethal Weapon 2 (1989) Average Rating: 3.3172641120725177
#
# Movie Title: Lethal Weapon 3 (1992) Average Rating: 3.2001489678655033
#
# Movie Title: Gremlins (1984) Average Rating: 3.251660026560425
#
# Movie Title: Mask of Zorro, The (1998) Average Rating: 3.3375743327340617
#
# Movie Title: Back to the Future Part II (1989) Average Rating: 3.373681592039801
#
# Movie Title: Poseidon Adventure, The (1972) Average Rating: 3.339604281543951
#
# Movie Title: Absent Minded Professor, The (1961) Average Rating: 3.3809366754617414
#
# Movie Title: Dune (1984) Average Rating: 3.294068678459938
#
# Movie Title: Godfather: Part III, The (1990) Average Rating: 3.3949032738095237
#
# Movie Title: Rapture, The (1991) Average Rating: 3.266798418972332
#
# Movie Title: Candleshoe (1977) Average Rating: 3.2957198443579765
#
# Movie Title: Darby O'Gill and the Little People (1959) Average Rating: 3.253623188405797
#
# Movie Title: Far Off Place, A (1993) Average Rating: 3.373046875
#
# Movie Title: Great Mouse Detective, The (1986) Average Rating: 3.3719745222929935
#
# Movie Title: Happiest Millionaire, The (1967) Average Rating: 3.313008130081301
#
# Movie Title: In Search of the Castaways (1962) Average Rating: 3.3028846153846154
#
# Movie Title: Incredible Journey, The (1963) Average Rating: 3.376637554585153
#
# Movie Title: Kidnapped (1960) Average Rating: 3.3544303797468356
#
# Movie Title: Rescuers Down Under, The (1990) Average Rating: 3.246376811594203
#
# Movie Title: Splash (1984) Average Rating: 3.257652680304614
#
# Movie Title: Tex (1982) Average Rating: 3.300518134715026
#
# Movie Title: Tron (1982) Average Rating: 3.31479718148924
#
# Movie Title: Swing Kids (1993) Average Rating: 3.3230688935281836
#
# Movie Title: Dead Men Don't Wear Plaid (1982) Average Rating: 3.2848729076255423
#
# Movie Title: Man with Two Brains, The (1983) Average Rating: 3.2356363636363636
#
# Movie Title: Safe Men (1998) Average Rating: 3.3378378378378377
#
# Movie Title: Adventures in Babysitting (1987) Average Rating: 3.2054063994115483
#
# Movie Title: Weird Science (1985) Average Rating: 3.3038160469667317
#
# Movie Title: American Tail, An (1986) Average Rating: 3.3144720235591083
#
# Movie Title: Legend (1985) Average Rating: 3.257433920704846
#
# Movie Title: Pretty in Pink (1986) Average Rating: 3.350261780104712
#
# Movie Title: Slums of Beverly Hills, The (1998) Average Rating: 3.397008547008547
#
# Movie Title: Your Friends and Neighbors (1998) Average Rating: 3.2104
#
# Movie Title: Blade (1998) Average Rating: 3.375081433224756
#
# Movie Title: Strike! (a.k.a. All I Wanna Do, The Hairy Bird) (1998) Average Rating: 3.319672131147541
#
# Movie Title: I Married A Strange Person! (1997) Average Rating: 3.378504672897196
#
# Movie Title: Phoenix (1998) Average Rating: 3.3846153846153846
#
# Movie Title: Paradine Case, The (1947) Average Rating: 3.348148148148148
#
# Movie Title: Young and Innocent (1937) Average Rating: 3.397727272727273
#
# Movie Title: Murder! (1930) Average Rating: 3.2785714285714285
#
# Movie Title: My Bodyguard (1980) Average Rating: 3.39738430583501
#
# Movie Title: Working Girl (1988) Average Rating: 3.332798001427552
#
# Movie Title: Men Don't Leave (1990) Average Rating: 3.2490118577075098
#
# Movie Title: One Crazy Summer (1986) Average Rating: 3.2781109445277363
#
# Movie Title: Century of Cinema, A (1994) Average Rating: 3.4
#
# Movie Title: Permanent Midnight (1998) Average Rating: 3.219402985074627
#
# Movie Title: Six-String Samurai (1998) Average Rating: 3.3786666666666667
#
# Movie Title: Clay Pigeons (1998) Average Rating: 3.3312159709618876
#
# Movie Title: Sheltering Sky, The (1990) Average Rating: 3.2
#
# Movie Title: Antz (1998) Average Rating: 3.369998048018739
#
# Movie Title: Inheritors, The (Die Siebtelbauern) (1998) Average Rating: 3.396551724137931
#
# Movie Title: 2010: The Year We Make Contact (1984) Average Rating: 3.365693739424704
#
# Movie Title: Living Out Loud (1998) Average Rating: 3.3685897435897436
#
# Movie Title: Velvet Goldmine (1998) Average Rating: 3.298575129533679
#
# Movie Title: Meet Joe Black (1998) Average Rating: 3.2305016477480777
#
# Movie Title: Dancing at Lughnasa (1998) Average Rating: 3.2525
#
# Movie Title: Stepford Wives, The (1975) Average Rating: 3.3084772370486655
#
# Movie Title: Pink Flamingos (1972) Average Rating: 3.29568345323741
#
# Movie Title: Godzilla (Gojira) (1954) Average Rating: 3.21072226358898
#
# Movie Title: Steam: The Turkish Bath (Hamam) (1997) Average Rating: 3.3365384615384617
#
# Movie Title: Star Trek: Insurrection (1998) Average Rating: 3.2147721935180837
#
# Movie Title: Mass Appeal (1984) Average Rating: 3.3063063063063063
#
# Movie Title: Cocoon (1985) Average Rating: 3.3202792439979567
#
# Movie Title: Clue (1985) Average Rating: 3.360409407665505
#
# Movie Title: Young Sherlock Holmes (1985) Average Rating: 3.388406695598264
#
# Movie Title: Karate Kid, The (1984) Average Rating: 3.2590218423551756
#
# Movie Title: Theory of Flight, The (1998) Average Rating: 3.238532110091743
#
# Movie Title: Thin Red Line, The (1998) Average Rating: 3.392709291628335
#
# Movie Title: Civil Action, A (1998) Average Rating: 3.329971762807584
#
# Movie Title: Tea with Mussolini (1999) Average Rating: 3.388757396449704
#
# Movie Title: 24 7: Twenty Four Seven (1997) Average Rating: 3.282608695652174
#
# Movie Title: Fly, The (1958) Average Rating: 3.335125448028674
#
# Movie Title: Fly, The (1986) Average Rating: 3.3803353658536586
#
# Movie Title: Running Scared (1986) Average Rating: 3.335672514619883
#
# Movie Title: Belizaire the Cajun (1986) Average Rating: 3.28125
#
# Movie Title: Heartbreak Ridge (1986) Average Rating: 3.289992119779354
#
# Movie Title: Still Crazy (1998) Average Rating: 3.256038647342995
#
# Movie Title: Day of the Beast, The (El Día de la bestia) (1995) Average Rating: 3.284375
#
# Movie Title: Blast from the Past (1999) Average Rating: 3.2141527001862196
#
# Movie Title: Night Shift (1982) Average Rating: 3.3236404833836857
#
# Movie Title: House on Haunted Hill (1958) Average Rating: 3.2392241379310347
#
# Movie Title: Dancemaker (1998) Average Rating: 3.314814814814815
#
# Movie Title: Analyze This (1999) Average Rating: 3.2572763968557465
#
# Movie Title: Cruel Intentions (1999) Average Rating: 3.2714056776556775
#
# Movie Title: School of Flesh, The (L' École de la chair) (1998) Average Rating: 3.255952380952381
#
# Movie Title: Relax... It's Just Sex (1998) Average Rating: 3.25625
#
# Movie Title: Harvest (1998) Average Rating: 3.3333333333333335
#
# Movie Title: Village of the Damned (1960) Average Rating: 3.3994350282485875
#
# Movie Title: Children of the Damned (1963) Average Rating: 3.217436974789916
#
# Movie Title: Bandits (1997) Average Rating: 3.3046357615894038
#
# Movie Title: Tango (1998) Average Rating: 3.264705882352941
#
# Movie Title: eXistenZ (1999) Average Rating: 3.31636863823934
#
# Movie Title: Midsummer Night's Dream, A (1999) Average Rating: 3.303926206244087
#
# Movie Title: Mummy, The (1932) Average Rating: 3.3532994923857866
#
# Movie Title: Superman (1978) Average Rating: 3.3875656938387566
#
# Movie Title: Son of Frankenstein (1939) Average Rating: 3.2062780269058297
#
# Movie Title: Rocky Horror Picture Show, The (1975) Average Rating: 3.3142456234130697
#
# Movie Title: It Came from Outer Space (1953) Average Rating: 3.249206349206349
#
# Movie Title: Earth vs. the Flying Saucers (1956) Average Rating: 3.2266355140186915
#
# Movie Title: Thirteenth Floor, The (1999) Average Rating: 3.2189647274393036
#
# Movie Title: Twice Upon a Yesterday (1998) Average Rating: 3.3
#
# Movie Title: Austin Powers: The Spy Who Shagged Me (1999) Average Rating: 3.2332583427071615
#
# Movie Title: Red Dwarf, The (Nain rouge, Le) (1998) Average Rating: 3.263157894736842
#
# Movie Title: Get Bruce (1999) Average Rating: 3.200617283950617
#
# Movie Title: Late August, Early September (Fin août, début septembre) (1998) Average Rating: 3.388888888888889
#
# Movie Title: American Pie (1999) Average Rating: 3.384331759052117
#
# Movie Title: Mosquito Coast, The (1986) Average Rating: 3.332936979785969
#
# Movie Title: Crimes of the Heart (1986) Average Rating: 3.3577712609970676
#
# Movie Title: Native Son (1986) Average Rating: 3.221311475409836
#
# Movie Title: Little Shop of Horrors (1986) Average Rating: 3.283904109589041
#
# Movie Title: Little Shop of Horrors, The (1960) Average Rating: 3.2197149643705463
#
# Movie Title: Bedroom Window, The (1987) Average Rating: 3.2362385321100917
#
# Movie Title: Dick (1999) Average Rating: 3.296759522455941
#
# Movie Title: Gambler, The (A Játékos) (1997) Average Rating: 3.391891891891892
#
# Movie Title: Adventures of Sebastian Cole, The (1998) Average Rating: 3.217142857142857
#
# Movie Title: Better Than Chocolate (1999) Average Rating: 3.3046272493573263
#
# Movie Title: Pit and the Pendulum (1961) Average Rating: 3.326923076923077
#
# Movie Title: Masque of the Red Death, The (1964) Average Rating: 3.3501805054151625
#
# Movie Title: Oscar and Lucinda (a.k.a. Oscar & Lucinda) (1997) Average Rating: 3.397222222222222
#
# Movie Title: Pelican Brief, The (1993) Average Rating: 3.247298919567827
#
# Movie Title: Source, The (1999) Average Rating: 3.268292682926829
#
# Movie Title: Lucie Aubrac (1997) Average Rating: 3.3916666666666666
#
# Movie Title: Very Thought of You, The (1998) Average Rating: 3.3513513513513513
#
# Movie Title: Outside Providence (1999) Average Rating: 3.2365728900255752
#
# Movie Title: Bedrooms & Hallways (1998) Average Rating: 3.355855855855856
#
# Movie Title: Best Laid Plans (1999) Average Rating: 3.223849372384937
#
# Movie Title: Splendor (1999) Average Rating: 3.205
#
# Movie Title: Fright Night (1985) Average Rating: 3.3204488778054864
#
# Movie Title: Separation, The (La Séparation) (1994) Average Rating: 3.274193548387097
#
# Movie Title: Operation Condor (Armour of God II: Operation Condor) (Fei ying gai wak) (1991) Average Rating: 3.331738437001595
#
# Movie Title: Guinevere (1999) Average Rating: 3.2789017341040463
#
# Movie Title: Mystery, Alaska (1999) Average Rating: 3.3056265984654734
#
# Movie Title: Happy, Texas (1999) Average Rating: 3.3833528722157094
#
# Movie Title: Gulliver's Travels (1939) Average Rating: 3.352722772277228
#
# Movie Title: Hairspray (1988) Average Rating: 3.3908751334044824
#
# Movie Title: Razor's Edge, The (1984) Average Rating: 3.380813953488372
#
# Movie Title: Love Bewitched, A (El Amor Brujo) (1986) Average Rating: 3.3333333333333335
#
# Movie Title: Fever Pitch (1997) Average Rating: 3.365702479338843
#
# Movie Title: Joe the King (1999) Average Rating: 3.2037037037037037
#
# Movie Title: Brother, Can You Spare a Dime? (1975) Average Rating: 3.324324324324324
#
# Movie Title: RoboCop (1987) Average Rating: 3.3006439150032194
#
# Movie Title: City, The (La Ciudad) (1998) Average Rating: 3.309090909090909
#
# Movie Title: Music of the Heart (1999) Average Rating: 3.3687089715536107
#
# Movie Title: Dreaming of Joseph Lees (1999) Average Rating: 3.215686274509804
#
# Movie Title: Man of the Century (1999) Average Rating: 3.3275862068965516
#
# Movie Title: Train of Life (Train De Vie) (1998) Average Rating: 3.3579545454545454
#
# Movie Title: Bone Collector, The (1999) Average Rating: 3.2391369047619047
#
# Movie Title: Coma (1978) Average Rating: 3.301109350237718
#
# Movie Title: Spaceballs (1987) Average Rating: 3.390831134564644
#
# Movie Title: Quest for Fire (Guerre du feu, La) (1981) Average Rating: 3.2425531914893617
#
# Movie Title: Nothing to Lose (a.k.a. Ten Benny) (1996) Average Rating: 3.238095238095238
#
# Movie Title: Adventures of Buckaroo Banzai Across the 8th Dimension, The (1984) Average Rating: 3.3479638009049775
#
# Movie Title: World Is Not Enough, The (1999) Average Rating: 3.2174661464310303
#
# Movie Title: Shampoo (1975) Average Rating: 3.2236533957845435
#
# Movie Title: Come See the Paradise (1990) Average Rating: 3.2295081967213113
#
# Movie Title: Backdraft (1991) Average Rating: 3.3409313725490195
#
# Movie Title: Country (1984) Average Rating: 3.3333333333333335
#
# Movie Title: Ride with the Devil (1999) Average Rating: 3.302521008403361
#
# Movie Title: Santa Fe Trail (1940) Average Rating: 3.218390804597701
#
# Movie Title: End of the Affair, The (1955) Average Rating: 3.35
#
# Movie Title: Map of the World, A (1999) Average Rating: 3.3082901554404147
#
# Movie Title: Broadway Damage (1997) Average Rating: 3.3333333333333335
#
# Movie Title: Sea Wolves, The (1980) Average Rating: 3.348101265822785
#
# Movie Title: Cradle Will Rock (1999) Average Rating: 3.3064295485636115
#
# Movie Title: Blood on the Sun (1945) Average Rating: 3.3392857142857144
#
# Movie Title: Onegin (1999) Average Rating: 3.3155339805825244
#
# Movie Title: Snow Falling on Cedars (1999) Average Rating: 3.3221299093655587
#
# Movie Title: American Flyers (1985) Average Rating: 3.347058823529412
#
# Movie Title: Poison (1991) Average Rating: 3.2010309278350517
#
# Movie Title: Pacific Heights (1990) Average Rating: 3.22684246112238
#
# Movie Title: Santitos (1999) Average Rating: 3.235294117647059
#
# Movie Title: Agnes of God (1985) Average Rating: 3.3858823529411763
#
# Movie Title: Far and Away (1992) Average Rating: 3.2527409117137913
#
# Movie Title: Twin Peaks: Fire Walk with Me (1992) Average Rating: 3.3844155844155845
#
# Movie Title: Cutting Edge, The (1992) Average Rating: 3.3239104829210837
#
# Movie Title: Bad Lieutenant (1992) Average Rating: 3.2503649635036496
#
# Movie Title: Minnie and Moskowitz (1971) Average Rating: 3.352272727272727
#
# Movie Title: Pitch Black (2000) Average Rating: 3.3376659292035398
#
# Movie Title: Whole Nine Yards, The (2000) Average Rating: 3.364788312462731
#
# Movie Title: Deterrence (1999) Average Rating: 3.336206896551724
#
# Movie Title: Judy Berlin (1999) Average Rating: 3.210227272727273
#
# Movie Title: I'll Never Forget What's'isname (1967) Average Rating: 3.3333333333333335
#
# Movie Title: Charlie, the Lonesome Cougar (1967) Average Rating: 3.2866666666666666
#
# Movie Title: Perils of Pauline, The (1947) Average Rating: 3.223076923076923
#
# Movie Title: Betrayed (1988) Average Rating: 3.3333333333333335
#
# Movie Title: Destination Moon (1950) Average Rating: 3.2283464566929134
#
# Movie Title: Hangmen Also Die (1943) Average Rating: 3.38
#
# Movie Title: Ogre, The (Der Unhold) (1996) Average Rating: 3.3676470588235294
#
# Movie Title: Railroaded! (1947) Average Rating: 3.2
#
# Movie Title: Slaves to the Underground (1997) Average Rating: 3.2
#
# Movie Title: Song of Freedom (1936) Average Rating: 3.4
#
# Movie Title: Turtle Diary (1985) Average Rating: 3.375
#
# Movie Title: Titanic (1953) Average Rating: 3.2263374485596708
#
# Movie Title: Soft Fruit (1999) Average Rating: 3.3636363636363638
#
# Movie Title: Love Is a Many-Splendored Thing (1955) Average Rating: 3.3801369863013697
#
# Movie Title: Mo' Better Blues (1990) Average Rating: 3.330827067669173
#
# Movie Title: Coogan's Bluff (1968) Average Rating: 3.338862559241706
#
# Movie Title: Grumpy Old Men (1993) Average Rating: 3.3626994680851063
#
# Movie Title: Empire Records (1995) Average Rating: 3.3013788575180563
#
# Movie Title: Bamba, La (1987) Average Rating: 3.22663139329806
#
# Movie Title: Son of the Sheik, The (1926) Average Rating: 3.23
#
# Movie Title: Madame Sousatzka (1988) Average Rating: 3.2305194805194803
#
# Movie Title: My Life (1993) Average Rating: 3.364705882352941
#
# Movie Title: North Dallas Forty (1979) Average Rating: 3.2767094017094016
#
# Movie Title: Rules of Engagement (2000) Average Rating: 3.2949568679495687
#
# Movie Title: Joe Gould's Secret (2000) Average Rating: 3.2626582278481013
#
# Movie Title: Bells, The (1926) Average Rating: 3.25
#
# Movie Title: Force 10 from Navarone (1978) Average Rating: 3.3051750380517504
#
# Movie Title: Arthur (1981) Average Rating: 3.2980427046263343
#
# Movie Title: American Psycho (2000) Average Rating: 3.3689086294416244
#
# Movie Title: Hunger, The (1983) Average Rating: 3.3635578583765113
#
# Movie Title: U-571 (2000) Average Rating: 3.3536116451524305
#
# Movie Title: Where the Heart Is (2000) Average Rating: 3.2332361516034984
#
# Movie Title: Big Kahuna, The (2000) Average Rating: 3.282258064516129
#
# Movie Title: Bossa Nova (2000) Average Rating: 3.391304347826087
#
# Movie Title: Last September, The (1999) Average Rating: 3.2
#
# Movie Title: Time Code (2000) Average Rating: 3.2362924281984333
#
# Movie Title: Great Locomotive Chase, The (1956) Average Rating: 3.2169811320754715
#
# Movie Title: Idolmaker, The (1980) Average Rating: 3.391304347826087
#
# Movie Title: King of Marvin Gardens, The (1972) Average Rating: 3.369047619047619
#
# Movie Title: Mr. Mom (1983) Average Rating: 3.2676453980801807
#
# Movie Title: Castaway Cowboy, The (1974) Average Rating: 3.236842105263158
#
# Movie Title: One Little Indian (1973) Average Rating: 3.375
#
# Movie Title: Pee-wee's Big Adventure (1985) Average Rating: 3.3190768237572628
#
# Movie Title: Slipper and the Rose, The (1976) Average Rating: 3.363157894736842
#
# Movie Title: Road Trip (2000) Average Rating: 3.213128038897893
#
# Movie Title: Small Time Crooks (2000) Average Rating: 3.3100624024961
#
# Movie Title: Shanghai Noon (2000) Average Rating: 3.3928295073510446
#
# Movie Title: Better Living Through Circuitry (1999) Average Rating: 3.25
#
# Movie Title: It's in the Water (1998) Average Rating: 3.236842105263158
#
# Movie Title: King in New York, A (1957) Average Rating: 3.3189655172413794
#
# Movie Title: Fighting Seabees, The (1944) Average Rating: 3.2676767676767677
#
# Movie Title: Dark Command (1940) Average Rating: 3.2857142857142856
#
# Movie Title: Pandora and the Flying Dutchman (1951) Average Rating: 3.230769230769231
#
# Movie Title: Enemy from Space (Quatermass 2) (1957) Average Rating: 3.32967032967033
#
# Movie Title: Fabulous Baker Boys, The (1989) Average Rating: 3.3152466367713003
#
# Movie Title: Flatliners (1990) Average Rating: 3.2255883825738607
#
# Movie Title: Sarafina! (1992) Average Rating: 3.200980392156863
#
# Movie Title: Soapdish (1991) Average Rating: 3.2329787234042553
#
# Movie Title: American Pimp (1999) Average Rating: 3.360082304526749
#
# Movie Title: Shaft (1971) Average Rating: 3.2934051144010765
#
# Movie Title: Sugarland Express, The (1974) Average Rating: 3.3915929203539825
#
# Movie Title: Titan A.E. (2000) Average Rating: 3.215144230769231
#
# Movie Title: Time Regained (Temps retrouvé, Le) (1999) Average Rating: 3.3950617283950617
#
# Movie Title: Fun and Fancy Free (1947) Average Rating: 3.2180851063829787
#
# Movie Title: Dreamscape (1984) Average Rating: 3.362264150943396
#
# Movie Title: Make Mine Music (1946) Average Rating: 3.3157894736842106
#
# Movie Title: Melody Time (1948) Average Rating: 3.280821917808219
#
# Movie Title: But I'm a Cheerleader (1999) Average Rating: 3.3236196319018405
#
# Movie Title: Groove (2000) Average Rating: 3.3771428571428572
#
# Movie Title: Duel in the Sun (1946) Average Rating: 3.3482758620689657
#
# Movie Title: Chuck & Buck (2000) Average Rating: 3.2636022514071295
#
# Movie Title: What Lies Beneath (2000) Average Rating: 3.2417685794920037
#
# Movie Title: What About Bob? (1991) Average Rating: 3.3674042272126816
#
# Movie Title: Better Living (1998) Average Rating: 3.25
#
# Movie Title: Black Sabbath (Tre volti della paura, I) (1963) Average Rating: 3.3716216216216215
#
# Movie Title: About Adam (2000) Average Rating: 3.338815789473684
#
# Movie Title: Original Kings of Comedy, The (2000) Average Rating: 3.283333333333333
#
# Movie Title: Devil Rides Out, The (1968) Average Rating: 3.2547169811320753
#
# Movie Title: Skipped Parts (2000) Average Rating: 3.2222222222222223
#
# Movie Title: Nurse Betty (2000) Average Rating: 3.248261983168679
#
# Movie Title: Way of the Gun, The (2000) Average Rating: 3.279623477297896
#
# Movie Title: Urbania (2000) Average Rating: 3.3
#
# Movie Title: Specials, The (2000) Average Rating: 3.2662337662337664
#
# Movie Title: Hellraiser (1987) Average Rating: 3.29449961802903
#
# Movie Title: Voyage to the Bottom of the Sea (1961) Average Rating: 3.328212290502793
#
# Movie Title: Creature from the Black Lagoon, The (1954) Average Rating: 3.297427652733119
#
# Movie Title: Unsinkable Molly Brown, The (1964) Average Rating: 3.251655629139073
#
# Movie Title: Pay It Forward (2000) Average Rating: 3.297069597069597
#
# Movie Title: Beyond, The (E tu Vivrai nel Terrore - L'aldilà ) (1981) Average Rating: 3.287037037037037
#
# Movie Title: What's Cooking? (2000) Average Rating: 3.3125
#
# Movie Title: Boys Life 3 (2000) Average Rating: 3.375
#
# Movie Title: Living Daylights, The (1987) Average Rating: 3.21713508612874
#
# Movie Title: Transformers: The Movie (1986) Average Rating: 3.269130998702983
#
# Movie Title: What Women Want (2000) Average Rating: 3.203690560681334
#
# Movie Title: Family Man, The (2000) Average Rating: 3.3256496227996646
#
# Movie Title: House of Mirth, The (2000) Average Rating: 3.3827319587628866
#
# Movie Title: Claim, The (2000) Average Rating: 3.2688442211055277
#
# Movie Title: Kill Me Again (1989) Average Rating: 3.2857142857142856
#
# Movie Title: Alamo, The (1960) Average Rating: 3.3694444444444445
#
# Movie Title: Breakheart Pass (1975) Average Rating: 3.3358208955223883
#
# Movie Title: Imaginary Crimes (1994) Average Rating: 3.357142857142857
#
# Movie Title: Rancho Deluxe (1975) Average Rating: 3.3958333333333335
#
# Movie Title: Pledge, The (2001) Average Rating: 3.319954128440367
#
# Movie Title: Personals, The (Zheng hun qi shi) (1998) Average Rating: 3.3333333333333335
#
# Movie Title: Mystic Pizza (1988) Average Rating: 3.313651591289782
#
# Movie Title: Coffy (1973) Average Rating: 3.32
#
# Movie Title: Amy (1998) Average Rating: 3.22
#
# Movie Title: Faithless (Trolösa) (2000) Average Rating: 3.2142857142857144
#
# Movie Title: Legend of Rita, The (Die Stille nach dem Schuß) (1999) Average Rating: 3.265957446808511
#
# Movie Title: Amazing Grace and Chuck (1987) Average Rating: 3.253012048192771
#
# Movie Title: Amazon Women on the Moon (1987) Average Rating: 3.2652091254752853
#
# Movie Title: Barfly (1987) Average Rating: 3.3769574944071588
#
# Movie Title: Best Seller (1987) Average Rating: 3.3013698630136985
#
# Movie Title: Brave Little Toaster, The (1987) Average Rating: 3.327285921625544
#
# Movie Title: Dogs in Space (1987) Average Rating: 3.3333333333333335
#
# Movie Title: Family Viewing (1987) Average Rating: 3.232142857142857
#
# Movie Title: Five Corners (1987) Average Rating: 3.2540983606557377
#
# Movie Title: Fourth Protocol, The (1987) Average Rating: 3.245
#
# Movie Title: Gardens of Stone (1987) Average Rating: 3.3698630136986303
#
# Movie Title: Good Morning, Babylon (1987) Average Rating: 3.232142857142857
#
# Movie Title: Innerspace (1987) Average Rating: 3.251286449399657
#
# Movie Title: No Man's Land (1987) Average Rating: 3.207317073170732
#
# Movie Title: Vatel (2000) Average Rating: 3.4
#
# Movie Title: Madadayo (a.k.a. Not Yet) (1993) Average Rating: 3.340909090909091
#
# Movie Title: Elvis: That's the Way It Is (1970) Average Rating: 3.25
#
# Movie Title: Greatest Story Ever Told, The (1965) Average Rating: 3.3233082706766917
#
# Movie Title: Unmade Beds (1997) Average Rating: 3.370967741935484
#
# Movie Title: Keep the River on Your Right: A Modern Cannibal Tale (2000) Average Rating: 3.3719512195121952
#
# Movie Title: Along Came a Spider (2001) Average Rating: 3.268561872909699
#
# Movie Title: Cleopatra (1963) Average Rating: 3.366883116883117
#
# Movie Title: True Believer (1989) Average Rating: 3.3666666666666667
#
# Movie Title: City of Women, The (La Città delle Donne) (1980) Average Rating: 3.201492537313433
#
# Movie Title: Nine to Five (a.k.a. 9 to 5) (1980) Average Rating: 3.2629382303839733
#
# Movie Title: Knight's Tale, A (2001) Average Rating: 3.212885154061625
#
# Movie Title: Calle 54 (2000) Average Rating: 3.2888888888888888
#
# Movie Title: Sordid Lives (2000) Average Rating: 3.35
#
# Movie Title: Postcards From the Edge (1990) Average Rating: 3.232484076433121
#
# Movie Title: Apache (1954) Average Rating: 3.2625
#
# Movie Title: City Slickers (1991) Average Rating: 3.3512385568120626
#
# Movie Title: Kentuckian, The (1955) Average Rating: 3.3333333333333335
#
# Movie Title: Midnight Madness (1980) Average Rating: 3.209090909090909
#
# Movie Title: Whatever Happened to Harold Smith? (1999) Average Rating: 3.3947368421052633
#
# Movie Title: Point Break (1991) Average Rating: 3.2585101134681795
#
# Movie Title: There's No Business Like Show Business (1954) Average Rating: 3.382978723404255
#
# Movie Title: Too Late the Hero (1970) Average Rating: 3.289473684210526
#
# Movie Title: Pavilion of Women (2000) Average Rating: 3.2
#
# Movie Title: Adventures of Felix, The (a.k.a. Funny Felix) (Drôle de Félix) (2000) Average Rating: 3.310810810810811
#
# Movie Title: Kiss of the Dragon (2001) Average Rating: 3.2277397260273974
#
# Movie Title: Lost and Delirious (2001) Average Rating: 3.306547619047619
#
# Movie Title: Fall of the House of Usher, The (House of Usher) (1960) Average Rating: 3.343137254901961
#
# Movie Title: X: The Man with the X-Ray Eyes (1963) Average Rating: 3.28125
#
# Movie Title: Barefoot Contessa, The (1954) Average Rating: 3.395
#
# Movie Title: 10th Victim, The (La Decima Vittima) (1965) Average Rating: 3.3666666666666667
#
# Movie Title: Colonel Redl (Oberst Redl) (1985) Average Rating: 3.3448275862068964
#
# Movie Title: Game of Death (1978) Average Rating: 3.273049645390071
#
# Movie Title: Outland (1981) Average Rating: 3.3855721393034828
#
# Movie Title: Legally Blonde (2001) Average Rating: 3.222041006523765
#
# Movie Title: Bully (2001) Average Rating: 3.3820224719101124
#
# Movie Title: Made (2001) Average Rating: 3.2454545454545456
#
# Movie Title: Appointment with Death (1988) Average Rating: 3.2111111111111112
#
# Movie Title: Bat*21 (1988) Average Rating: 3.3248730964467006
#
# Movie Title: Biloxi Blues (1988) Average Rating: 3.35790273556231
#
# Movie Title: Clean and Sober (1988) Average Rating: 3.364406779661017
#
# Movie Title: Colors (1988) Average Rating: 3.3751974723538702
#
# Movie Title: D.O.A. (1988) Average Rating: 3.2110481586402266
#
# Movie Title: Frantic (1988) Average Rating: 3.374340949033392
#
# Movie Title: Great Outdoors, The (1988) Average Rating: 3.2
#
# Movie Title: Land Before Time, The (1988) Average Rating: 3.209726443768997
#
# Movie Title: Masquerade (1988) Average Rating: 3.2880434782608696
#
# Movie Title: Return of the Living Dead, The (1985) Average Rating: 3.289285714285714
#
# Movie Title: Return to Snowy River (a.k.a. The Man From Snowy River II) (1988) Average Rating: 3.2546583850931676
#
# Movie Title: Rocket Gibraltar (1988) Average Rating: 3.358974358974359
#
# Movie Title: Shoot to Kill (1988) Average Rating: 3.2848484848484847
#
# Movie Title: Always (1989) Average Rating: 3.2612540192926045
#
# Movie Title: Big Picture, The (1989) Average Rating: 3.3386243386243386
#
# Movie Title: Bill & Ted's Excellent Adventure (1989) Average Rating: 3.3608319700864686
#
# Movie Title: Breaking In (1989) Average Rating: 3.2333333333333334
#
# Movie Title: Casualties of War (1989) Average Rating: 3.344110854503464
#
# Movie Title: Dad (1989) Average Rating: 3.2846153846153845
#
# Movie Title: Erik the Viking (1989) Average Rating: 3.3203125
#
# Movie Title: In Country (1989) Average Rating: 3.240740740740741
#
# Movie Title: Jacknife (1989) Average Rating: 3.3636363636363638
#
# Movie Title: Let It Ride (1989) Average Rating: 3.2532894736842106
#
# Movie Title: Meet the Feebles (1989) Average Rating: 3.353131749460043
#
# Movie Title: Miss Firecracker (1989) Average Rating: 3.224
#
# Movie Title: New York Stories (1989) Average Rating: 3.316622691292876
#
# Movie Title: Penn & Teller Get Killed (1989) Average Rating: 3.2954545454545454
#
# Movie Title: Cure (1997) Average Rating: 3.393805309734513
#
# Movie Title: Wet Hot American Summer (2001) Average Rating: 3.3225388601036268
#
# Movie Title: Scandal (1989) Average Rating: 3.26171875
#
# Movie Title: Sweetie (1989) Average Rating: 3.2155172413793105
#
# Movie Title: Tall Guy, The (1989) Average Rating: 3.334070796460177
#
# Movie Title: Uncle Buck (1989) Average Rating: 3.2400145243282497
#
# Movie Title: Rush Hour 2 (2001) Average Rating: 3.2537443399512367
#
# Movie Title: Paint Your Wagon (1969) Average Rating: 3.2507082152974505
#
# Movie Title: Bad Timing: A Sensual Obsession (1980) Average Rating: 3.2291666666666665
#
# ...
#
# Movie Title: Duck Season (Temporada de patos) (2004) Average Rating: 3.4
#
# Movie Title: Revolver (2005) Average Rating: 3.2435064935064934
#
# Movie Title: Match Factory Girl, The (Tulitikkutehtaan tyttö) (1990) Average Rating: 3.2916666666666665
#
# Movie Title: Sarah Silverman: Jesus Is Magic (2005) Average Rating: 3.3725961538461537
#
# Movie Title: Good Woman, A (2004) Average Rating: 3.346774193548387
#
# Movie Title: Kiss of Death (1947) Average Rating: 3.3555555555555556
#
# Movie Title: Casanova (2005) Average Rating: 3.2302631578947367
#
# Movie Title: 7 Faces of Dr. Lao (1964) Average Rating: 3.25
#
# Movie Title: 49th Parallel (1941) Average Rating: 3.25
#
# Movie Title: Tristan & Isolde (2006) Average Rating: 3.271505376344086
#
# Movie Title: Last Holiday (2006) Average Rating: 3.3055555555555554
#
# Movie Title: Hoodwinked (2006) Average Rating: 3.237762237762238
#
# Movie Title: Underworld: Evolution (2006) Average Rating: 3.2514792899408285
#
# Movie Title: Nanny McPhee (2005) Average Rating: 3.3819444444444446
#
# Movie Title: Something New (2006) Average Rating: 3.310126582278481
#
# Movie Title: Imagine Me & You (2005) Average Rating: 3.2411764705882353
#
# Movie Title: Neil Young: Heart of Gold (2006) Average Rating: 3.376923076923077
#
# Movie Title: Winter Passing (2005) Average Rating: 3.234375
#
# Movie Title: 16 Blocks (2006) Average Rating: 3.2855855855855856
#
# Movie Title: Ice Age 2: The Meltdown (2006) Average Rating: 3.314497716894977
#
# Movie Title: Find Me Guilty (2006) Average Rating: 3.387323943661972
#
# Movie Title: Unknown White Male (2005) Average Rating: 3.2045454545454546
#
# Movie Title: Take the Lead (2006) Average Rating: 3.2130434782608694
#
# Movie Title: Dead Birds (2004) Average Rating: 3.3333333333333335
#
# Movie Title: Prairie Home Companion, A (2006) Average Rating: 3.3297872340425534
#
# Movie Title: Mission: Impossible III (2006) Average Rating: 3.3044
#
# Movie Title: Down in the Valley (2005) Average Rating: 3.21875
#
# Movie Title: X-Men: The Last Stand (2006) Average Rating: 3.384128926968584
#
# Movie Title: Peaceful Warrior (2006) Average Rating: 3.347826086956522
#
# Movie Title: Notorious Bettie Page, The (2005) Average Rating: 3.234042553191489
#
# Movie Title: Lake House, The (2006) Average Rating: 3.3125
#
# Movie Title: Seventh Victim, The (1943) Average Rating: 3.210526315789474
#
# Movie Title: Devil Wears Prada, The (2006) Average Rating: 3.389883616830797
#
# Movie Title: Marie Antoinette (2006) Average Rating: 3.2144444444444447
#
# Movie Title: Superman Returns (2006) Average Rating: 3.2091315453384417
#
# Movie Title: Edmond (2005) Average Rating: 3.2260273972602738
#
# Movie Title: End of the Spear (2005) Average Rating: 3.378787878787879
#
# Movie Title: Monster House (2006) Average Rating: 3.384130982367758
#
# Movie Title: Tears of the Black Tiger (Fah talai jone) (2000) Average Rating: 3.375
#
# Movie Title: Crank (2006) Average Rating: 3.393796992481203
#
# Movie Title: Step Up (2006) Average Rating: 3.3
#
# Movie Title: La Moustache (2005) Average Rating: 3.2241379310344827
#
# Movie Title: Tideland (2005) Average Rating: 3.324
#
# Movie Title: Accepted (2006) Average Rating: 3.2642140468227425
#
# Movie Title: Puffy Chair, The (2006) Average Rating: 3.21875
#
# Movie Title: Sketches of Frank Gehry (2005) Average Rating: 3.3333333333333335
#
# Movie Title: Jesse James (1939) Average Rating: 3.283333333333333
#
# Movie Title: Last Kiss, The (2006) Average Rating: 3.2181069958847734
#
# Movie Title: SherryBaby (2006) Average Rating: 3.3160919540229883
#
# Movie Title: Idiocracy (2006) Average Rating: 3.269455252918288
#
# Movie Title: Snoopy Come Home (1972) Average Rating: 3.3658536585365852
#
# Movie Title: Gridiron Gang (2006) Average Rating: 3.297029702970297
#
# Movie Title: Flyboys (2006) Average Rating: 3.2576923076923077
#
# Movie Title: Jackass Number Two (2006) Average Rating: 3.223946784922395
#
# Movie Title: Conversations with Other Women (2005) Average Rating: 3.3870967741935485
#
# Movie Title: Guardian, The (2006) Average Rating: 3.3588516746411483
#
# Movie Title: Feast (2005) Average Rating: 3.3734939759036147
#
# Movie Title: Facing the Giants (2006) Average Rating: 3.236842105263158
#
# Movie Title: Guide to Recognizing Your Saints, A (2006) Average Rating: 3.3793103448275863
#
# Movie Title: 5 Fingers (1952) Average Rating: 3.3076923076923075
#
# Movie Title: Arabesque (1966) Average Rating: 3.289473684210526
#
# Movie Title: Good Year, A (2006) Average Rating: 3.260355029585799
#
# Movie Title: Fuck (2005) Average Rating: 3.3815789473684212
#
# Movie Title: Happy Feet (2006) Average Rating: 3.2304832713754648
#
# Movie Title: Holiday, The (2006) Average Rating: 3.3745247148288975
#
# Movie Title: Tenacious D in The Pick of Destiny (2006) Average Rating: 3.257575757575758
#
# Movie Title: Nativity Story, The (2006) Average Rating: 3.3773584905660377
#
# Movie Title: Off the Black (2006) Average Rating: 3.2
#
# Movie Title: Charlotte's Web (2006) Average Rating: 3.3721804511278197
#
# Movie Title: Rocky Balboa (2006) Average Rating: 3.3262711864406778
#
# Movie Title: Fur: An Imaginary Portrait of Diane Arbus (2006) Average Rating: 3.22972972972973
#
# Movie Title: Dreamgirls (2006) Average Rating: 3.2693333333333334
#
# Movie Title: Page Turner, The (Tourneuse de pages, La) (2006) Average Rating: 3.375
#
# Movie Title: Curse of the Golden Flower (Man cheng jin dai huang jin jia) (2006) Average Rating: 3.3851674641148324
#
# Movie Title: Rosario Tijeras (2005) Average Rating: 3.375
#
# Movie Title: Little World of Don Camillo, The (Le Petit monde de Don Camillo) (1953) Average Rating: 3.289473684210526
#
# Movie Title: Daisies (Sedmikrasky) (1966) Average Rating: 3.4
#
# Movie Title: Mafioso (1962) Average Rating: 3.375
#
# Movie Title: Music and Lyrics (2007) Average Rating: 3.273026315789474
#
# Movie Title: Next (2007) Average Rating: 3.20625
#
# Movie Title: Breaking and Entering (2006) Average Rating: 3.2473684210526317
#
# Movie Title: Westerner, The (1940) Average Rating: 3.3055555555555554
#
# Movie Title: Last Mimzy, The (2007) Average Rating: 3.3757225433526012
#
# Movie Title: Becoming Jane (2007) Average Rating: 3.3392857142857144
#
# Movie Title: Pride (2007) Average Rating: 3.388888888888889
#
# Movie Title: Avenue Montaigne (Fauteuils d'orchestre) (2006) Average Rating: 3.272727272727273
#
# Movie Title: Blades of Glory (2007) Average Rating: 3.24459234608985
#
# Movie Title: Seraphim Falls (2006) Average Rating: 3.3461538461538463
#
# Movie Title: Hoax, The (2007) Average Rating: 3.3506493506493507
#
# Movie Title: Ulysses' Gaze (To Vlemma tou Odyssea) (1995) Average Rating: 3.2
#
# Movie Title: Goya's Ghosts (2006) Average Rating: 3.2976190476190474
#
# Movie Title: Disturbia (2007) Average Rating: 3.27027027027027
#
# Movie Title: Aqua Teen Hunger Force Colon Movie Film for Theaters (2007) Average Rating: 3.3008849557522124
#
# Movie Title: Big Nothing (2006) Average Rating: 3.202127659574468
#
# Movie Title: In the Land of Women (2007) Average Rating: 3.3012048192771086
#
# Movie Title: Day Watch (Dnevnoy dozor) (2006) Average Rating: 3.3652482269503547
#
# Movie Title: Pirates of the Caribbean: At World's End (2007) Average Rating: 3.3253638253638256
#
# Movie Title: Paranoid Park (2007) Average Rating: 3.260204081632653
#
# Movie Title: Iceberg, L' (2005) Average Rating: 3.25
#
# Movie Title: TV Set, The (2006) Average Rating: 3.3333333333333335
#
# Movie Title: Night of the Generals, The (1967) Average Rating: 3.375
#
# Movie Title: Mighty Heart, A (2007) Average Rating: 3.237623762376238
#
# Movie Title: 1408 (2007) Average Rating: 3.205769230769231
#
# Movie Title: Driving Lessons (2006) Average Rating: 3.3658536585365852
#
# Movie Title: My Best Friend (Mon meilleur ami) (2006) Average Rating: 3.3095238095238093
#
# Movie Title: Czech Dream (Ceský sen) (2004) Average Rating: 3.375
#
# Movie Title: Joshua (2007) Average Rating: 3.2666666666666666
#
# Movie Title: Resurrecting the Champ (2007) Average Rating: 3.3513513513513513
#
# Movie Title: 2 Days in Paris (2007) Average Rating: 3.3392857142857144
#
# Movie Title: Nines, The (2007) Average Rating: 3.336448598130841
#
# Movie Title: Shoot 'Em Up (2007) Average Rating: 3.2732426303854876
#
# Movie Title: Brave One, The (2007) Average Rating: 3.3394736842105264
#
# Movie Title: December Boys (2007) Average Rating: 3.3125
#
# Movie Title: Hunting Party, The (2007) Average Rating: 3.396551724137931
#
# Movie Title: Stephanie Daley (2006) Average Rating: 3.227272727272727
#
# Movie Title: We Own the Night (2007) Average Rating: 3.25
#
# Movie Title: Sleuth (2007) Average Rating: 3.310344827586207
#
# Movie Title: Rendition (2007) Average Rating: 3.342857142857143
#
# Movie Title: Reservation Road (2007) Average Rating: 3.349056603773585
#
# Movie Title: Beaufort (2007) Average Rating: 3.4
#
# Movie Title: I'm Reed Fish (2006) Average Rating: 3.3333333333333335
#
# Movie Title: Jane Austen Book Club, The (2007) Average Rating: 3.3990384615384617
#
# Movie Title: Mary, Queen of Scots (1971) Average Rating: 3.4
#
# Movie Title: King of California (2007) Average Rating: 3.235632183908046
#
# Movie Title: Be Kind Rewind (2008) Average Rating: 3.315673289183223
#
# Movie Title: Itty Bitty Titty Committee (2007) Average Rating: 3.2
#
# Movie Title: Mr. Magorium's Wonder Emporium (2007) Average Rating: 3.2948717948717947
#
# Movie Title: Golden Compass, The (2007) Average Rating: 3.2427797833935017
#
# Movie Title: My Blueberry Nights (2007) Average Rating: 3.36734693877551
#
# Movie Title: National Treasure: Book of Secrets (2007) Average Rating: 3.2303030303030305
#
# Movie Title: Walk Hard: The Dewey Cox Story (2007) Average Rating: 3.275
#
# Movie Title: Water Horse: Legend of the Deep, The (2007) Average Rating: 3.232876712328767
#
# Movie Title: P.S. I Love You (2007) Average Rating: 3.356353591160221
#
# Movie Title: Cassandra's Dream (2007) Average Rating: 3.2755102040816326
#
# Movie Title: Cheyenne Social Club, The (1970) Average Rating: 3.238095238095238
#
# Movie Title: 3 Bad Men (1926) Average Rating: 3.4
#
# Movie Title: Heaven and Earth (Ten to Chi to) (1990) Average Rating: 3.25
#
# Movie Title: Rambo (2008) Average Rating: 3.362533692722372
#
# Movie Title: Canvas (2006) Average Rating: 3.4
#
# Movie Title: Vantage Point (2008) Average Rating: 3.2785326086956523
#
# Movie Title: Other Boleyn Girl, The (2008) Average Rating: 3.3698979591836733
#
# Movie Title: Run Fatboy Run (2007) Average Rating: 3.3289473684210527
#
# Movie Title: Grace Is Gone (2007) Average Rating: 3.2777777777777777
#
# Movie Title: Hallam Foe (Mister Foe) (2007) Average Rating: 3.3783783783783785
#
# Movie Title: Zeitgeist: The Movie (2007) Average Rating: 3.2333333333333334
#
# Movie Title: Jellyfish (Meduzot) (2007) Average Rating: 3.2777777777777777
#
# Movie Title: Snow Angels (2007) Average Rating: 3.3260869565217392
#
# Movie Title: CJ7 (Cheung Gong 7 hou) (2008) Average Rating: 3.2666666666666666
#
# Movie Title: 21 (2008) Average Rating: 3.3942528735632185
#
# Movie Title: Stop-Loss (2008) Average Rating: 3.262295081967213
#
# Movie Title: Aerial, The (La Antena) (2007) Average Rating: 3.375
#
# Movie Title: Street Kings (2008) Average Rating: 3.386986301369863
#
# Movie Title: Harold & Kumar Escape from Guantanamo Bay (2008) Average Rating: 3.324561403508772
#
# Movie Title: Speed Racer (2008) Average Rating: 3.2906976744186047
#
# Movie Title: Where in the World Is Osama Bin Laden? (2008) Average Rating: 3.2096774193548385
#
# Movie Title: Life Before Her Eyes, The (2007) Average Rating: 3.323529411764706
#
# Movie Title: Super High Me (2007) Average Rating: 3.375
#
# Movie Title: Black Friday (1940) Average Rating: 3.3333333333333335
#
# Movie Title: Bella (2006) Average Rating: 3.357142857142857
#
# Movie Title: Reprise (2006) Average Rating: 3.3684210526315788
#
# Movie Title: Girl Next Door, The (2007) Average Rating: 3.2837837837837838
#
# Movie Title: Wings of Eagles, The (1957) Average Rating: 3.25
#
# Movie Title: And When Did You Last See Your Father? (2007) Average Rating: 3.282608695652174
#
# Movie Title: My Brother is an Only Child (Mio fratello è figlio unico) (2006) Average Rating: 3.3666666666666667
#
# Movie Title: Wanted (2008) Average Rating: 3.3158953722334004
#
# Movie Title: Hancock (2008) Average Rating: 3.283739837398374
#
# Movie Title: Get Smart (2008) Average Rating: 3.3200992555831266
#
# Movie Title: Brick Lane (2007) Average Rating: 3.25
#
# Movie Title: Surfwise (2007) Average Rating: 3.35
#
# Movie Title: Roman de gare (2007) Average Rating: 3.3636363636363638
#
# Movie Title: Standard Operating Procedure (2008) Average Rating: 3.272727272727273
#
# Movie Title: Battle for Haditha (2007) Average Rating: 3.2142857142857144
#
# Movie Title: Mamma Mia! (2008) Average Rating: 3.393258426966292
#
# Movie Title: Kabluey (2007) Average Rating: 3.3
#
# Movie Title: Water Lilies (Naissance des pieuvres) (2007) Average Rating: 3.3333333333333335
#
# Movie Title: Transsiberian (2008) Average Rating: 3.35
#
# Movie Title: Step Brothers (2008) Average Rating: 3.315642458100559
#
# Movie Title: Brideshead Revisited (2008) Average Rating: 3.375
#
# Movie Title: American Teen (2008) Average Rating: 3.275
#
# Movie Title: Expired (2007) Average Rating: 3.25
#
# Movie Title: Rocker, The (2008) Average Rating: 3.25
#
# Movie Title: Sukiyaki Western Django (2008) Average Rating: 3.3448275862068964
#
# Movie Title: Half Life of Timofey Berezin, The (PU-239) (2006) Average Rating: 3.25
#
# Movie Title: Shadows in Paradise (Varjoja paratiisissa) (1986) Average Rating: 3.3
#
# Movie Title: Sawdust and Tinsel (Gycklarnas afton) (1953) Average Rating: 3.3333333333333335
#
# Movie Title: On the Beach (2000) Average Rating: 3.3636363636363638
#
# Movie Title: Eagle Eye (2008) Average Rating: 3.3345588235294117
#
# Movie Title: Martyrs (2008) Average Rating: 3.25
#
# Movie Title: Magicians (2007) Average Rating: 3.25
#
# Movie Title: Synecdoche, New York (2008) Average Rating: 3.296875
#
# Movie Title: Secret Life of Bees, The (2008) Average Rating: 3.3181818181818183
#
# Movie Title: Niko & The Way to the Stars (Niko - Lentäjän poika) (2008) Average Rating: 3.25
#
# Movie Title: Express, The (2008) Average Rating: 3.3333333333333335
#
# Movie Title: Into The West (2005) Average Rating: 3.25
#
# Movie Title: Madagascar: Escape 2 Africa (2008) Average Rating: 3.3055555555555554
#
# Movie Title: Tale of Two Cities, A (1958) Average Rating: 3.2142857142857144
#
# Movie Title: Kozara (1962) Average Rating: 3.25
#
# Movie Title: Caótica Ana (2007) Average Rating: 3.25
#
# Movie Title: Soul Men (2008) Average Rating: 3.25
#
# Movie Title: Australia (2008) Average Rating: 3.289473684210526
#
# Movie Title: Devil Doll, The (1936) Average Rating: 3.3
#
# Movie Title: Twilight (2008) Average Rating: 3.3114754098360657
#
# Movie Title: Boy in the Striped Pyjamas, The (2008) Average Rating: 3.2777777777777777
#
# Movie Title: Punisher: War Zone (2008) Average Rating: 3.3
#
# Movie Title: Four Men and a Prayer (1938) Average Rating: 3.25
#
# Movie Title: Boomerang (1947) Average Rating: 3.375
#
# Movie Title: I've Loved You So Long (Il y a longtemps que je t'aime) (2008) Average Rating: 3.2
#
# Movie Title: Little Giant, The (1933) Average Rating: 3.25
#
# Movie Title: Nazis Strike, The (Why We Fight, 2) (1943) Average Rating: 3.25
#
# Movie Title: Arabian Nights (1942) Average Rating: 3.25
#
# Movie Title: Birds of America (2008) Average Rating: 3.3333333333333335
#
# Movie Title: 5 Centimeters per Second (Byôsoku 5 senchimêtoru) (2007) Average Rating: 3.25
#
# Movie Title: Blackadder Back & Forth (1999) Average Rating: 3.357142857142857
#
#
# Choose
#
#  1) rating T1 T2: find all movies with rating between T1 and T2
#
#  2) top_movies K: find all movies with rating over K
#
#  3) user_pairs K: find all user pairs that have given rating to the same movie
#
#  4) dominance: find users that aren't dominated from other movies
#
#  5) iceberg K T: find movies that have been rated at least K times with average score over T
#
#  6) top_user K: find the K users that have rated the most movies
#
#  7) movie_sample S: find a percentage of movies from all categories
#
#  8) similar_users Θ: find users that have similar tastes in movies based on cosine similarity
#
#  9) S to stop
