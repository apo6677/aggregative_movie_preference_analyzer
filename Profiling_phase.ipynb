# %%
# %%file prof_phase.py
import math
import random
from memory_profiler import profile
import gc

###################################################################################################################################################################################
###-----------------------------------------------------------------------------------RATING ---------------------------------------------------------------------------------
###################################################################################################################################################################################
@profile
def find_movies_between_T1_T2(T1, T2):
    filtered_ratings = dict()
    average_ratings = dict()
    movies = dict()

    with open("movies.dat","r", encoding="utf-8") as Mov:
        for line in Mov:
            data = line.strip().split('::')

            MovieID = data[0]
            Title = data[1]
            
            movies[MovieID] = Title

    with open("ratings.dat","r") as ratings:
        for line in ratings:
            data = line.strip().split('::')

            MovieID = data[1]
            Rating = float(data[2])
            
            if MovieID in average_ratings:
                average_ratings[MovieID]['Total_Rating'] +=Rating
                average_ratings[MovieID]['Count'] += 1
            else:
                average_ratings[MovieID] = {'Total_Rating': Rating, 'Count': 1}

    for MovieID in movies:
        if MovieID in average_ratings.keys():
            Title = movies[MovieID]
            average_rating = average_ratings[MovieID]['Total_Rating']/average_ratings[MovieID]['Count']
            if T1 <= average_rating <= T2:
                filtered_ratings[Title] = average_rating

    for Title in filtered_ratings:
        print("Movie Title:", Title, "Average Rating:", filtered_ratings[Title], "\n")
    
    gc.collect

###################################################################################################################################################################################
###-----------------------------------------------------------------------------------TOP MOVIES ---------------------------------------------------------------------------------
###################################################################################################################################################################################
@profile
def find_top_movies(K):

    filtered_ratings = dict()
    average_ratings = dict()
    movies = dict()

    with open("movies.dat","r", encoding="utf-8") as Mov:
        for line in Mov:
            data = line.strip().split('::')

            MovieID = data[0]
            Title = data[1]
            
            movies[MovieID] = Title

    with open("ratings.dat","r") as ratings:
        for line in ratings:
            data = line.strip().split('::')

            MovieID = data[1]
            Rating = float(data[2])
            
            if MovieID in average_ratings:
                average_ratings[MovieID]['Total_Rating'] +=Rating
                average_ratings[MovieID]['Count'] += 1
            else:
                average_ratings[MovieID] = {'Total_Rating': Rating, 'Count': 1}
        
    for MovieID in movies:
        if MovieID in average_ratings.keys():
            Title = movies[MovieID]
            average_rating = average_ratings[MovieID]['Total_Rating']/average_ratings[MovieID]['Count']
            filtered_ratings[Title] = average_rating

    sorted_ratings = sorted(filtered_ratings.items(), key=lambda x: x[1], reverse=True)

    top_K_movies = sorted_ratings[:K]
    
    for Title, Average_Rating in top_K_movies:
        print("Movie Title:", Title, "Average Rating:", Average_Rating, "\n")
    gc.collect

###################################################################################################################################################################################
###-----------------------------------------------------------------------------------USER PAIRS ---------------------------------------------------------------------------------
###################################################################################################################################################################################
@profile
def find_user_pairs(K):
    user_pairs = dict()
    filtered_pairs = dict()
    movies = dict()
    MovieIds = []

    with open("movies.dat","r", encoding="utf-8") as Mov:
        for line in Mov:
            data = line.strip().split('::')

            MovieID = data[0]
            Title = data[1]
            
            movies[MovieID] = Title
            MovieIds.append(MovieID)


    with open("ratings.dat","r") as ratings:
        for line in ratings:
            data = line.strip().split('::')

            MovieID = data[1]
            UserID = data[0]
            
            if MovieID in user_pairs:
                if len(user_pairs[MovieID]) == 2:
                    continue;
                else:
                    user_pairs[MovieID].append(int(UserID))    
            else:
                user_pairs[MovieID] = [int(UserID)]

    chosen_movies = random.sample(MovieIds, min(K, len(MovieIds)))
  
    for MovieID in chosen_movies:
        if MovieID in user_pairs.keys():
            Title = movies[MovieID]
            filtered_pairs[Title] = user_pairs[MovieID]

    for Title in filtered_pairs:
        print("Movie Title:", Title, "Users:", filtered_pairs[Title], "\n")
    gc.collect

###################################################################################################################################################################################
###-----------------------------------------------------------------------------------ICEBERG ---------------------------------------------------------------------------------
###################################################################################################################################################################################
@profile
def iceberg(K,T):

    iceberg_movies = dict()
    filtered_movies = dict()
    movies = dict()

    with open("movies.dat","r", encoding="utf-8") as Mov:
        for line in Mov:
            data = line.strip().split('::')

            MovieID = data[0]
            Title = data[1]
            
            movies[MovieID] = Title


    with open("ratings.dat","r") as ratings:
        for line in ratings:
            data = line.strip().split('::')

            MovieID = data[1]
            Rating = float(data[2])
            
            if MovieID in iceberg_movies:
                iceberg_movies[MovieID]['Total_Rating'] +=Rating
                iceberg_movies[MovieID]['Count'] += 1   
            else:
                iceberg_movies[MovieID] = {'Movie': MovieID, 'Total_Rating': Rating, 'Count': 1}

  
    for MovieID in movies:
        if MovieID in iceberg_movies.keys():
            average_rating = iceberg_movies[MovieID]['Total_Rating']/iceberg_movies[MovieID]['Count']
            iceberg_movies[MovieID]['Total_Rating'] = average_rating
            if iceberg_movies[MovieID]['Count'] < K or average_rating < T:
                del iceberg_movies[MovieID]
            else:
                Title = movies[MovieID]
                filtered_movies[Title] = iceberg_movies[MovieID]

    for Title in filtered_movies:
        print("Movie Title:", Title, "Number of critics:", filtered_movies[Title]['Count'], "Average Rating:", filtered_movies[Title]['Total_Rating'], "\n")
    gc.collect

###################################################################################################################################################################################
###-----------------------------------------------------------------------------------TOP USER---------------------------------------------------------------------------------
###################################################################################################################################################################################
@profile
def top_users(K):
    users = dict()
   
    with open("ratings.dat","r") as ratings:
        for line in ratings:
            data = line.strip().split('::')

            UserID = data[0]
            
            if UserID in users:
                users[UserID]+=1    
            else:
                users[UserID] = 1

    sorted_users = sorted(users.items(), key=lambda x: x[1], reverse=True)


    top_K_users = sorted_users[:K]

    for UserID, Movies in top_K_users:
        print("User:", UserID, "Movies:", Movies, "\n")
    gc.collect
###################################################################################################################################################################################
###-----------------------------------------------------------------------------------MOVIE SAMPLE---------------------------------------------------------------------------------
###################################################################################################################################################################################

@profile
def movie_sample(S):
   movies = dict()
   categorised_movies = dict()

   with open("movies.dat","r", encoding="utf-8") as Mov:
    for line in Mov:
        data = line.strip().split('::')

        Categories = data[2].split('|')
        Title = data[1]
            
        movies[Title] = Categories

    for Title in movies:
        for Category in movies[Title]:
            if  Category in categorised_movies.keys():
                categorised_movies[Category].append(Title)
            else: categorised_movies[Category] = [Title]

    for Category in categorised_movies:
        size = math.ceil(int((S/100)*len(categorised_movies[Category])))
        categorised_movies[Category] = categorised_movies[Category][:size]
        print("Category:", Category, "Movies:", categorised_movies[Category], "\n")
    gc.collect

###################################################################################################################################################################################
###-----------------------------------------------------------------------------------COSINE SIMILARITY---------------------------------------------------------------------------------
###################################################################################################################################################################################
@profile
def cosine_similarity(Thetta):
    users_with_same_movies = dict()
    users = dict()
    user_movies = dict()
    cosine_users = dict()

    with open("ratings.dat","r") as ratings:
        for line in ratings:
            data = line.strip().split('::')

            UserID = data[0]
            MovieID = data[1]
            Rating = float(data[2])
            
            if UserID not in users:
                users[UserID] = []
            rating_entry = {MovieID: Rating}
            users[UserID].append(rating_entry)

            if UserID not in user_movies:
                user_movies[UserID] = []
            user_movies[UserID].append(MovieID)

    common_user_ids = list(set(users.keys()))
    selected_user_ids = random.sample(common_user_ids, 100)

    trimmed_users = {user_id: users[user_id] for user_id in selected_user_ids}
    trimmed_user_movies = {user_id: user_movies[user_id] for user_id in selected_user_ids}

    for UserID1 in trimmed_user_movies:
        for UserID2 in trimmed_user_movies:
            if UserID1 != UserID2: 
                common_movies = [movie for movie in trimmed_user_movies[UserID1] if movie in trimmed_user_movies[UserID2]]

                if len(common_movies) != 0:
                    if (UserID1, UserID2) not in users_with_same_movies:
                        if (UserID2, UserID1) not in users_with_same_movies:
                            users_with_same_movies[(UserID1, UserID2)] = []

                            for MovieID in common_movies:
                                users_with_same_movies[(UserID1, UserID2)].append(MovieID)
    

    for (UserID1, UserID2) in users_with_same_movies:
        cos_similar = 0
        sum_cos_sim_nominator = 0
        sum_cos_sim_denominator_user1 = 0
        sum_cos_sim_denominator_user2 = 0

        for MovieID in users_with_same_movies[(UserID1, UserID2)]:

            ratings_user1 = {list(movie.keys())[0]: list(movie.values())[0] for movie in trimmed_users[UserID1]}

            rating1 = 0
            for rating_entry in trimmed_users[UserID1]:
                rating1 = ratings_user1.get(MovieID, 0)

            ratings_user2 = {list(movie.keys())[0]: list(movie.values())[0] for movie in trimmed_users[UserID2]}

            rating2 = 0
            for rating_entry in trimmed_users[UserID2]:
                rating2 = ratings_user2.get(MovieID, 0)

            sum_cos_sim_nominator += rating1*rating2
            sum_cos_sim_denominator_user1 += rating1**2
            sum_cos_sim_denominator_user2 += rating2**2

        cos_similar = sum_cos_sim_nominator/(math.sqrt(sum_cos_sim_denominator_user1)*math.sqrt(sum_cos_sim_denominator_user2)) if (math.sqrt(sum_cos_sim_denominator_user1)*math.sqrt(sum_cos_sim_denominator_user2))!=0 else 0

        cosine_users[(UserID1, UserID2)] = cos_similar

    sorted_users = sorted(cosine_users.items(), key=lambda x: x[1], reverse=True)

    final_cosine_users = dict()
    for ((UserID1, UserID2), similarity) in sorted_users:
        if similarity >= Thetta:
            final_cosine_users[(UserID1, UserID2)] = similarity

    for (UserID1, UserID2) in final_cosine_users:
        print("Users:", UserID1, UserID2, "Cosine Similarity:", final_cosine_users[(UserID1, UserID2)], "\n")
    gc.collect
    
###################################################################################################################################################################################
###-----------------------------------------------------------------------------------DOMINANCE---------------------------------------------------------------------------------
###################################################################################################################################################################################
@profile
def dominance():
    movies_that_are_not_dominated = dict()
    average_ratings = dict()
    movies = dict()

    with open("movies.dat","r", encoding="utf-8") as Mov:
        for line in Mov:
            data = line.strip().split('::')

            MovieID = data[0]
            Title = data[1]
            
            movies[MovieID] = Title

    with open("ratings.dat","r") as ratings:
        for line in ratings:
            data = line.strip().split('::')

            MovieID = data[1]
            Rating = float(data[2])
            
            if MovieID in average_ratings:
                average_ratings[MovieID]['Total_Rating'] +=Rating
                average_ratings[MovieID]['Count'] += 1
            else:
                average_ratings[MovieID] = {'Total_Rating': Rating, 'Count': 1}

    for MovieID in movies:
        if MovieID in average_ratings.keys():
            Title = movies[MovieID]
            average_rating = average_ratings[MovieID]['Total_Rating']/average_ratings[MovieID]['Count']
            count = average_ratings[MovieID]['Count']
            movies_that_are_not_dominated[Title] = [count, average_rating]
            for MovieID2 in movies:
                if MovieID2!=MovieID:
                    if MovieID2 in average_ratings.keys():
                        average_rating2 = average_ratings[MovieID2]['Total_Rating']/average_ratings[MovieID2]['Count']
                        count2 = average_ratings[MovieID2]['Count']
                        if average_rating2 >= average_rating and count2>=count:
                            del movies_that_are_not_dominated[Title]
                            break;

    for Title in movies_that_are_not_dominated:
        count, average_rating = movies_that_are_not_dominated[Title]
        print("Movie Title:", Title, "Average Rating:", average_rating, "Total Votes:", count, "\n") 
    gc.collect   

###################################################################################################################################################################################
###-----------------------------------------------------------------------------------MAIN---------------------------------------------------------------------------------
###################################################################################################################################################################################
def main():
    a = 0
    b = 0
    c = 0
    d = 0
    e = 0
    f = 0
    g = 0
    h = 0
    mode = [0, 0, 0]
    while(True):
        print("\nChoose\n\n 1) rating T1 T2: find all movies with rating between T1 and T2\n\n 2) top_movies K: find all movies with rating over K \n\n 3) user_pairs K: find all user pairs that have given rating to the same movie\n\n\
    4) dominance: find users that aren't dominated from other movies\n\n 5) iceberg K T: find movies that have been rated at least K times with average score over T\n\n 6) top_user K: find the K users that have rated the most movies\n\n\
    7) movie_sample S: find a percentage of movies from all categories\n\n 8) similar_users Θ: find users that have similar tastes in movies based on cosine similarity\n\n 9) S to stop\n\n")

        if a == 0:
            mode[0] = "rating"
            mode[1] = "2.0"
            mode[2] = "2.2"
        elif b == 0:
            mode[0] = "top_movies"
            mode[1] = "10"
        elif c == 0:
            mode[0] = "user_pairs"
            mode[1] = "7"
        elif d == 0:
            mode[0] = "dominance"
        elif e == 0:
            mode[0] = "iceberg"
            mode[1] = "100"
            mode[2] = "4"
        elif f == 0:
            mode[0] = "top_user"
            mode[1] = "5"
        elif g == 0:
            mode[0] = "movie_sample"
            mode[1] = "20"
        elif h == 0:
            mode[0] = "similar_users"
            mode[1] = "0.9"
        else:
            mode[0] = "S"

        if mode[0] == "S":
            break;

        if mode[0] == "rating":
            find_movies_between_T1_T2(float(mode[1]), float(mode[2]))
            a=1
        elif mode[0] == "top_movies":
            find_top_movies(int(mode[1]))
            b=1
        elif mode[0]== "user_pairs":
            find_user_pairs(int(mode[1]))
            c=1
        elif mode[0]== "iceberg":
            iceberg(int(mode[1]), float(mode[2]))
            d=1
        elif mode[0]== "top_user":
            top_users(int(mode[1]))
            e=1
        elif mode[0]== "movie_sample":
            movie_sample(int(mode[1]))
            f=1
        elif mode[0]== "similar_users":
            cosine_similarity(float(mode[1]))
            g=1
        elif mode[0]== "dominance":
            dominance()
            h=1
        else : print("not a choice, choose again")

if __name__ == "__main__":
    main()
# Out:
# Overwriting prof_phase.py

# %%
# !python -m memory_profiler prof_phase.py
# Out:
# Choose
#
#  1) rating T1 T2: find all movies with rating between T1 and T2
#
#  2) top_movies K: find all movies with rating over K
#
#  3) user_pairs K: find all user pairs that have given rating to the same movie
#
#     4) dominance: find users that aren't dominated from other movies
#
#  5) iceberg K T: find movies that have been rated at least K times with average score over T
#
#  6) top_user K: find the K users that have rated the most movies
#
#     7) movie_sample S: find a percentage of movies from all categories
#
#  8) similar_users Θ: find users that have similar tastes in movies based on cosine similarity
#
#  9) S to stop
#
#
# Movie Title: Lawnmower Man 2: Beyond Cyberspace (1996) Average Rating: 2.132411067193676
#
# Movie Title: Beyond Bedlam (1993) Average Rating: 2.1160714285714284
#
# Movie Title: Nemesis 2: Nebula (1995) Average Rating: 2.108695652173913
#
# Movie Title: Fear, The (1995) Average Rating: 2.018181818181818
#
# Movie Title: Girl in the Cadillac (1995) Average Rating: 2.1875
#
# Movie Title: Two Crimes (Dos crímenes) (1995) Average Rating: 2.0555555555555554
#
# Movie Title: House Party 3 (1994) Average Rating: 2.175373134328358
#
# Movie Title: RoboCop 3 (1993) Average Rating: 2.1861480075901327
#
# Movie Title: Super Mario Bros. (1993) Average Rating: 2.0479274611398965
# Movie Title: Welcome Home, Roscoe Jenkins (2008) Average Rating: 2.130434782608696
#
# Movie Title: Klimt (2006) Average Rating: 2.05
#
# Movie Title: Fly Me to the Moon (2008) Average Rating: 2.0625
#
# Movie Title: 100 Feet (2008) Average Rating: 2.0
#
# Movie Title: Moonbase (1998) Average Rating: 2.0
#
# Movie Title: Alone In The Dark II (2008) Average Rating: 2.0833333333333335
#
# Movie Title: Fallout (1998) Average Rating: 2.0
#
# Movie Title: Rockin' in the Rockies (1945) Average Rating: 2.0
#
# Movie Title: Gold Raiders (1951) Average Rating: 2.0
#
# Movie Title: Dirty Dozen: The Deadly Mission (1987) Average Rating: 2.0
#
# Movie Title: Fireproof (2008) Average Rating: 2.0
#
# Movie Title: Guyver, The (1991) Average Rating: 2.0
#
# Movie Title: Ace of Hearts (2008) Average Rating: 2.0
#
# Movie Title: Delgo (2008) Average Rating: 2.0
#
# Movie Title: Double Dynamite (1951) Average Rating: 2.0
#
# Filename: prof_phase.py
#
# Line #    Mem usage    Increment  Occurrences   Line Contents
# =============================================================
#      9     50.1 MiB     50.1 MiB           1   @profile
#     10                                         def find_movies_between_T1_T2(T1, T2):
#     11     50.1 MiB      0.0 MiB           1       filtered_ratings = dict()
#     12     50.1 MiB      0.0 MiB           1       average_ratings = dict()
#     13     50.1 MiB      0.0 MiB           1       movies = dict()
#     14
#     15     50.1 MiB      0.0 MiB           1       with open("movies.dat","r", encoding="utf-8") as Mov:
#     16     51.9 MiB   -120.7 MiB       10682           for line in Mov:
#     17     51.9 MiB   -119.6 MiB       10681               data = line.strip().split('::')
#     18
#     19     51.9 MiB   -120.7 MiB       10681               MovieID = data[0]
#     20     51.9 MiB   -120.8 MiB       10681               Title = data[1]
#     21
#     22     51.9 MiB   -120.2 MiB       10681               movies[MovieID] = Title
#     23
#     24     51.9 MiB      0.0 MiB           1       with open("ratings.dat","r") as ratings:
#     25     55.6 MiB -252098798.3 MiB    10000055           for line in ratings:
#     26     55.6 MiB -252098607.2 MiB    10000054               data = line.strip().split('::')
#     27
#     28     55.6 MiB -252098774.8 MiB    10000054               MovieID = data[1]
#     29     55.6 MiB -252132169.8 MiB    10000054               Rating = float(data[2])
#     30
#     31     55.6 MiB -252132174.2 MiB    10000054               if MovieID in average_ratings:
#     32     55.6 MiB -252114235.6 MiB     9989377                   average_ratings[MovieID]['Total_Rating'] +=Rating
#     33     55.6 MiB -252114240.6 MiB     9989377                   average_ratings[MovieID]['Count'] += 1
#     34                                                     else:
#     35     55.6 MiB -17941.2 MiB       10677                   average_ratings[MovieID] = {'Total_Rating': Rating, 'Count': 1}
#     36
#     37     24.6 MiB    -32.0 MiB       10682       for MovieID in movies:
#     38     24.6 MiB      0.0 MiB       10681           if MovieID in average_ratings.keys():
#     39     24.6 MiB      0.9 MiB       10677               Title = movies[MovieID]
#     40     24.6 MiB      0.0 MiB       10677               average_rating = average_ratings[MovieID]['Total_Rating']/average_ratings[MovieID]['Count']
#     41     24.6 MiB      0.0 MiB       10677               if T1 <= average_rating <= T2:
#     42     24.6 MiB      0.1 MiB         272                   filtered_ratings[Title] = average_rating
#     43
#     44     24.7 MiB      0.0 MiB         273       for Title in filtered_ratings:
#     45     24.7 MiB      0.1 MiB         272           print("Movie Title:", Title, "Average Rating:", filtered_ratings[Title], "\n")
#     46
#     47     24.7 MiB      0.0 MiB           1       gc.collect
#
#
#
# Choose
#
#  1) rating T1 T2: find all movies with rating between T1 and T2
#
#  2) top_movies K: find all movies with rating over K
#
#  3) user_pairs K: find all user pairs that have given rating to the same movie
#
#     4) dominance: find users that aren't dominated from other movies
#
#  5) iceberg K T: find movies that have been rated at least K times with average score over T
#
#  6) top_user K: find the K users that have rated the most movies
#
#     7) movie_sample S: find a percentage of movies from all categories
#
#  8) similar_users Θ: find users that have similar tastes in movies based on cosine similarity
#
#  9) S to stop
#
#
# Movie Title: Satan's Tango (Sátántangó) (1994) Average Rating: 5.0
#
# Movie Title: Shadows of Forgotten Ancestors (1964) Average Rating: 5.0
#
# Movie Title: Fighting Elegy (Kenka erejii) (1966) Average Rating: 5.0
#
# Movie Title: Sun Alley (Sonnenallee) (1999) Average Rating: 5.0
#
# Movie Title: Blue Light, The (Das Blaue Licht) (1932) Average Rating: 5.0
#
# Movie Title: More (1998) Average Rating: 4.75
#
# Movie Title: Who's Singin' Over There? (a.k.a. Who Sings Over There) (Ko to tamo peva) (1980) Average Rating: 4.75
#
# Movie Title: Human Condition II, The (Ningen no joken II) (1959) Average Rating: 4.75
#
# Movie Title: Human Condition III, The (Ningen no joken III) (1961) Average Rating: 4.75
#
# Movie Title: Constantine's Sword (2007) Average Rating: 4.75
#
# Filename: prof_phase.py
#
# Line #    Mem usage    Increment  Occurrences   Line Contents
# =============================================================
#     52     27.2 MiB     27.2 MiB           1   @profile
#     53                                         def find_top_movies(K):
#     54
#     55     27.2 MiB      0.0 MiB           1       filtered_ratings = dict()
#     56     27.2 MiB      0.0 MiB           1       average_ratings = dict()
#     57     27.2 MiB      0.0 MiB           1       movies = dict()
#     58
#     59     27.3 MiB      0.1 MiB           1       with open("movies.dat","r", encoding="utf-8") as Mov:
#     60     28.2 MiB   -630.8 MiB       10682           for line in Mov:
#     61     28.2 MiB   -697.3 MiB       10681               data = line.strip().split('::')
#     62
#     63     28.2 MiB   -555.0 MiB       10681               MovieID = data[0]
#     64     28.2 MiB   -555.0 MiB       10681               Title = data[1]
#     65
#     66     28.2 MiB   -554.5 MiB       10681               movies[MovieID] = Title
#     67
#     68     28.3 MiB      0.1 MiB           1       with open("ratings.dat","r") as ratings:
#     69     31.8 MiB -69546542.2 MiB    10000055           for line in ratings:
#     70     31.8 MiB -69546561.3 MiB    10000054               data = line.strip().split('::')
#     71
#     72     31.8 MiB -69546558.5 MiB    10000054               MovieID = data[1]
#     73     31.8 MiB -69546560.7 MiB    10000054               Rating = float(data[2])
#     74
#     75     31.8 MiB -69546561.9 MiB    10000054               if MovieID in average_ratings:
#     76     31.8 MiB -69543568.4 MiB     9989377                   average_ratings[MovieID]['Total_Rating'] +=Rating
#     77     31.8 MiB -69543569.9 MiB     9989377                   average_ratings[MovieID]['Count'] += 1
#     78                                                     else:
#     79     31.8 MiB  -2992.6 MiB       10677                   average_ratings[MovieID] = {'Total_Rating': Rating, 'Count': 1}
#     80
#     81     24.0 MiB    -94.9 MiB       10682       for MovieID in movies:
#     82     24.0 MiB   -103.8 MiB       10681           if MovieID in average_ratings.keys():
#     83     24.0 MiB    -95.2 MiB       10677               Title = movies[MovieID]
#     84     24.0 MiB    -77.7 MiB       10677               average_rating = average_ratings[MovieID]['Total_Rating']/average_ratings[MovieID]['Count']
#     85     24.0 MiB    -80.2 MiB       10677               filtered_ratings[Title] = average_rating
#     86
#     87     25.0 MiB      1.0 MiB       21353       sorted_ratings = sorted(filtered_ratings.items(), key=lambda x: x[1], reverse=True)
#     88
#     89     25.0 MiB      0.0 MiB           1       top_K_movies = sorted_ratings[:K]
#     90
#     91     25.0 MiB      0.0 MiB          11       for Title, Average_Rating in top_K_movies:
#     92     25.0 MiB      0.0 MiB          10           print("Movie Title:", Title, "Average Rating:", Average_Rating, "\n")
#     93     25.0 MiB      0.0 MiB           1       gc.collect
#
#
#
# Choose
#
#  1) rating T1 T2: find all movies with rating between T1 and T2
#
#  2) top_movies K: find all movies with rating over K
#
#  3) user_pairs K: find all user pairs that have given rating to the same movie
#
#     4) dominance: find users that aren't dominated from other movies
#
#  5) iceberg K T: find movies that have been rated at least K times with average score over T
#
#  6) top_user K: find the K users that have rated the most movies
#
#     7) movie_sample S: find a percentage of movies from all categories
#
#  8) similar_users Θ: find users that have similar tastes in movies based on cosine similarity
#
#  9) S to stop
#
#
# Movie Title: Cypher (2002) Users: [8, 348]
#
# Movie Title: Space Truckers (1996) Users: [1741, 3116]
#
# Movie Title: Slaughterhouse (1987) Users: [2573, 2705]
#
# Movie Title: Glass Bottom Boat, The (1966) Users: [1088, 1906]
#
# Movie Title: Children Are Watching Us, The (Bambini ci guardano, I) (1944) Users: [322, 3652]
#
# Movie Title: Single Girl, A (La Fille Seule) (1995) Users: [215, 837]
#
# Movie Title: Castle, The (1997) Users: [8, 117]
#
# Filename: prof_phase.py
#
# Line #    Mem usage    Increment  Occurrences   Line Contents
# =============================================================
#     98     31.1 MiB     31.1 MiB           1   @profile
#     99                                         def find_user_pairs(K):
#    100     31.1 MiB      0.0 MiB           1       user_pairs = dict()
#    101     31.1 MiB      0.0 MiB           1       filtered_pairs = dict()
#    102     31.1 MiB      0.0 MiB           1       movies = dict()
#    103     31.1 MiB      0.0 MiB           1       MovieIds = []
#    104
#    105     31.1 MiB      0.0 MiB           1       with open("movies.dat","r", encoding="utf-8") as Mov:
#    106     31.2 MiB   -636.0 MiB       10682           for line in Mov:
#    107     31.2 MiB   -635.9 MiB       10681               data = line.strip().split('::')
#    108
#    109     31.2 MiB   -636.0 MiB       10681               MovieID = data[0]
#    110     31.2 MiB   -636.0 MiB       10681               Title = data[1]
#    111
#    112     31.2 MiB   -635.7 MiB       10681               movies[MovieID] = Title
#    113     31.2 MiB   -635.6 MiB       10681               MovieIds.append(MovieID)
#    114
#    115
#    116     31.1 MiB     -0.1 MiB           1       with open("ratings.dat","r") as ratings:
#    117     31.6 MiB -105870582.2 MiB    10000055           for line in ratings:
#    118     31.6 MiB -105870571.7 MiB    10000054               data = line.strip().split('::')
#    119
#    120     31.6 MiB -105870573.6 MiB    10000054               MovieID = data[1]
#    121     31.6 MiB -105870575.4 MiB    10000054               UserID = data[0]
#    122
#    123     31.6 MiB -105870577.5 MiB    10000054               if MovieID in user_pairs:
#    124     31.6 MiB -105861981.8 MiB     9989377                   if len(user_pairs[MovieID]) == 2:
#    125     31.6 MiB -105847535.9 MiB     9978800                       continue;
#    126                                                         else:
#    127     31.6 MiB -14447.5 MiB       10577                       user_pairs[MovieID].append(int(UserID))
#    128                                                     else:
#    129     31.6 MiB  -8597.1 MiB       10677                   user_pairs[MovieID] = [int(UserID)]
#    130
#    131     19.4 MiB    -12.2 MiB           1       chosen_movies = random.sample(MovieIds, min(K, len(MovieIds)))
#    132
#    133     19.5 MiB      0.0 MiB           8       for MovieID in chosen_movies:
#    134     19.5 MiB      0.0 MiB           7           if MovieID in user_pairs.keys():
#    135     19.5 MiB      0.1 MiB           7               Title = movies[MovieID]
#    136     19.5 MiB      0.0 MiB           7               filtered_pairs[Title] = user_pairs[MovieID]
#    137
#    138     19.6 MiB      0.0 MiB           8       for Title in filtered_pairs:
#    139     19.6 MiB      0.1 MiB           7           print("Movie Title:", Title, "Users:", filtered_pairs[Title], "\n")
#    140     19.6 MiB      0.0 MiB           1       gc.collect
#
#
#
# Choose
#
#  1) rating T1 T2: find all movies with rating between T1 and T2
#
#  2) top_movies K: find all movies with rating over K
#
#  3) user_pairs K: find all user pairs that have given rating to the same movie
#
#     4) dominance: find users that aren't dominated from other movies
#
#  5) iceberg K T: find movies that have been rated at least K times with average score over T
#
#  6) top_user K: find the K users that have rated the most movies
#
#     7) movie_sample S: find a percentage of movies from all categories
#
#  8) similar_users Θ: find users that have similar tastes in movies based on cosine similarity
#
#  9) S to stop
#
#
# Movie Title: Pulp Fiction (1994) Average Rating: 4.157425998164295 Total Votes: 34864
#
# Movie Title: Shawshank Redemption, The (1994) Average Rating: 4.457238321660348 Total Votes: 31126
#
# Movie Title: Silence of the Lambs, The (1991) Average Rating: 4.2041998336699535 Total Votes: 33668
#
# Movie Title: More (1998) Average Rating: 4.75 Total Votes: 8
#
# Movie Title: Satan's Tango (Sátántangó) (1994) Average Rating: 5.0 Total Votes: 2
#
# Filename: prof_phase.py
#
# Line #    Mem usage    Increment  Occurrences   Line Contents
# =============================================================
#    335     29.2 MiB     29.2 MiB           1   @profile
#    336                                         def dominance():
#    337     29.2 MiB      0.0 MiB           1       movies_that_are_not_dominated = dict()
#    338     29.2 MiB      0.0 MiB           1       average_ratings = dict()
#    339     29.2 MiB      0.0 MiB           1       movies = dict()
#    340
#    341     29.2 MiB      0.0 MiB           1       with open("movies.dat","r", encoding="utf-8") as Mov:
#    342     29.8 MiB  -3309.9 MiB       10682           for line in Mov:
#    343     29.8 MiB  -3309.5 MiB       10681               data = line.strip().split('::')
#    344
#    345     29.8 MiB  -3309.4 MiB       10681               MovieID = data[0]
#    346     29.8 MiB  -3309.5 MiB       10681               Title = data[1]
#    347
#    348     29.8 MiB  -3398.5 MiB       10681               movies[MovieID] = Title
#    349
#    350     29.4 MiB     -0.4 MiB           1       with open("ratings.dat","r") as ratings:
#    351     30.8 MiB -139550919.6 MiB    10000055           for line in ratings:
#    352     30.8 MiB -139550898.7 MiB    10000054               data = line.strip().split('::')
#    353
#    354     30.8 MiB -139550905.2 MiB    10000054               MovieID = data[1]
#    355     30.8 MiB -139550908.4 MiB    10000054               Rating = float(data[2])
#    356
#    357     30.8 MiB -139550912.0 MiB    10000054               if MovieID in average_ratings:
#    358     30.8 MiB -139542567.6 MiB     9989377                   average_ratings[MovieID]['Total_Rating'] +=Rating
#    359     30.8 MiB -139542570.5 MiB     9989377                   average_ratings[MovieID]['Count'] += 1
#    360                                                     else:
#    361     30.8 MiB  -8346.3 MiB       10677                   average_ratings[MovieID] = {'Total_Rating': Rating, 'Count': 1}
#    362
#    363      9.3 MiB    -23.4 MiB       10682       for MovieID in movies:
#    364      9.3 MiB      0.0 MiB       10681           if MovieID in average_ratings.keys():
#    365      9.3 MiB      0.8 MiB       10677               Title = movies[MovieID]
#    366      9.3 MiB      0.0 MiB       10677               average_rating = average_ratings[MovieID]['Total_Rating']/average_ratings[MovieID]['Count']
#    367      9.3 MiB      0.0 MiB       10677               count = average_ratings[MovieID]['Count']
#    368      9.3 MiB      0.0 MiB       10677               movies_that_are_not_dominated[Title] = [count, average_rating]
#    369      9.3 MiB      1.1 MiB      199633               for MovieID2 in movies:
#    370      9.3 MiB      0.0 MiB      199628                   if MovieID2!=MovieID:
#    371      9.3 MiB      0.0 MiB      199614                       if MovieID2 in average_ratings.keys():
#    372      9.3 MiB      0.0 MiB      199590                           average_rating2 = average_ratings[MovieID2]['Total_Rating']/average_ratings[MovieID2]['Count']
#    373      9.3 MiB      0.0 MiB      199590                           count2 = average_ratings[MovieID2]['Count']
#    374      9.3 MiB      0.0 MiB      199590                           if average_rating2 >= average_rating and count2>=count:
#    375      9.3 MiB      0.0 MiB       10672                               del movies_that_are_not_dominated[Title]
#
# Users: 34993 5523 Cosine Similarity: 0.9030856401442293
#
# Users: 56447 40163 Cosine Similarity: 0.9029750170417881
#
# Users: 52681 62667 Cosine Similarity: 0.9029252409583397
#
# Users: 54049 40163 Cosine Similarity: 0.9029151299664873
#
# Users: 65475 62667 Cosine Similarity: 0.9028684804268802
#
# Users: 32898 62667 Cosine Similarity: 0.9027579460006055
#
# Users: 31037 30278 Cosine Similarity: 0.902443867887612
#
# Users: 69528 5523 Cosine Similarity: 0.9023511590492995
#
# Users: 56193 47082 Cosine Similarity: 0.9023424467950961
#
# Users: 34993 31870 Cosine Similarity: 0.9022360631396091
#
# Users: 45776 219 Cosine Similarity: 0.9021682150103436
#
# Users: 42050 23406 Cosine Similarity: 0.9021342216356465
#
# Users: 49576 62667 Cosine Similarity: 0.9016087213328133
#
# Users: 54049 23746 Cosine Similarity: 0.9014819509180415
#
# Users: 45776 66469 Cosine Similarity: 0.9013618104170599
#
# Users: 56638 54231 Cosine Similarity: 0.9013375323931454
#
# Users: 31037 24209 Cosine Similarity: 0.9012301173931253
#
# Users: 50742 42050 Cosine Similarity: 0.9010764985876355
#
# Users: 49576 6445 Cosine Similarity: 0.9008466072778082
#
# Users: 22923 18579 Cosine Similarity: 0.9007654534378589
#
# Users: 31037 65600 Cosine Similarity: 0.9007071430944368
#
# Users: 47951 42050 Cosine Similarity: 0.900658242095351
#
# Users: 32898 23406 Cosine Similarity: 0.900544917933827
#
# Users: 65600 23622 Cosine Similarity: 0.9003443688890338
#
# Users: 20329 11786 Cosine Similarity: 0.9002659049839619
#
# Users: 3040 64505 Cosine Similarity: 0.9001808023903551
#
# Users: 24209 23406 Cosine Similarity: 0.9001487972234686
#
# Filename: prof_phase.py
#
# Line #    Mem usage    Increment  Occurrences   Line Contents
# =============================================================
#    249     41.7 MiB     41.7 MiB           1   @profile
#    250                                         def cosine_similarity(Thetta):
#    251     41.7 MiB      0.0 MiB           1       users_with_same_movies = dict()
#    252     41.7 MiB      0.0 MiB           1       users = dict()
#    253     41.7 MiB      0.0 MiB           1       user_movies = dict()
#    254     41.7 MiB      0.0 MiB           1       cosine_users = dict()
#    255
#    256     41.7 MiB      0.0 MiB           1       with open("ratings.dat","r") as ratings:
#    257   1929.1 MiB -1020388162.9 MiB    10000055           for line in ratings:
#    258   1929.1 MiB -1020385656.1 MiB    10000054               data = line.strip().split('::')
#    259
#    260   1929.1 MiB -1020386507.2 MiB    10000054               UserID = data[0]
#    261   1929.1 MiB -1020387039.0 MiB    10000054               MovieID = data[1]
#    262   1929.1 MiB -1020387368.8 MiB    10000054               Rating = float(data[2])
#    263
#    264   1929.1 MiB -1020387412.1 MiB    10000054               if UserID not in users:
#    265   1929.1 MiB -6986705.8 MiB       69878                   users[UserID] = []
#    266   1929.1 MiB -1020384795.7 MiB    10000054               rating_entry = {MovieID: Rating}
#    267   1929.1 MiB -1020387578.7 MiB    10000054               users[UserID].append(rating_entry)
#    268
#    269   1929.1 MiB -1020388057.7 MiB    10000054               if UserID not in user_movies:
#    270   1929.1 MiB -6986703.4 MiB       69878                   user_movies[UserID] = []
#    271   1929.1 MiB -1020385904.9 MiB    10000054               user_movies[UserID].append(MovieID)
#    272
#    273    469.4 MiB  -1459.7 MiB           1       common_user_ids = list(set(users.keys()))
#    274    469.7 MiB      0.3 MiB           1       selected_user_ids = random.sample(common_user_ids, 100)
#    275
#    276    469.8 MiB      0.0 MiB         103       trimmed_users = {user_id: users[user_id] for user_id in selected_user_ids}
#    277    469.8 MiB      0.0 MiB         103       trimmed_user_movies = {user_id: user_movies[user_id] for user_id in selected_user_ids}
#    278
#    279   1485.4 MiB  -1873.1 MiB         101       for UserID1 in trimmed_user_movies:
#    280   1485.4 MiB -191385.7 MiB       10100           for UserID2 in trimmed_user_movies:
#    281   1485.4 MiB -189513.7 MiB       10000               if UserID1 != UserID2:
#    282   1485.4 MiB -22464939.0 MiB     1188594                   common_movies = [movie for movie in trimmed_user_movies[UserID1] if movie in trimmed_user_movies[UserID2]]
#    283
#    284   1485.4 MiB -187614.3 MiB        9900                   if len(common_movies) != 0:
#    285   1485.4 MiB -175065.8 MiB        9146                       if (UserID1, UserID2) not in users_with_same_movies:
#    286   1485.4 MiB -175066.0 MiB        9146                           if (UserID2, UserID1) not in users_with_same_movies:
#    287   1485.4 MiB -121188.1 MiB        4573                               users_with_same_movies[(UserID1, UserID2)] = []
#    288
#    289   1485.4 MiB -1978537.7 MiB       72540                               for MovieID in common_movies:
#    290   1485.4 MiB -1857349.7 MiB       67967                                   users_with_same_movies[(UserID1, UserID2)].append(MovieID)
#    291
#    292
#    293   1489.4 MiB -5313961.4 MiB        4574       for (UserID1, UserID2) in users_with_same_movies:
#    294   1489.4 MiB -5312487.1 MiB        4573           cos_similar = 0
#    295   1489.4 MiB -5312487.1 MiB        4573           sum_cos_sim_nominator = 0
#    296   1489.4 MiB -5312487.1 MiB        4573           sum_cos_sim_denominator_user1 = 0
#    297   1489.4 MiB -5312487.1 MiB        4573           sum_cos_sim_denominator_user2 = 0
#    298
#    299   1489.4 MiB -91530419.3 MiB       72540           for MovieID in users_with_same_movies[(UserID1, UserID2)]:
#    300
#    301   1489.4 MiB -17213985363.7 MiB    13178993               ratings_user1 = {list(movie.keys())[0]: list(movie.values())[0] for movie in trimmed_users[UserID1]}
#    302
#    303   1489.4 MiB -86216704.3 MiB       67967               rating1 = 0
#    304   1489.4 MiB -17041767457.4 MiB    13043059               for rating_entry in trimmed_users[UserID1]:
#    305   1489.4 MiB -16955550457.0 MiB    12975092                   rating1 = ratings_user1.get(MovieID, 0)
#    306
#    307   1489.4 MiB -16749400807.2 MiB    13104718               ratings_user2 = {list(movie.keys())[0]: list(movie.values())[0] for movie in trimmed_users[UserID2]}
#    308
#    309   1489.4 MiB -86217494.9 MiB       67967               rating2 = 0
#    310   1489.4 MiB -16577106324.7 MiB    12968784               for rating_entry in trimmed_users[UserID2]:
#    311   1489.4 MiB -16490888610.3 MiB    12900817                   rating2 = ratings_user2.get(MovieID, 0)
#    312
#    313   1489.4 MiB -86217931.6 MiB       67967               sum_cos_sim_nominator += rating1*rating2
#    314   1489.4 MiB -86217932.1 MiB       67967               sum_cos_sim_denominator_user1 += rating1**2
#    315   1489.4 MiB -86217932.7 MiB       67967               sum_cos_sim_denominator_user2 += rating2**2
#    316
#    317   1489.4 MiB -5313962.3 MiB        4573           cos_similar = sum_cos_sim_nominator/(math.sqrt(sum_cos_sim_denominator_user1)*math.sqrt(sum_cos_sim_denominator_user2)) if (math.sqrt(sum_cos_sim_denominator_user1)*math.sqrt(sum_cos_sim_denominator_user2))!=0 else 0
#    318
#    319   1489.4 MiB -5313962.0 MiB        4573           cosine_users[(UserID1, UserID2)] = cos_similar
#    320
#    321     15.6 MiB  -1473.9 MiB        9147       sorted_users = sorted(cosine_users.items(), key=lambda x: x[1], reverse=True)
#    322
#    323     15.6 MiB      0.0 MiB           1       final_cosine_users = dict()
#    324     16.1 MiB      0.3 MiB        4574       for ((UserID1, UserID2), similarity) in sorted_users:
#    325     16.1 MiB      0.0 MiB        4573           if similarity >= Thetta:
#    326     16.1 MiB      0.3 MiB        4298               final_cosine_users[(UserID1, UserID2)] = similarity
#    327
#    328     16.3 MiB      0.0 MiB        4299       for (UserID1, UserID2) in final_cosine_users:
#    329     16.3 MiB      0.1 MiB        4298           print("Users:", UserID1, UserID2, "Cosine Similarity:", final_cosine_users[(UserID1, UserID2)], "\n")
#    330     16.3 MiB      0.0 MiB           1       gc.collect
#
#
#
# Choose
#
#  1) rating T1 T2: find all movies with rating between T1 and T2
#
#  2) top_movies K: find all movies with rating over K
#
#  3) user_pairs K: find all user pairs that have given rating to the same movie
#
#     4) dominance: find users that aren't dominated from other movies
#
#  5) iceberg K T: find movies that have been rated at least K times with average score over T
#
#  6) top_user K: find the K users that have rated the most movies
#
#     7) movie_sample S: find a percentage of movies from all categories
#
#  8) similar_users Θ: find users that have similar tastes in movies based on cosine similarity
#
#  9) S to stop

# %%
import math
import random
import cProfile

###################################################################################################################################################################################
###-----------------------------------------------------------------------------------RATING ---------------------------------------------------------------------------------
###################################################################################################################################################################################
def find_movies_between_T1_T2(T1, T2):
    filtered_ratings = dict()
    average_ratings = dict()
    movies = dict()

    with open("movies.dat","r", encoding="utf-8") as Mov:
        for line in Mov:
            data = line.strip().split('::')

            MovieID = data[0]
            Title = data[1]
            
            movies[MovieID] = Title

    with open("ratings.dat","r") as ratings:
        for line in ratings:
            data = line.strip().split('::')

            MovieID = data[1]
            Rating = float(data[2])
            
            if MovieID in average_ratings:
                average_ratings[MovieID]['Total_Rating'] +=Rating
                average_ratings[MovieID]['Count'] += 1
            else:
                average_ratings[MovieID] = {'Total_Rating': Rating, 'Count': 1}

    for MovieID in movies:
        if MovieID in average_ratings.keys():
            Title = movies[MovieID]
            average_rating = average_ratings[MovieID]['Total_Rating']/average_ratings[MovieID]['Count']
            if T1 <= average_rating <= T2:
                filtered_ratings[Title] = average_rating

    for Title in filtered_ratings:
        print("Movie Title:", Title, "Average Rating:", filtered_ratings[Title], "\n")

###################################################################################################################################################################################
###-----------------------------------------------------------------------------------TOP MOVIES ---------------------------------------------------------------------------------
###################################################################################################################################################################################

def find_top_movies(K):

    filtered_ratings = dict()
    average_ratings = dict()
    movies = dict()

    with open("movies.dat","r", encoding="utf-8") as Mov:
        for line in Mov:
            data = line.strip().split('::')

            MovieID = data[0]
            Title = data[1]
            
            movies[MovieID] = Title

    with open("ratings.dat","r") as ratings:
        for line in ratings:
            data = line.strip().split('::')

            MovieID = data[1]
            Rating = float(data[2])
            
            if MovieID in average_ratings:
                average_ratings[MovieID]['Total_Rating'] +=Rating
                average_ratings[MovieID]['Count'] += 1
            else:
                average_ratings[MovieID] = {'Total_Rating': Rating, 'Count': 1}
        
    for MovieID in movies:
        if MovieID in average_ratings.keys():
            Title = movies[MovieID]
            average_rating = average_ratings[MovieID]['Total_Rating']/average_ratings[MovieID]['Count']
            filtered_ratings[Title] = average_rating

    sorted_ratings = sorted(filtered_ratings.items(), key=lambda x: x[1], reverse=True)

    top_K_movies = sorted_ratings[:K]
    
    for Title, Average_Rating in top_K_movies:
        print("Movie Title:", Title, "Average Rating:", Average_Rating, "\n")

###################################################################################################################################################################################
###-----------------------------------------------------------------------------------USER PAIRS ---------------------------------------------------------------------------------
###################################################################################################################################################################################

def find_user_pairs(K):
    user_pairs = dict()
    filtered_pairs = dict()
    movies = dict()
    MovieIds = []

    with open("movies.dat","r", encoding="utf-8") as Mov:
        for line in Mov:
            data = line.strip().split('::')

            MovieID = data[0]
            Title = data[1]
            
            movies[MovieID] = Title
            MovieIds.append(MovieID)


    with open("ratings.dat","r") as ratings:
        for line in ratings:
            data = line.strip().split('::')

            MovieID = data[1]
            UserID = data[0]
            
            if MovieID in user_pairs:
                if len(user_pairs[MovieID]) == 2:
                    continue;
                else:
                    user_pairs[MovieID].append(int(UserID))    
            else:
                user_pairs[MovieID] = [int(UserID)]

    chosen_movies = random.sample(MovieIds, min(K, len(MovieIds)))
  
    for MovieID in chosen_movies:
        if MovieID in user_pairs.keys():
            Title = movies[MovieID]
            filtered_pairs[Title] = user_pairs[MovieID]

    for Title in filtered_pairs:
        print("Movie Title:", Title, "Users:", filtered_pairs[Title], "\n")

###################################################################################################################################################################################
###-----------------------------------------------------------------------------------ICEBERG ---------------------------------------------------------------------------------
###################################################################################################################################################################################

def iceberg(K,T):

    iceberg_movies = dict()
    filtered_movies = dict()
    movies = dict()

    with open("movies.dat","r", encoding="utf-8") as Mov:
        for line in Mov:
            data = line.strip().split('::')

            MovieID = data[0]
            Title = data[1]
            
            movies[MovieID] = Title


    with open("ratings.dat","r") as ratings:
        for line in ratings:
            data = line.strip().split('::')

            MovieID = data[1]
            Rating = float(data[2])
            
            if MovieID in iceberg_movies:
                iceberg_movies[MovieID]['Total_Rating'] +=Rating
                iceberg_movies[MovieID]['Count'] += 1   
            else:
                iceberg_movies[MovieID] = {'Movie': MovieID, 'Total_Rating': Rating, 'Count': 1}

  
    for MovieID in movies:
        if MovieID in iceberg_movies.keys():
            average_rating = iceberg_movies[MovieID]['Total_Rating']/iceberg_movies[MovieID]['Count']
            iceberg_movies[MovieID]['Total_Rating'] = average_rating
            if iceberg_movies[MovieID]['Count'] < K or average_rating < T:
                del iceberg_movies[MovieID]
            else:
                Title = movies[MovieID]
                filtered_movies[Title] = iceberg_movies[MovieID]

    for Title in filtered_movies:
        print("Movie Title:", Title, "Number of critics:", filtered_movies[Title]['Count'], "Average Rating:", filtered_movies[Title]['Total_Rating'], "\n")

###################################################################################################################################################################################
###-----------------------------------------------------------------------------------TOP USER---------------------------------------------------------------------------------
###################################################################################################################################################################################

def top_users(K):
    users = dict()
   
    with open("ratings.dat","r") as ratings:
        for line in ratings:
            data = line.strip().split('::')

            UserID = data[0]
            
            if UserID in users:
                users[UserID]+=1    
            else:
                users[UserID] = 1

    sorted_users = sorted(users.items(), key=lambda x: x[1], reverse=True)


    top_K_users = sorted_users[:K]

    for UserID, Movies in top_K_users:
        print("User:", UserID, "Movies:", Movies, "\n")
###################################################################################################################################################################################
###-----------------------------------------------------------------------------------MOVIE SAMPLE---------------------------------------------------------------------------------
###################################################################################################################################################################################


def movie_sample(S):
   movies = dict()
   categorised_movies = dict()

   with open("movies.dat","r", encoding="utf-8") as Mov:
    for line in Mov:
        data = line.strip().split('::')

        Categories = data[2].split('|')
        Title = data[1]
            
        movies[Title] = Categories

    for Title in movies:
        for Category in movies[Title]:
            if  Category in categorised_movies.keys():
                categorised_movies[Category].append(Title)
            else: categorised_movies[Category] = [Title]

    for Category in categorised_movies:
        size = math.ceil(int((S/100)*len(categorised_movies[Category])))
        categorised_movies[Category] = categorised_movies[Category][:size]
        print("Category:", Category, "Movies:", categorised_movies[Category], "\n")

###################################################################################################################################################################################
###-----------------------------------------------------------------------------------COSINE SIMILARITY---------------------------------------------------------------------------------
###################################################################################################################################################################################
def cosine_similarity(Thetta):
    users_with_same_movies = dict()
    users = dict()
    user_movies = dict()
    cosine_users = dict()

    with open("ratings.dat","r") as ratings:
        for line in ratings:
            data = line.strip().split('::')

            UserID = data[0]
            MovieID = data[1]
            Rating = float(data[2])
            
            if UserID not in users:
                users[UserID] = []
            rating_entry = {MovieID: Rating}
            users[UserID].append(rating_entry)

            if UserID not in user_movies:
                user_movies[UserID] = []
            user_movies[UserID].append(MovieID)

    common_user_ids = list(set(users.keys()))
    selected_user_ids = random.sample(common_user_ids, 100)

    trimmed_users = {user_id: users[user_id] for user_id in selected_user_ids}
    trimmed_user_movies = {user_id: user_movies[user_id] for user_id in selected_user_ids}

    for UserID1 in trimmed_user_movies:
        for UserID2 in trimmed_user_movies:
            if UserID1 != UserID2: 
                common_movies = [movie for movie in trimmed_user_movies[UserID1] if movie in trimmed_user_movies[UserID2]]

                if len(common_movies) != 0:
                    if (UserID1, UserID2) not in users_with_same_movies:
                        if (UserID2, UserID1) not in users_with_same_movies:
                            users_with_same_movies[(UserID1, UserID2)] = []

                            for MovieID in common_movies:
                                users_with_same_movies[(UserID1, UserID2)].append(MovieID)
    

    for (UserID1, UserID2) in users_with_same_movies:
        cos_similar = 0
        sum_cos_sim_nominator = 0
        sum_cos_sim_denominator_user1 = 0
        sum_cos_sim_denominator_user2 = 0

        for MovieID in users_with_same_movies[(UserID1, UserID2)]:

            ratings_user1 = {list(movie.keys())[0]: list(movie.values())[0] for movie in trimmed_users[UserID1]}

            rating1 = 0
            for rating_entry in trimmed_users[UserID1]:
                rating1 = ratings_user1.get(MovieID, 0)

            ratings_user2 = {list(movie.keys())[0]: list(movie.values())[0] for movie in trimmed_users[UserID2]}

            rating2 = 0
            for rating_entry in trimmed_users[UserID2]:
                rating2 = ratings_user2.get(MovieID, 0)

            sum_cos_sim_nominator += rating1*rating2
            sum_cos_sim_denominator_user1 += rating1**2
            sum_cos_sim_denominator_user2 += rating2**2

        cos_similar = sum_cos_sim_nominator/(math.sqrt(sum_cos_sim_denominator_user1)*math.sqrt(sum_cos_sim_denominator_user2)) if (math.sqrt(sum_cos_sim_denominator_user1)*math.sqrt(sum_cos_sim_denominator_user2))!=0 else 0

        cosine_users[(UserID1, UserID2)] = cos_similar

    sorted_users = sorted(cosine_users.items(), key=lambda x: x[1], reverse=True)

    final_cosine_users = dict()
    for ((UserID1, UserID2), similarity) in sorted_users:
        if similarity >= Thetta:
            final_cosine_users[(UserID1, UserID2)] = similarity

    for (UserID1, UserID2) in final_cosine_users:
        print("Users:", UserID1, UserID2, "Cosine Similarity:", final_cosine_users[(UserID1, UserID2)], "\n")
###################################################################################################################################################################################
###-----------------------------------------------------------------------------------DOMINANCE---------------------------------------------------------------------------------
###################################################################################################################################################################################
def dominance():
    movies_that_are_not_dominated = dict()
    average_ratings = dict()
    movies = dict()

    with open("movies.dat","r", encoding="utf-8") as Mov:
        for line in Mov:
            data = line.strip().split('::')

            MovieID = data[0]
            Title = data[1]
            
            movies[MovieID] = Title

    with open("ratings.dat","r") as ratings:
        for line in ratings:
            data = line.strip().split('::')

            MovieID = data[1]
            Rating = float(data[2])
            
            if MovieID in average_ratings:
                average_ratings[MovieID]['Total_Rating'] +=Rating
                average_ratings[MovieID]['Count'] += 1
            else:
                average_ratings[MovieID] = {'Total_Rating': Rating, 'Count': 1}

    for MovieID in movies:
        if MovieID in average_ratings.keys():
            Title = movies[MovieID]
            average_rating = average_ratings[MovieID]['Total_Rating']/average_ratings[MovieID]['Count']
            count = average_ratings[MovieID]['Count']
            movies_that_are_not_dominated[Title] = [count, average_rating]
            for MovieID2 in movies:
                if MovieID2!=MovieID:
                    if MovieID2 in average_ratings.keys():
                        average_rating2 = average_ratings[MovieID2]['Total_Rating']/average_ratings[MovieID2]['Count']
                        count2 = average_ratings[MovieID2]['Count']
                        if average_rating2 >= average_rating and count2>=count:
                            del movies_that_are_not_dominated[Title]
                            break;

    for Title in movies_that_are_not_dominated:
        count, average_rating = movies_that_are_not_dominated[Title]
        print("Movie Title:", Title, "Average Rating:", average_rating, "Total Votes:", count, "\n")    

###################################################################################################################################################################################
###-----------------------------------------------------------------------------------MAIN---------------------------------------------------------------------------------
###################################################################################################################################################################################
def main():
    while(True):
        print("\nChoose\n\n 1) rating T1 T2: find all movies with rating between T1 and T2\n\n 2) top_movies K: find all movies with rating over K \n\n 3) user_pairs K: find all user pairs that have given rating to the same movie\n\n\
 4) dominance: find users that aren't dominated from other movies\n\n 5) iceberg K T: find movies that have been rated at least K times with average score over T\n\n 6) top_user K: find the K users that have rated the most movies\n\n\
 7) movie_sample S: find a percentage of movies from all categories\n\n 8) similar_users Θ: find users that have similar tastes in movies based on cosine similarity\n\n 9) S to stop\n\n")
        mode = [i for i in input(" ").split(' ')]

        if mode[0] == "S":
            break;

        if mode[0] == "rating":
            profiler = cProfile.Profile()
            profiler.enable()
            find_movies_between_T1_T2(float(mode[1]), float(mode[2]))
            profiler.disable()
            profiler.print_stats(sort="cumulative")

        elif mode[0] == "top_movies":
            profiler = cProfile.Profile()
            profiler.enable()
            find_top_movies(int(mode[1]))
            profiler.disable()
            profiler.print_stats(sort="cumulative")

        elif mode[0]== "user_pairs":
            profiler = cProfile.Profile()
            profiler.enable()
            find_user_pairs(int(mode[1]))
            profiler.disable()
            profiler.print_stats(sort="cumulative")

        elif mode[0]== "iceberg":
            profiler = cProfile.Profile()
            profiler.enable()
            iceberg(int(mode[1]), float(mode[2]))
            profiler.disable()
            profiler.print_stats(sort="cumulative")

        elif mode[0]== "top_user":
            profiler = cProfile.Profile()
            profiler.enable()
            top_users(int(mode[1]))
            profiler.disable()
            profiler.print_stats(sort="cumulative")

        elif mode[0]== "movie_sample":
            profiler = cProfile.Profile()
            profiler.enable()
            movie_sample(int(mode[1]))
            profiler.disable()
            profiler.print_stats(sort="cumulative")

        elif mode[0]== "similar_users":
            profiler = cProfile.Profile()
            profiler.enable()
            cosine_similarity(float(mode[1]))
            profiler.disable()
            profiler.print_stats(sort="cumulative")

        elif mode[0]== "dominance":
            profiler = cProfile.Profile()
            profiler.enable()
            dominance()

        else : print("not a choice, choose again")
        k =1

if __name__ == "__main__":
    main()
# Out:
# Choose
#
#  1) rating T1 T2: find all movies with rating between T1 and T2
#
#  2) top_movies K: find all movies with rating over K
#
#  3) user_pairs K: find all user pairs that have given rating to the same movie
#
#  4) dominance: find users that aren't dominated from other movies
#
#  5) iceberg K T: find movies that have been rated at least K times with average score over T
#
#  6) top_user K: find the K users that have rated the most movies
#
#  7) movie_sample S: find a percentage of movies from all categories
#
#  8) similar_users Θ: find users that have similar tastes in movies based on cosine similarity
#
#  9) S to stop

# %%
import cProfile

cProfile.run("find_movies_between_T1_T2(2.0, 2.2)")
cProfile.run("find_top_movies(10)")
cProfile.run("find_user_pairs(7)")
cProfile.run("dominance()")
cProfile.run("iceberg(100, 4)")
cProfile.run("top_users(5)")
cProfile.run("movie_sample(20)")
cProfile.run("cosine_similarity(0.9)")
# Out:
# Movie Title: Lawnmower Man 2: Beyond Cyberspace (1996) Average Rating: 2.132411067193676
#
# Movie Title: Beyond Bedlam (1993) Average Rating: 2.1160714285714284
#
# Movie Title: Nemesis 2: Nebula (1995) Average Rating: 2.108695652173913
#
# Movie Title: Fear, The (1995) Average Rating: 2.018181818181818
#
# Movie Title: Girl in the Cadillac (1995) Average Rating: 2.1875
#
# Movie Title: Two Crimes (Dos crímenes) (1995) Average Rating: 2.0555555555555554
#
# Movie Title: House Party 3 (1994) Average Rating: 2.175373134328358
#
# Movie Title: RoboCop 3 (1993) Average Rating: 2.1861480075901327
#
# Movie Title: Super Mario Bros. (1993) Average Rating: 2.0479274611398965
#
# Movie Title: Tough and Deadly (1995) Average Rating: 2.1666666666666665
#
# Movie Title: Hostile Intentions (1994) Average Rating: 2.130434782608696
#
# Movie Title: Barb Wire (1996) Average Rating: 2.162495466086326
#
# Movie Title: Magic Hunter (Büvös vadász) (1994) Average Rating: 2.175
#
# Movie Title: Power 98 (1996) Average Rating: 2.0
#
# Movie Title: Women Robbers (Diebinnen) (1995) Average Rating: 2.1333333333333333
#
# Movie Title: Liebelei (1933) Average Rating: 2.142857142857143
#
# Movie Title: Best of the Best 3: No Turning Back (1995) Average Rating: 2.0686274509803924
#
# Movie Title: B*A*P*S (1997) Average Rating: 2.042452830188679
#
# Movie Title: Anaconda (1997) Average Rating: 2.0859893758300134
seconds
#
#    Ordered by: standard name
#
#    ncalls  tottime  percall  cumtime  percall filename:lineno(function)
#         1   14.987   14.987   19.568   19.568 884442477.py:8(find_movies_between_T1_T2)
#         1    0.002    0.002   19.569   19.569 <string>:1(<module>)
#         1    0.000    0.000    0.000    0.000 _bootlocale.py:11(getpreferredencoding)
#         2    0.000    0.000    0.000    0.000 codecs.py:260(__init__)
#         1    0.000    0.000    0.000    0.000 codecs.py:309(__init__)
#        65    0.000    0.000    0.001    0.000 codecs.py:319(decode)
#     32363    0.036    0.000    0.727    0.000 cp1253.py:22(decode)
#         2    0.001    0.001    0.002    0.001 interactiveshell.py:275(_modified_open)
#         1    0.000    0.000    0.000    0.000 iostream.py:137(_event_pipe)
#         1    0.000    0.000    0.000    0.000 iostream.py:258(schedule)
#      2720    0.001    0.000    0.001    0.000 iostream.py:519(_is_master_process)
#      2720    0.000    0.000    0.000    0.000 iostream.py:546(_schedule_flush)
#      2720    0.004    0.000    0.006    0.000 iostream.py:624(write)
#         1    0.000    0.000    0.000    0.000 socket.py:621(send)
#         1    0.000    0.000    0.000    0.000 threading.py:1017(_wait_for_tstate_lock)
#         1    0.000    0.000    0.000    0.000 threading.py:1071(is_alive)
#         1    0.000    0.000    0.000    0.000 threading.py:513(is_set)
#     32363    0.691    0.000    0.691    0.000 {built-in method _codecs.charmap_decode}
#        65    0.001    0.000    0.001    0.000 {built-in method _codecs.utf_8_decode}
#         1    0.000    0.000    0.000    0.000 {built-in method _locale._getdefaultlocale}
#         1    0.000    0.000   19.570   19.570 {built-in method builtins.exec}
#      2720    0.000    0.000    0.000    0.000 {built-in method builtins.isinstance}
#      2720    0.000    0.000    0.000    0.000 {built-in method builtins.len}
#       272    0.002    0.000    0.008    0.000 {built-in method builtins.print}
#         2    0.001    0.000    0.001    0.001 {built-in method io.open}
#      2720    0.000    0.000    0.000    0.000 {built-in method nt.getpid}
#         1    0.000    0.000    0.000    0.000 {method 'acquire' of '_thread.lock' objects}
#         1    0.000    0.000    0.000    0.000 {method 'append' of 'collections.deque' objects}
#         1    0.000    0.000    0.000    0.000 {method 'disable' of '_lsprof.Profiler' objects}
#     10681    0.001    0.000    0.001    0.000 {method 'keys' of 'dict' objects}
#  10010735    2.764    0.000    2.764    0.000 {method 'split' of 'str' objects}
#  10010735    1.078    0.000    1.078    0.000 {method 'strip' of 'str' objects}
#      2720    0.000    0.000    0.000    0.000 {method 'write' of '_io.StringIO' objects}
#
#
# Movie Title: Satan's Tango (Sátántangó) (1994) Average Rating: 5.0
#
# Movie Title: Shadows of Forgotten Ancestors (1964) Average Rating: 5.0
#
# Movie Title: Fighting Elegy (Kenka erejii) (1966) Average Rating: 5.0
#
# Movie Title: Sun Alley (Sonnenallee) (1999) Average Rating: 5.0
#
# Movie Title: Blue Light, The (Das Blaue Licht) (1932) Average Rating: 5.0
#
# Movie Title: More (1998) Average Rating: 4.75
#
# Movie Title: Who's Singin' Over There? (a.k.a. Who Sings Over There) (Ko to tamo peva) (1980) Average Rating: 4.75
#
# Movie Title: Human Condition II, The (Ningen no joken II) (1959) Average Rating: 4.75
#
# Movie Title: Human Condition III, The (Ningen no joken III) (1961) Average Rating: 4.75
#
# Movie Title: Constantine's Sword (2007) Average Rating: 4.75
#
#          20108416 function calls in 16.120 seconds
#
#    Ordered by: standard name
#
#    ncalls  tottime  percall  cumtime  percall filename:lineno(function)
#         1   12.153   12.153   16.118   16.118 884442477.py:49(find_top_movies)
#     10676    0.001    0.000    0.001    0.000 884442477.py:83(<lambda>)
#         1    0.003    0.003   16.120   16.120 <string>:1(<module>)
#         1    0.000    0.000    0.000    0.000 _bootlocale.py:11(getpreferredencoding)
#         2    0.000    0.000    0.000    0.000 codecs.py:260(__init__)
#         1    0.000    0.000    0.000    0.000 codecs.py:309(__init__)
#        65    0.000    0.000    0.001    0.000 codecs.py:319(decode)
#     32363    0.027    0.000    0.664    0.000 cp1253.py:22(decode)
#         2    0.000    0.000    0.000    0.000 interactiveshell.py:275(_modified_open)
#         1    0.000    0.000    0.000    0.000 iostream.py:137(_event_pipe)
#         1    0.000    0.000    0.000    0.000 iostream.py:258(schedule)
#       100    0.000    0.000    0.000    0.000 iostream.py:519(_is_master_process)
#       100    0.000    0.000    0.000    0.000 iostream.py:546(_schedule_flush)
#       100    0.000    0.000    0.000    0.000 iostream.py:624(write)
#         1    0.000    0.000    0.000    0.000 socket.py:621(send)
#         1    0.000    0.000    0.000    0.000 threading.py:1017(_wait_for_tstate_lock)
#         1    0.000    0.000    0.000    0.000 threading.py:1071(is_alive)
#         1    0.000    0.000    0.000    0.000 threading.py:513(is_set)
#     32363    0.637    0.000    0.637    0.000 {built-in method _codecs.charmap_decode}
#        65    0.000    0.000    0.000    0.000 {built-in method _codecs.utf_8_decode}
#         1    0.000    0.000    0.000    0.000 {built-in method _locale._getdefaultlocale}
#         1    0.000    0.000   16.120   16.120 {built-in method builtins.exec}
#       100    0.000    0.000    0.000    0.000 {built-in method builtins.isinstance}
#       100    0.000    0.000    0.000    0.000 {built-in method builtins.len}
#        10    0.000    0.000    0.001    0.000 {built-in method builtins.print}
#         1    0.031    0.031    0.032    0.032 {built-in method builtins.sorted}
#         2    0.000    0.000    0.000    0.000 {built-in method io.open}
#       100    0.000    0.000    0.000    0.000 {built-in method nt.getpid}
#         1    0.000    0.000    0.000    0.000 {method 'acquire' of '_thread.lock' objects}
#         1    0.000    0.000    0.000    0.000 {method 'append' of 'collections.deque' objects}
#         1    0.000    0.000    0.000    0.000 {method 'disable' of '_lsprof.Profiler' objects}
#         1    0.000    0.000    0.000    0.000 {method 'items' of 'dict' objects}
#     10681    0.001    0.000    0.001    0.000 {method 'keys' of 'dict' objects}
#  10010735    2.314    0.000    2.314    0.000 {method 'split' of 'str' objects}
#  10010735    0.953    0.000    0.953    0.000 {method 'strip' of 'str' objects}
#       100    0.000    0.000    0.000    0.000 {method 'write' of '_io.StringIO' objects}
#
#
# Movie Title: War and Peace (1956) Users: [402, 867]
#
# Movie Title: Jonah: A VeggieTales Movie (2002) Users: [226, 259]
#
# Movie Title: Oldboy (2005) Users: [144, 192]
#
# Movie Title: Ernest Goes to Camp (1987) Users: [97, 143]
#
# Movie Title: Killer: A Journal of Murder (1995) Users: [1766, 1883]
#
# Movie Title: Running Scared (1980) Users: [1433, 1621]
#
# Movie Title: Boys Don't Cry (Chlopaki nie placza) (2000) Users: [6362, 15181]
#
#          30097554 function calls (30097540 primitive calls) in 12.645 seconds
#
#    Ordered by: standard name
#
#    ncalls  tottime  percall  cumtime  percall filename:lineno(function)
#         1    8.067    8.067   12.642   12.642 884442477.py:94(find_user_pairs)
#         1    0.002    0.002   12.645   12.645 <string>:1(<module>)
#         1    0.000    0.000    0.000    0.000 _bootlocale.py:11(getpreferredencoding)
#         3    0.000    0.000    0.000    0.000 _collections_abc.py:302(__subclasshook__)
#         6    0.000    0.000    0.000    0.000 _collections_abc.py:392(__subclasshook__)
#       9/2    0.000    0.000    0.000    0.000 abc.py:100(__subclasscheck__)
#         2    0.000    0.000    0.000    0.000 abc.py:96(__instancecheck__)
#         2    0.000    0.000    0.000    0.000 codecs.py:260(__init__)
#         1    0.000    0.000    0.000    0.000 codecs.py:309(__init__)
#        65    0.000    0.000    0.000    0.000 codecs.py:319(decode)
#     32363    0.024    0.000    0.654    0.000 cp1253.py:22(decode)
#         2    0.000    0.000    0.001    0.001 interactiveshell.py:275(_modified_open)
#         1    0.000    0.000    0.000    0.000 iostream.py:137(_event_pipe)
#         1    0.000    0.000    0.000    0.000 iostream.py:258(schedule)
#        70    0.000    0.000    0.000    0.000 iostream.py:519(_is_master_process)
#        70    0.000    0.000    0.000    0.000 iostream.py:546(_schedule_flush)
#        70    0.000    0.000    0.000    0.000 iostream.py:624(write)
#         7    0.000    0.000    0.000    0.000 random.py:250(_randbelow_with_getrandbits)
#         1    0.000    0.000    0.000    0.000 random.py:315(sample)
#         1    0.000    0.000    0.000    0.000 socket.py:621(send)
#         1    0.000    0.000    0.000    0.000 threading.py:1017(_wait_for_tstate_lock)
#         1    0.000    0.000    0.000    0.000 threading.py:1071(is_alive)
#         1    0.000    0.000    0.000    0.000 threading.py:513(is_set)
#         2    0.000    0.000    0.000    0.000 {built-in method _abc._abc_instancecheck}
#       9/2    0.000    0.000    0.000    0.000 {built-in method _abc._abc_subclasscheck}
#     32363    0.629    0.000    0.629    0.000 {built-in method _codecs.charmap_decode}
#        65    0.000    0.000    0.000    0.000 {built-in method _codecs.utf_8_decode}
#         1    0.000    0.000    0.000    0.000 {built-in method _locale._getdefaultlocale}
#         1    0.000    0.000   12.645   12.645 {built-in method builtins.exec}
#        72    0.000    0.000    0.000    0.000 {built-in method builtins.isinstance}
#   9989449    0.642    0.000    0.642    0.000 {built-in method builtins.len}
#         1    0.000    0.000    0.000    0.000 {built-in method builtins.min}
#         7    0.000    0.000    0.000    0.000 {built-in method builtins.print}
#         2    0.001    0.000    0.001    0.000 {built-in method io.open}
#         1    0.000    0.000    0.000    0.000 {built-in method math.ceil}
#         1    0.000    0.000    0.000    0.000 {built-in method math.log}
#        70    0.000    0.000    0.000    0.000 {built-in method nt.getpid}
#         1    0.000    0.000    0.000    0.000 {method 'acquire' of '_thread.lock' objects}
#         7    0.000    0.000    0.000    0.000 {method 'add' of 'set' objects}
#         1    0.000    0.000    0.000    0.000 {method 'append' of 'collections.deque' objects}
#     21258    0.004    0.000    0.004    0.000 {method 'append' of 'list' objects}
#         7    0.000    0.000    0.000    0.000 {method 'bit_length' of 'int' objects}
#         1    0.000    0.000    0.000    0.000 {method 'disable' of '_lsprof.Profiler' objects}
#         8    0.000    0.000    0.000    0.000 {method 'getrandbits' of '_random.Random' objects}
#         7    0.000    0.000    0.000    0.000 {method 'keys' of 'dict' objects}
#  10010735    2.292    0.000    2.292    0.000 {method 'split' of 'str' objects}
#  10010735    0.982    0.000    0.982    0.000 {method 'strip' of 'str' objects}
#        70    0.000    0.000    0.000    0.000 {method 'write' of '_io.StringIO' objects}
#
#
# Movie Title: Pulp Fiction (1994) Average Rating: 4.157425998164295 Total Votes: 34864
#
# Movie Title: Shawshank Redemption, The (1994) Average Rating: 4.457238321660348 Total Votes: 31126
#
# Movie Title: Silence of the Lambs, The (1991) Average Rating: 4.2041998336699535 Total Votes: 33668
#
# Movie Title: More (1998) Average Rating: 4.75 Total Votes: 8
#
# Movie Title: Satan's Tango (Sátántangó) (1994) Average Rating: 5.0 Total Votes: 2
#
#          20297137 function calls in 22.116 seconds
#
#    Ordered by: standard name
#
#    ncalls  tottime  percall  cumtime  percall filename:lineno(function)
#         1   17.066   17.066   22.114   22.114 884442477.py:323(dominance)
#         1    0.002    0.002   22.116   22.116 <string>:1(<module>)
#         1    0.000    0.000    0.000    0.000 _bootlocale.py:11(getpreferredencoding)
#         2    0.000    0.000    0.000    0.000 codecs.py:260(__init__)
#         1    0.000    0.000    0.000    0.000 codecs.py:309(__init__)
#        65    0.000    0.000    0.000    0.000 codecs.py:319(decode)
#     32363    0.049    0.000    0.784    0.000 cp1253.py:22(decode)
#         2    0.000    0.000    0.001    0.000 interactiveshell.py:275(_modified_open)
#         1    0.000    0.000    0.000    0.000 iostream.py:137(_event_pipe)
#         1    0.000    0.000    0.001    0.001 iostream.py:258(schedule)
#        70    0.000    0.000    0.000    0.000 iostream.py:519(_is_master_process)
#        70    0.000    0.000    0.001    0.000 iostream.py:546(_schedule_flush)
#        70    0.000    0.000    0.001    0.000 iostream.py:624(write)
#         1    0.001    0.001    0.001    0.001 socket.py:621(send)
#         1    0.000    0.000    0.000    0.000 threading.py:1017(_wait_for_tstate_lock)
#         1    0.000    0.000    0.000    0.000 threading.py:1071(is_alive)
#         1    0.000    0.000    0.000    0.000 threading.py:513(is_set)
#     32363    0.734    0.000    0.734    0.000 {built-in method _codecs.charmap_decode}
#        65    0.000    0.000    0.000    0.000 {built-in method _codecs.utf_8_decode}
#         1    0.000    0.000    0.000    0.000 {built-in method _locale._getdefaultlocale}
#         1    0.000    0.000   22.116   22.116 {built-in method builtins.exec}
#        70    0.000    0.000    0.000    0.000 {built-in method builtins.isinstance}
#        70    0.000    0.000    0.000    0.000 {built-in method builtins.len}
#         5    0.000    0.000    0.001    0.000 {built-in method builtins.print}
#         2    0.001    0.000    0.001    0.000 {built-in method io.open}
#        70    0.000    0.000    0.000    0.000 {built-in method nt.getpid}
#         1    0.000    0.000    0.000    0.000 {method 'acquire' of '_thread.lock' objects}
#         1    0.000    0.000    0.000    0.000 {method 'append' of 'collections.deque' objects}
#         1    0.000    0.000    0.000    0.000 {method 'disable' of '_lsprof.Profiler' objects}
#    210295    0.024    0.000    0.024    0.000 {method 'keys' of 'dict' objects}
#  10010735    3.014    0.000    3.014    0.000 {method 'split' of 'str' objects}
#  10010735    1.225    0.000    1.225    0.000 {method 'strip' of 'str' objects}
#        70    0.000    0.000    0.000    0.000 {method 'write' of '_io.StringIO' objects}
# Users: 2516 15611 Cosine Similarity: 0.9018887379219993
#
# Users: 30987 5549 Cosine Similarity: 0.9018535912726997
#
# Users: 37315 15611 Cosine Similarity: 0.9018273063538679
#
# Users: 30696 3265 Cosine Similarity: 0.9016018123752455
#
# Users: 4131 42109 Cosine Similarity: 0.9015063592706771
#
# Users: 71507 33540 Cosine Similarity: 0.901397130867928
#
# Users: 10401 71507 Cosine Similarity: 0.9011992185600846
#
# Users: 9272 1445 Cosine Similarity: 0.9011524749175376
#
# Users: 25501 38250 Cosine Similarity: 0.9011335178094674
#
# Users: 47948 30987 Cosine Similarity: 0.9008736915024161
#
# Users: 25501 47005 Cosine Similarity: 0.9007988462684449
#
# Users: 48932 21759 Cosine Similarity: 0.9006833360535759
#
# Users: 42018 19777 Cosine Similarity: 0.9004189903853235
#
# Users: 16571 30853 Cosine Similarity: 0.9003422138892231
#
# Users: 48932 15611 Cosine Similarity: 0.9000567109713344
#
#          256440639 function calls in 134.697 seconds
#
#    Ordered by: standard name
#
#    ncalls  tottime  percall  cumtime  percall filename:lineno(function)
#         1   31.105   31.105  124.210  124.210 884442477.py:240(cosine_similarity)
#         1    0.000    0.000    0.000    0.000 884442477.py:266(<dictcomp>)
#         1    0.000    0.000    0.000    0.000 884442477.py:267(<dictcomp>)
#      9900    4.708    0.000    4.708    0.000 884442477.py:272(<listcomp>)
#    105481   30.757    0.000   37.026    0.000 884442477.py:291(<dictcomp>)
#    105481   30.780    0.000   37.066    0.000 884442477.py:297(<dictcomp>)
#      4676    0.000    0.000    0.000    0.000 884442477.py:311(<lambda>)
#         1   10.487   10.487  134.696  134.696 <string>:1(<module>)
#         1    0.000    0.000    0.000    0.000 _bootlocale.py:11(getpreferredencoding)
#         2    0.000    0.000    0.000    0.000 abc.py:96(__instancecheck__)
#         1    0.000    0.000    0.000    0.000 codecs.py:260(__init__)
#     32363    0.039    0.000    0.751    0.000 cp1253.py:22(decode)
#         1    0.000    0.000    0.000    0.000 interactiveshell.py:275(_modified_open)
#         1    0.000    0.000    0.000    0.000 iostream.py:137(_event_pipe)
#         1    0.001    0.001    0.010    0.010 iostream.py:258(schedule)
#     51540    0.017    0.000    0.024    0.000 iostream.py:519(_is_master_process)
#     51540    0.007    0.000    0.018    0.000 iostream.py:546(_schedule_flush)
#     51540    0.089    0.000    0.149    0.000 iostream.py:624(write)
#       101    0.000    0.000    0.000    0.000 random.py:250(_randbelow_with_getrandbits)
#         1    0.000    0.000    0.001    0.001 random.py:315(sample)
#         1    0.009    0.009    0.009    0.009 socket.py:621(send)
#         1    0.000    0.000    0.000    0.000 threading.py:1017(_wait_for_tstate_lock)
#         1    0.000    0.000    0.000    0.000 threading.py:1071(is_alive)
#         1    0.000    0.000    0.000    0.000 threading.py:513(is_set)
#         2    0.000    0.000    0.000    0.000 {built-in method _abc._abc_instancecheck}
#     32363    0.713    0.000    0.713    0.000 {built-in method _codecs.charmap_decode}
#         1    0.000    0.000    0.000    0.000 {built-in method _locale._getdefaultlocale}
#         1    0.001    0.001  134.697  134.697 {built-in method builtins.exec}
#     51542    0.005    0.000    0.005    0.000 {built-in method builtins.isinstance}
#     61441    0.007    0.000    0.007    0.000 {built-in method builtins.len}
#      4295    0.026    0.000    0.175    0.000 {built-in method builtins.print}
#         1    0.005    0.005    0.005    0.005 {built-in method builtins.sorted}
#         1    0.000    0.000    0.000    0.000 {built-in method io.open}
#         1    0.000    0.000    0.000    0.000 {built-in method math.ceil}
#         1    0.000    0.000    0.000    0.000 {built-in method math.log}
#     18704    0.005    0.000    0.005    0.000 {built-in method math.sqrt}
#     51540    0.007    0.000    0.007    0.000 {built-in method nt.getpid}
#         1    0.000    0.000    0.000    0.000 {method 'acquire' of '_thread.lock' objects}
#       100    0.000    0.000    0.000    0.000 {method 'add' of 'set' objects}
#         1    0.000    0.000    0.000    0.000 {method 'append' of 'collections.deque' objects}
#  20105589    2.363    0.000    2.363    0.000 {method 'append' of 'list' objects}
#       101    0.000    0.000    0.000    0.000 {method 'bit_length' of 'int' objects}
#         1    0.000    0.000    0.000    0.000 {method 'disable' of '_lsprof.Profiler' objects}
#  71883495    6.064    0.000    6.064    0.000 {method 'get' of 'dict' objects}
#       180    0.000    0.000    0.000    0.000 {method 'getrandbits' of '_random.Random' objects}
#         1    0.000    0.000    0.000    0.000 {method 'items' of 'dict' objects}
#  71883496    6.341    0.000    6.341    0.000 {method 'keys' of 'dict' objects}
#  10000054    3.667    0.000    3.667    0.000 {method 'split' of 'str' objects}
#  10000054    1.269    0.000    1.269    0.000 {method 'strip' of 'str' objects}
#  71883495    6.215    0.000    6.215    0.000 {method 'values' of 'dict' objects}
#     51540    0.009    0.000    0.009    0.000 {method 'write' of '_io.StringIO' objects}
