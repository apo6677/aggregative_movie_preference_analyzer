# %%
import math
import random

###################################################################################################################################################################################
###-----------------------------------------------------------------------------------RATING ---------------------------------------------------------------------------------
###################################################################################################################################################################################

def data_handling_ratings():

    filtered_ratings = dict()
    average_ratings = dict()
    movies = dict()

    with open("movies.dat","r", encoding="utf-8") as Mov:
            for line in Mov:
                data = line.strip().split('::')

                MovieID = data[0]
                Title = data[1]
                
                movies[MovieID] = Title

    with open("ratings.dat","r") as ratings:
        for line in ratings:
            data = line.strip().split('::')

            MovieID = data[1]
            Rating = float(data[2])
            
            if MovieID in average_ratings:
                average_ratings[MovieID]['Total_Rating'] +=Rating
                average_ratings[MovieID]['Count'] += 1
            else:
                average_ratings[MovieID] = {'Total_Rating': Rating, 'Count': 1}

    for MovieID in movies:
        if MovieID in average_ratings.keys():
            Title = movies[MovieID]
            average_rating = average_ratings[MovieID]['Total_Rating']/average_ratings[MovieID]['Count']
            filtered_ratings[Title] = average_rating

    with open("first_user_search_of_ratings.txt", "w", encoding="utf-8") as searched_ratings:
        for Title in filtered_ratings.keys():
            searched_ratings.write(Title +"::"+str(filtered_ratings[Title])+ '\n') 

#-------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------

def find_movies_between_T1_T2(T1, T2, a):
    final_ratings = dict()

    if a == 0:
        data_handling_ratings()

    with open("first_user_search_of_ratings.txt", "r", encoding="utf-8") as searched_ratings:
            for line in searched_ratings:
                data = line.strip().split('::')

                Title = data[0]
                Rating = float(data[1])
                if T1 <= Rating <= T2:
                    final_ratings[Title] = Rating

    for Title in final_ratings:
        print("Movie Title:", Title, "Average Rating:", final_ratings[Title], "\n")

    T1_T2_a = f"rating_{T1}_{T2}.txt"

    with open(T1_T2_a, "w", encoding="utf-8") as new_entry:
        for Title in final_ratings.keys():
            new_entry.write(f"Movie Title: {Title}, Average Rating: {final_ratings[Title]}\n")

###################################################################################################################################################################################
###-----------------------------------------------------------------------------------TOP MOVIES ---------------------------------------------------------------------------------
###################################################################################################################################################################################

def data_handling_top_movies():

    filtered_ratings = dict()
    average_ratings = dict()
    movies = dict()

    with open("movies.dat","r", encoding="utf-8") as Mov:
        for line in Mov:
            data = line.strip().split('::')

            MovieID = data[0]
            Title = data[1]
            
            movies[MovieID] = Title

    with open("ratings.dat","r") as ratings:
        for line in ratings:
            data = line.strip().split('::')

            MovieID = data[1]
            Rating = float(data[2])
            
            if MovieID in average_ratings:
                average_ratings[MovieID]['Total_Rating'] +=Rating
                average_ratings[MovieID]['Count'] += 1
            else:
                average_ratings[MovieID] = {'Total_Rating': Rating, 'Count': 1}
        
    for MovieID in movies:
        if MovieID in average_ratings.keys():
            Title = movies[MovieID]
            average_rating = average_ratings[MovieID]['Total_Rating']/average_ratings[MovieID]['Count']
            filtered_ratings[Title] = average_rating

    with open("first_top_movies_search.txt", "w", encoding="utf-8") as searched_top_movies:
        for Title in filtered_ratings.keys():
            searched_top_movies.write(Title +"::"+str(filtered_ratings[Title])+ '\n')

#---------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------

def find_top_movies(K, b): 
    filtered_ratings = dict()

    if b == 0:
        data_handling_top_movies()

    with open("first_top_movies_search.txt", "r", encoding="utf-8") as searched_top_movies:
            for line in searched_top_movies:
                data = line.strip().split('::')

                Title = data[0]
                Rating = float(data[1])
                filtered_ratings[Title] = Rating

    sorted_ratings = sorted(filtered_ratings.items(), key=lambda x: x[1], reverse=True)
    top_K_movies = sorted_ratings[:K]
    
    for Title, Average_Rating in top_K_movies:
        print("Movie Title:", Title, "Average Rating:", Average_Rating, "\n")

    Kappa = f"top_movies_{K}.txt"

    with open(Kappa, "w", encoding="utf-8") as new_entry:
        for Title, Average_Rating in top_K_movies:
            new_entry.write(f"Movie Title: {Title}, Average Rating: {Average_Rating}\n")

###################################################################################################################################################################################
###-----------------------------------------------------------------------------------USER PAIRS ---------------------------------------------------------------------------------
###################################################################################################################################################################################
def handling_user_pairs(K):
    user_pairs = dict()
    filtered_pairs = dict()
    movies = dict()
    MovieIds = []

    with open("movies.dat","r", encoding="utf-8") as Mov:
        for line in Mov:
            data = line.strip().split('::')

            MovieID = data[0]
            Title = data[1]
            
            movies[MovieID] = Title
            MovieIds.append(MovieID)


    with open("ratings.dat","r") as ratings:
        for line in ratings:
            data = line.strip().split('::')

            MovieID = data[1]
            UserID = data[0]
            
            if MovieID in user_pairs:
                if len(user_pairs[MovieID]) == 2:
                    continue;
                else:
                    user_pairs[MovieID].append(int(UserID))    
            else:
                user_pairs[MovieID] = [int(UserID)]

    chosen_movies = random.sample(MovieIds, min(K, len(MovieIds)))
  
    for MovieID in chosen_movies:
        if MovieID in user_pairs.keys():
            Title = movies[MovieID]
            filtered_pairs[Title] = user_pairs[MovieID]
    
    with open("first_user_pairs_search.txt", "w", encoding="utf-8") as searched_user_pairs:
        for Title in filtered_pairs.keys():
            searched_user_pairs.write(Title +"::"+str(filtered_pairs[Title])+ '\n')
#------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
def find_user_pairs(K, c):
    final_pairs = dict()
    if c == 0:
        handling_user_pairs(K)

    with open("first_user_pairs_search.txt", "r", encoding="utf-8") as searched_user_pairs:
            for line in searched_user_pairs:
                data = line.strip().split('::')

                Title = data[0]
                Pair = data[1]
                final_pairs[Title] = Pair

    for Title in final_pairs:
        print("Movie Title:", Title, "Users Pair:", final_pairs[Title], "\n")

    Kappa = f"user_pairs_{K}.txt"

    with open(Kappa, "w", encoding="utf-8") as new_entry:
        for Title in final_pairs.keys():
            new_entry.write(f"Movie Title: {Title}, Users Pair: {final_pairs[Title]}\n")

###################################################################################################################################################################################
###-----------------------------------------------------------------------------------ICEBERG ---------------------------------------------------------------------------------
###################################################################################################################################################################################
def handling_iceberg():

    iceberg_movies = dict()
    movies = dict()

    with open("movies.dat","r", encoding="utf-8") as Mov:
        for line in Mov:
            data = line.strip().split('::')

            MovieID = data[0]
            Title = data[1]
            
            movies[MovieID] = Title


    with open("ratings.dat","r") as ratings:
        for line in ratings:
            data = line.strip().split('::')

            MovieID = data[1]
            Rating = float(data[2])
            
            if MovieID in iceberg_movies:
                iceberg_movies[MovieID]['Total_Rating'] +=Rating
                iceberg_movies[MovieID]['Count'] += 1   
            else:
                iceberg_movies[MovieID] = {'Movie': MovieID, 'Total_Rating': Rating, 'Count': 1}

  
    for MovieID in movies:
        if MovieID in iceberg_movies.keys():
            average_rating = iceberg_movies[MovieID]['Total_Rating']/iceberg_movies[MovieID]['Count']
            iceberg_movies[MovieID]['Total_Rating'] = average_rating

    
    with open("first_user_search_of_iceberg.txt", "w", encoding="utf-8") as searched_iceberg:
        for Title in iceberg_movies.keys():
            searched_iceberg.write(Title +"::"+str(iceberg_movies[Title]['Total_Rating'])+"::"+ str(iceberg_movies[Title]['Count'])+ '\n')  

#--------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------

def iceberg(K,T, d):
    final_movies = dict()
    if d==0:
        handling_iceberg()

    with open("first_user_search_of_iceberg.txt", "r", encoding="utf-8") as searched_iceberg:
        for line in searched_iceberg:
            data = line.strip().split('::')

            Title = data[0]
            Rating = float(data[1])
            Count = int(data[2])

            if Count >= K and Rating >= T:
                final_movies[Title] = {'Count': Count, 'Total_Rating': Rating}

    for Title in final_movies:
        print("Movie Title:", Title, "Number of critics:", final_movies[Title]['Count'], "Average Rating:", final_movies[Title]['Total_Rating'], "\n")

    K_T = f"iceberg_{K}_{T}.txt"

    with open(K_T, "w", encoding="utf-8") as new_entry:
        for Title in final_movies.keys():
            new_entry.write(f"Movie Title: {Title}, Average Rating: {final_movies[Title]}\n")

###################################################################################################################################################################################
###-----------------------------------------------------------------------------------TOP USER---------------------------------------------------------------------------------
###################################################################################################################################################################################
def handling_top_user():
    users = dict()
   
    with open("ratings.dat","r") as ratings:
        for line in ratings:
            data = line.strip().split('::')

            UserID = data[0]
            
            if UserID in users:
                users[UserID]+=1    
            else:
                users[UserID] = 1

    sorted_users = sorted(users.items(), key=lambda x: x[1], reverse=True)

    with open("first_user_search_of_top_user.txt", "w", encoding="utf-8") as searched_top_user:
        for User, Critics in sorted_users:
            searched_top_user.write(User +"::"+str(Critics)+ '\n')
#------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------           
def top_users(K, e):
    Users = list()
    if e ==0:
        handling_top_user()
    with open("first_user_search_of_top_user.txt", "r", encoding="utf-8") as searched_top_user:
            for line in searched_top_user:
                data = line.strip().split('::')

                User = data[0]
                Critics = data[1]

                Users.append((User,Critics))

    top_K_users = Users[:K]

    for UserID, Critics in top_K_users:
        print("User:", UserID, "Movies:", Critics, "\n")

    Kappa = f"top_user_{K}.txt"

    with open(Kappa, "w", encoding="utf-8") as new_entry:
        for UserID, Critics in top_K_users:
            new_entry.write(f"User: {UserID}, Movies: {Critics}\n")
###################################################################################################################################################################################
###-----------------------------------------------------------------------------------MOVIE SAMPLE---------------------------------------------------------------------------------
###################################################################################################################################################################################
def handling_movie_sample():
    movies = dict()
    categorised_movies = dict()

    with open("movies.dat","r", encoding="utf-8") as Mov:
        for line in Mov:
            data = line.strip().split('::')

            Categories = data[2].split('|')
            Title = data[1]
                
            movies[Title] = Categories

    for Title in movies:
        for Category in movies[Title]:
            if  Category in categorised_movies.keys():
                categorised_movies[Category].append(Title)
            else: categorised_movies[Category] = [Title]
    with open("first_user_search_of_movie_sample.txt", "w", encoding="utf-8") as searched_movie_sample:
        for Category in categorised_movies:
            movies_str = '|'.join(categorised_movies[Category])
            searched_movie_sample.write(f"{Category}::{movies_str}\n")
#------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
def movie_sample(S, f):
    final_movies = dict()
    Movies = list()
    if f ==0:
        handling_movie_sample()

    with open("first_user_search_of_movie_sample.txt", "r", encoding="utf-8") as searched_movie_sample:
        for line in searched_movie_sample:
            data = line.strip().split('::')

            Category = data[0]
            Movies = data[1].split('|')
            final_movies[Category] = Movies

    for Category in final_movies:
        size = math.ceil(int((S/100)*len(final_movies[Category])))
        final_movies[Category] = final_movies[Category][:size]
        print("Category:", Category, "Movies:", final_movies[Category], "\n")

    Sigma = f"movie_sample_{S}.txt"

    with open(Sigma, "w", encoding="utf-8") as new_entry:
        for Category in final_movies:
            movies_str = ', '.join(final_movies[Category])
            new_entry.write(f"Category: {Category}, Movies: {movies_str}\n")

###################################################################################################################################################################################
###-----------------------------------------------------------------------------------COSINE SIMILARITY---------------------------------------------------------------------------------
###################################################################################################################################################################################
def handling_cosine():
    users_with_same_movies = dict()
    users = dict()
    user_movies = dict()
    cosine_users = dict()

    with open("ratings.dat","r") as ratings:
        for line in ratings:
            data = line.strip().split('::')

            UserID = data[0]
            MovieID = data[1]
            Rating = float(data[2])
            
            if UserID not in users:
                users[UserID] = []
            rating_entry = {MovieID: Rating}
            users[UserID].append(rating_entry)

            if UserID not in user_movies:
                user_movies[UserID] = []
            user_movies[UserID].append(MovieID)

    common_user_ids = list(set(users.keys()))
    selected_user_ids = random.sample(common_user_ids, 100)

    trimmed_users = {user_id: users[user_id] for user_id in selected_user_ids}
    trimmed_user_movies = {user_id: user_movies[user_id] for user_id in selected_user_ids}

    for UserID1 in trimmed_user_movies:
        for UserID2 in trimmed_user_movies:
            if UserID1 != UserID2: 
                common_movies = [movie for movie in trimmed_user_movies[UserID1] if movie in trimmed_user_movies[UserID2]]

                if len(common_movies) != 0:
                    if (UserID1, UserID2) not in users_with_same_movies:
                        if (UserID2, UserID1) not in users_with_same_movies:
                            users_with_same_movies[(UserID1, UserID2)] = []

                            for MovieID in common_movies:
                                users_with_same_movies[(UserID1, UserID2)].append(MovieID)
    

    for (UserID1, UserID2) in users_with_same_movies:
        cos_similar = 0
        sum_cos_sim_nominator = 0
        sum_cos_sim_denominator_user1 = 0
        sum_cos_sim_denominator_user2 = 0

        for MovieID in users_with_same_movies[(UserID1, UserID2)]:

            ratings_user1 = {list(movie.keys())[0]: list(movie.values())[0] for movie in trimmed_users[UserID1]}

            rating1 = 0
            for rating_entry in trimmed_users[UserID1]:
                rating1 = ratings_user1.get(MovieID, 0)

            ratings_user2 = {list(movie.keys())[0]: list(movie.values())[0] for movie in trimmed_users[UserID2]}

            rating2 = 0
            for rating_entry in trimmed_users[UserID2]:
                rating2 = ratings_user2.get(MovieID, 0)

            sum_cos_sim_nominator += rating1*rating2
            sum_cos_sim_denominator_user1 += rating1**2
            sum_cos_sim_denominator_user2 += rating2**2

        cos_similar = sum_cos_sim_nominator/(math.sqrt(sum_cos_sim_denominator_user1)*math.sqrt(sum_cos_sim_denominator_user2)) if (math.sqrt(sum_cos_sim_denominator_user1)*math.sqrt(sum_cos_sim_denominator_user2))!=0 else 0

        cosine_users[(UserID1, UserID2)] = cos_similar

    sorted_users = sorted(cosine_users.items(), key=lambda x: x[1], reverse=True)

    with open("first_user_search_of_cosine.txt", "w", encoding="utf-8") as searched_cosine:
        for ((UserID1, UserID2), similarity) in sorted_users:
            searched_cosine.write(f"{UserID1, UserID2}::{similarity}\n")

#-----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
def cosine_similarity(Thetta, g):
    cosine_users = dict()
    if g==0:
        handling_cosine()

    with open("first_user_search_of_cosine.txt", "r", encoding="utf-8") as searched_cosine:
        for line in searched_cosine:
            data = line.strip().split('::')

            pair = data[0]
            similarity = float(data[1])
            cosine_users[pair] = similarity

    final_cosine_users = dict()
    for pair in cosine_users:
        if cosine_users[pair] >= Thetta:
            final_cosine_users[pair] = cosine_users[pair]

    for pair in final_cosine_users:
        print("Users:", pair, "Cosine Similarity:", final_cosine_users[pair], "\n")

    Cos = f"similar_users_{Thetta}.txt"

    with open(Cos, "w", encoding="utf-8") as new_entry:
        for pair in final_cosine_users:
            new_entry.write(f"Users: {pair}, Similarity: {final_cosine_users[pair]}\n")
###################################################################################################################################################################################
###-----------------------------------------------------------------------------------DOMINANCE---------------------------------------------------------------------------------
###################################################################################################################################################################################
def dominance(h):
    if h == 1:
        prints = list()
        with open("dominance.txt", "r", encoding="utf-8") as prev_entry:
                for line in prev_entry:
                    prints.append(line+"\n")
        for i in prints:
            print(i)
        return

    movies_that_are_not_dominated = dict()
    average_ratings = dict()
    movies = dict()

    with open("movies.dat","r", encoding="utf-8") as Mov:
        for line in Mov:
            data = line.strip().split('::')

            MovieID = data[0]
            Title = data[1]
            
            movies[MovieID] = Title

    with open("ratings.dat","r") as ratings:
        for line in ratings:
            data = line.strip().split('::')

            MovieID = data[1]
            Rating = float(data[2])
            
            if MovieID in average_ratings:
                average_ratings[MovieID]['Total_Rating'] +=Rating
                average_ratings[MovieID]['Count'] += 1
            else:
                average_ratings[MovieID] = {'Total_Rating': Rating, 'Count': 1}

    for MovieID in movies:
        if MovieID in average_ratings.keys():
            Title = movies[MovieID]
            average_rating = average_ratings[MovieID]['Total_Rating']/average_ratings[MovieID]['Count']
            count = average_ratings[MovieID]['Count']
            movies_that_are_not_dominated[Title] = [count, average_rating]
            for MovieID2 in movies:
                if MovieID2!=MovieID:
                    if MovieID2 in average_ratings.keys():
                        average_rating2 = average_ratings[MovieID2]['Total_Rating']/average_ratings[MovieID2]['Count']
                        count2 = average_ratings[MovieID2]['Count']
                        if average_rating2 >= average_rating and count2>=count:
                            del movies_that_are_not_dominated[Title]
                            break;

    for Title in movies_that_are_not_dominated:
        count, average_rating = movies_that_are_not_dominated[Title]
        print("Movie Title:", Title, "Average Rating:", average_rating, "Total Votes:", count, "\n") 

    with open("dominance.txt", "w", encoding="utf-8") as dom:
        for Title in movies_that_are_not_dominated:
            count, average_rating = movies_that_are_not_dominated[Title]
            dom.write(f"Movie Title: {Title}, Average Rating: {average_rating}, Total Votes: {count}\n")
###################################################################################################################################################################################
###-----------------------------------------------------------------------------------CALL PREVIOUS ENTRIES---------------------------------------------------------------------------------
###################################################################################################################################################################################  
def call_previous_entries(a, b, c):
    prints = list()
    a_b_c = f"{a}_{b}_{c}.txt"
    with open(a_b_c, "r", encoding="utf-8") as prev_entry:
            for line in prev_entry:
                prints.append(line+"\n")
    for i in prints:
        print(i)

def call_previous_entries2(a, b):
    prints = list()
    a_b = f"{a}_{b}.txt"
    with open(a_b, "r", encoding="utf-8") as prev_entry:
            for line in prev_entry:
                prints.append(line+"\n")
    for i in prints:
        print(i)

def check_if_previous_entry_exists(prev_entries, key, b, c):
    for entry in prev_entries:
        if key in entry:
            if c is None:
                if entry[key] == b:
                    return False
            else:
                if entry[key] == [b,c]:
                   return False       
    return True
###################################################################################################################################################################################
###-----------------------------------------------------------------------------------MAIN---------------------------------------------------------------------------------
###################################################################################################################################################################################
def main():
    a = 0
    b = 0
    c = 0
    d = 0
    e = 0
    f = 0
    g = 0
    h = 0
    previous_entries = list()
    last_10_inputs = dict()
    new_entry = False
    while(True):
        print("\nChoose\n\n 1) rating T1 T2: find all movies with rating between T1 and T2\n\n 2) top_movies K: find all movies with rating over K \n\n 3) user_pairs K: find all user pairs that have given rating to the same movie\n\n\
 4) dominance: find users that aren't dominated from other movies\n\n 5) iceberg K T: find movies that have been rated at least K times with average score over T\n\n 6) top_user K: find the K users that have rated the most movies\n\n\
 7) movie_sample S: find a percentage of movies from all categories\n\n 8) similar_users Θ: find users that have similar tastes in movies based on cosine similarity\n\n 9) S to stop\n\n")
        mode = [i for i in input(" ").split(' ')]

        if mode[0] == "S":
            break;
#-----------------------------------------------------------------------------------------------------------------------------------------------------------------
        if mode[0] == "rating":

            new_entry = check_if_previous_entry_exists(previous_entries, mode[0], mode[1], mode[2])
            if(new_entry):
                find_movies_between_T1_T2(float(mode[1]), float(mode[2]), a)
            else:
                call_previous_entries(mode[0], float(mode[1]), float(mode[2]))
            a = 1
#-----------------------------------------------------------------------------------------------------------------------------------------------------------------
        elif mode[0] == "top_movies":

            new_entry = check_if_previous_entry_exists(previous_entries, mode[0], mode[1], None)
            if(new_entry):
                find_top_movies(int(mode[1]), b)
            else:
                call_previous_entries2(mode[0], int(mode[1]))
            b = 1
#-----------------------------------------------------------------------------------------------------------------------------------------------------------------
        elif mode[0]== "user_pairs":

            new_entry = check_if_previous_entry_exists(previous_entries, mode[0], mode[1], None)
            if(new_entry):
                find_user_pairs(int(mode[1]), c)
            else:
                call_previous_entries2(mode[0], int(mode[1]))
            c = 1
#-----------------------------------------------------------------------------------------------------------------------------------------------------------------
        elif mode[0]== "iceberg":

            new_entry = check_if_previous_entry_exists(previous_entries, mode[0], mode[1], mode[2]) 
            if(new_entry):
                iceberg(int(mode[1]), float(mode[2]), d)
            else:
                call_previous_entries(mode[0], int(mode[1]), float(mode[2]))
                d = 1
#-----------------------------------------------------------------------------------------------------------------------------------------------------------------
        elif mode[0]== "top_user":

            new_entry = check_if_previous_entry_exists(previous_entries, mode[0], mode[1], None)
            if(new_entry):
                top_users(int(mode[1]), e)
            else:
                call_previous_entries2(mode[0], int(mode[1]))
            e = 1
#-----------------------------------------------------------------------------------------------------------------------------------------------------------------
        elif mode[0]== "movie_sample":

            new_entry = check_if_previous_entry_exists(previous_entries, mode[0], mode[1], None)
            if(new_entry):
                movie_sample(int(mode[1]), f)
            else:
                call_previous_entries2(mode[0], int(mode[1]))
            f = 1
#-----------------------------------------------------------------------------------------------------------------------------------------------------------------
        elif mode[0]== "similar_users":

            new_entry = check_if_previous_entry_exists(previous_entries, mode[0], mode[1], None)
            if(new_entry):
                cosine_similarity(float(mode[1]), g)
            else:
                call_previous_entries2(mode[0], float(mode[1]))
            g = 1
#-----------------------------------------------------------------------------------------------------------------------------------------------------------------
        elif mode[0]== "dominance":
            dominance(h)
            h = 1
#-----------------------------------------------------------------------------------------------------------------------------------------------------------------
        else : 
            print("not a choice, choose again")
            new_entry = False

        if(new_entry):
            if len(last_10_inputs)<10:
                if len(mode)==2:
                    last_10_inputs[mode[0]] = mode[1]
                elif len(mode)== 3:
                    last_10_inputs[mode[0]] = [mode[1], mode[2]]
            previous_entries.append({mode[0]: last_10_inputs[mode[0]]})
            print(previous_entries)

if __name__ == "__main__":
    main()
# Out:
# Choose
#
#  1) rating T1 T2: find all movies with rating between T1 and T2
#
#  2) top_movies K: find all movies with rating over K
#
#  3) user_pairs K: find all user pairs that have given rating to the same movie
#
#  4) dominance: find users that aren't dominated from other movies
#
#  5) iceberg K T: find movies that have been rated at least K times with average score over T
#
#  6) top_user K: find the K users that have rated the most movies
#
#  7) movie_sample S: find a percentage of movies from all categories
#
#  8) similar_users Θ: find users that have similar tastes in movies based on cosine similarity
#
#  9) S to stop
#
#
# Movie Title: Satan's Tango (Sátántangó) (1994) Average Rating: 5.0
#
# Movie Title: Shadows of Forgotten Ancestors (1964) Average Rating: 5.0
#
# Movie Title: Fighting Elegy (Kenka erejii) (1966) Average Rating: 5.0
#
# Movie Title: Sun Alley (Sonnenallee) (1999) Average Rating: 5.0
#
# Movie Title: Blue Light, The (Das Blaue Licht) (1932) Average Rating: 5.0
#
# [{'rating': ['4.9', '5']}]
#
# Choose
#
#  1) rating T1 T2: find all movies with rating between T1 and T2
#
#  2) top_movies K: find all movies with rating over K
#
#  3) user_pairs K: find all user pairs that have given rating to the same movie
#
#  4) dominance: find users that aren't dominated from other movies
#
#  5) iceberg K T: find movies that have been rated at least K times with average score over T
#
#  6) top_user K: find the K users that have rated the most movies
#
#  7) movie_sample S: find a percentage of movies from all categories
#
#  8) similar_users Θ: find users that have similar tastes in movies based on cosine similarity
#
#  9) S to stop

# %%
import cProfile

cProfile.run("find_movies_between_T1_T2(2.0, 2.2, 0)")
cProfile.run("find_movies_between_T1_T2(2.1, 2.2, 1)")

cProfile.run("check_if_previous_entry_exists([{'rating': ['2.0', '2.2']}], 'rating', 2.0, 2.2)")
cProfile.run("call_previous_entries('rating', 2.0, 2.2)")



cProfile.run("find_top_movies(10, 0)")
cProfile.run("find_top_movies(9, 1)")

cProfile.run("find_user_pairs(7, 0)")
cProfile.run("find_user_pairs(6, 1)")

cProfile.run("dominance(0)")
cProfile.run("dominance(1)")

cProfile.run("iceberg(100, 4, 0)")
cProfile.run("iceberg(95, 4, 1)")

cProfile.run("top_users(5, 0)")
cProfile.run("top_users(4, 1)")

cProfile.run("movie_sample(20, 0)")
cProfile.run("movie_sample(30, 1)")

cProfile.run("cosine_similarity(0.97, 0)")
cProfile.run("cosine_similarity(0.99, 1)")
# Out:
# Movie Title: Lawnmower Man 2: Beyond Cyberspace (1996) Average Rating: 2.132411067193676
#
# Movie Title: Beyond Bedlam (1993) Average Rating: 2.1160714285714284
#
# Movie Title: Nemesis 2: Nebula (1995) Average Rating: 2.108695652173913
#
# Movie Title: Fear, The (1995) Average Rating: 2.018181818181818
#
# Movie Title: Girl in the Cadillac (1995) Average Rating: 2.1875
#
#
# Movie Title: Delta Farce (2007) Average Rating: 2.0416666666666665
#
# Movie Title: Daddy Day Camp (2007) Average Rating: 2.0972222222222223
#
# Movie Title: Illegal Tender (2007) Average Rating: 2.2
#
# Movie Title: Comebacks, The (2007) Average Rating: 2.1363636363636362
#
# Movie Title: Rails & Ties (2007) Average Rating: 2.0
#
# Movie Title: Welcome Home, Roscoe Jenkins (2008) Average Rating: 2.130434782608696
#
# Movie Title: Klimt (2006) Average Rating: 2.05
#
# Movie Title: Fly Me to the Moon (2008) Average Rating: 2.0625
#
# Movie Title: 100 Feet (2008) Average Rating: 2.0
#
# Movie Title: Moonbase (1998) Average Rating: 2.0
#
# Movie Title: Alone In The Dark II (2008) Average Rating: 2.0833333333333335
#
# Movie Title: Fallout (1998) Average Rating: 2.0
#
# Movie Title: Rockin' in the Rockies (1945) Average Rating: 2.0
#
# Movie Title: Gold Raiders (1951) Average Rating: 2.0
#
# Movie Title: Dirty Dozen: The Deadly Mission (1987) Average Rating: 2.0
#
# Movie Title: Fireproof (2008) Average Rating: 2.0
#
# Movie Title: Guyver, The (1991) Average Rating: 2.0
#
# Movie Title: Ace of Hearts (2008) Average Rating: 2.0
#
# Movie Title: Delgo (2008) Average Rating: 2.0
#
# Movie Title: Double Dynamite (1951) Average Rating: 2.0
#
#          20148775 function calls in 27.857 seconds
#
#    Ordered by: standard name
#
#    ncalls  tottime  percall  cumtime  percall filename:lineno(function)
#         1    0.035    0.035   27.857   27.857 3755690528.py:48(find_movies_between_T1_T2)
#         1   20.983   20.983   27.710   27.710 3755690528.py:8(data_handling_ratings)
#         1    0.000    0.000   27.857   27.857 <string>:1(<module>)
#         1    0.000    0.000    0.000    0.000 _bootlocale.py:11(getpreferredencoding)
#         2    0.000    0.000    0.000    0.000 codecs.py:186(__init__)
#         3    0.000    0.000    0.000    0.000 codecs.py:260(__init__)
#         2    0.000    0.000    0.000    0.000 codecs.py:309(__init__)
#       126    0.001    0.000    0.002    0.000 codecs.py:319(decode)
#     32363    0.054    0.000    0.996    0.000 cp1253.py:22(decode)
#         5    0.000    0.000    0.091    0.018 interactiveshell.py:275(_modified_open)
#         1    0.000    0.000    0.000    0.000 iostream.py:137(_event_pipe)
#         1    0.000    0.000    0.000    0.000 iostream.py:258(schedule)
#      2720    0.001    0.000    0.002    0.000 iostream.py:519(_is_master_process)
#      2720    0.001    0.000    0.001    0.000 iostream.py:546(_schedule_flush)
#      2720    0.007    0.000    0.011    0.000 iostream.py:624(write)
#         1    0.000    0.000    0.000    0.000 socket.py:621(send)
#         1    0.000    0.000    0.000    0.000 threading.py:1017(_wait_for_tstate_lock)
#         1    0.000    0.000    0.000    0.000 threading.py:1071(is_alive)
#         1    0.000    0.000    0.000    0.000 threading.py:513(is_set)
#     32363    0.942    0.000    0.942    0.000 {built-in method _codecs.charmap_decode}
#       126    0.001    0.000    0.001    0.000 {built-in method _codecs.utf_8_decode}
#         1    0.000    0.000    0.000    0.000 {built-in method _locale._getdefaultlocale}
#         1    0.000    0.000   27.857   27.857 {built-in method builtins.exec}
#      2720    0.000    0.000    0.000    0.000 {built-in method builtins.isinstance}
#      2720    0.000    0.000    0.000    0.000 {built-in method builtins.len}
#       272    0.002    0.000    0.013    0.000 {built-in method builtins.print}
#         5    0.091    0.018    0.091    0.018 {built-in method io.open}
#      2720    0.000    0.000    0.000    0.000 {built-in method nt.getpid}
#         1    0.000    0.000    0.000    0.000 {method 'acquire' of '_thread.lock' objects}
#         1    0.000    0.000    0.000    0.000 {method 'append' of 'collections.deque' objects}
#         1    0.000    0.000    0.000    0.000 {method 'disable' of '_lsprof.Profiler' objects}
#     10683    0.002    0.000    0.002    0.000 {method 'keys' of 'dict' objects}
#  10021411    4.075    0.000    4.075    0.000 {method 'split' of 'str' objects}
#  10021411    1.645    0.000    1.645    0.000 {method 'strip' of 'str' objects}
#      2720    0.001    0.000    0.001    0.000 {method 'write' of '_io.StringIO' objects}
#     10948    0.014    0.000    0.014    0.000 {method 'write' of '_io.TextIOWrapper' objects}
#
# Movie Title: Sound of Thunder, A (2005) Average Rating: 2.1129032258064515
#
# Movie Title: Daddy's Dyin'... Who's Got the Will? (1990) Average Rating: 2.2
#
# Movie Title: Man Trouble (1992) Average Rating: 2.1875
#
# Movie Title: Rebound (2005) Average Rating: 2.1375
#
# Movie Title: Three Stooges Meet Hercules, The (1962) Average Rating: 2.1166666666666667
#
# Movie Title: Venom (2005) Average Rating: 2.1973684210526314
#
# Movie Title: HellBent (2004) Average Rating: 2.1666666666666665
#
# Movie Title: Basic Instinct 2 (2006) Average Rating: 2.1366459627329193
#
# Movie Title: Zoom (2006) Average Rating: 2.1818181818181817
#
# Movie Title: Material Girls (2006) Average Rating: 2.1818181818181817
#
# Movie Title: Happily N'Ever After (2007) Average Rating: 2.1777777777777776
#
# Movie Title: Kickin It Old Skool (2007) Average Rating: 2.2
#
# Movie Title: Illegal Tender (2007) Average Rating: 2.2
#
# Movie Title: Comebacks, The (2007) Average Rating: 2.1363636363636362
#
# Movie Title: Welcome Home, Roscoe Jenkins (2008) Average Rating: 2.130434782608696
#
#          31350 function calls in 0.047 seconds
#
#    Ordered by: standard name
#
#    ncalls  tottime  percall  cumtime  percall filename:lineno(function)
#         1    0.028    0.028    0.047    0.047 3755690528.py:48(find_movies_between_T1_T2)
#         1    0.000    0.000    0.047    0.047 <string>:1(<module>)
#         1    0.000    0.000    0.000    0.000 codecs.py:186(__init__)
#         1    0.000    0.000    0.000    0.000 codecs.py:260(__init__)
#         1    0.000    0.000    0.000    0.000 codecs.py:309(__init__)
#        61    0.000    0.000    0.001    0.000 codecs.py:319(decode)
#         2    0.000    0.000    0.001    0.001 interactiveshell.py:275(_modified_open)
#      1370    0.001    0.000    0.001    0.000 iostream.py:519(_is_master_process)
#      1370    0.001    0.000    0.001    0.000 iostream.py:546(_schedule_flush)
#      1370    0.005    0.000    0.008    0.000 iostream.py:624(write)
#        61    0.001    0.000    0.001    0.000 {built-in method _codecs.utf_8_decode}
#         1    0.000    0.000    0.047    0.047 {built-in method builtins.exec}
#      1370    0.000    0.000    0.000    0.000 {built-in method builtins.isinstance}
#      1370    0.000    0.000    0.000    0.000 {built-in method builtins.len}
#       137    0.002    0.000    0.009    0.000 {built-in method builtins.print}
#         2    0.001    0.001    0.001    0.001 {built-in method io.open}
#      1370    0.000    0.000    0.000    0.000 {built-in method nt.getpid}
#         1    0.000    0.000    0.000    0.000 {method 'disable' of '_lsprof.Profiler' objects}
#         1    0.000    0.000    0.000    0.000 {method 'keys' of 'dict' objects}
#     10676    0.004    0.000    0.004    0.000 {method 'split' of 'str' objects}
#     10676    0.002    0.000    0.002    0.000 {method 'strip' of 'str' objects}
#      1370    0.000    0.000    0.000    0.000 {method 'write' of '_io.StringIO' objects}
#       137    0.000    0.000    0.000    0.000 {method 'write' of '_io.TextIOWrapper' objects}
#
#
# {'rating': ['2.0', '2.2']}
#
#
#          33 function calls in 0.000 seconds
#
#    Ordered by: standard name
#
#    ncalls  tottime  percall  cumtime  percall filename:lineno(function)
#         1    0.000    0.000    0.000    0.000 3755690528.py:567(check_if_previous_entry_exists)
#         1    0.000    0.000    0.000    0.000 <string>:1(<module>)
#         4    0.000    0.000    0.000    0.000 iostream.py:519(_is_master_process)
#         4    0.000    0.000    0.000    0.000 iostream.py:546(_schedule_flush)
#         4    0.000    0.000    0.000    0.000 iostream.py:624(write)
#         1    0.000    0.000    0.000    0.000 {built-in method builtins.exec}
#         4    0.000    0.000    0.000    0.000 {built-in method builtins.isinstance}
#         4    0.000    0.000    0.000    0.000 {built-in method builtins.len}
#         1    0.000    0.000    0.000    0.000 {built-in method builtins.print}
#         4    0.000    0.000    0.000    0.000 {built-in method nt.getpid}
#         1    0.000    0.000    0.000    0.000 {method 'disable' of '_lsprof.Profiler' objects}
#         4    0.000    0.000    0.000    0.000 {method 'write' of '_io.StringIO' objects}
#
#
# Movie Title: Lawnmower Man 2: Beyond Cyberspace (1996), Average Rating: 2.132411067193676
#
#
# Movie Title: Beyond Bedlam (1993), Average Rating: 2.1160714285714284
#
#
# Movie Title: Nemesis 2: Nebula (1995), Average Rating: 2.108695652173913
#
#
# Movie Title: Fear, The (1995), Average Rating: 2.018181818181818
#
#
# Movie Title: Girl in the Cadillac (1995), Average Rating: 2.1875
#
#
# Movie Title: Two Crimes (Dos crímenes) (1995), Average Rating: 2.0555555555555554
#
#
# Movie Title: House Party 3 (1994), Average Rating: 2.175373134328358
#
#
# Movie Title: RoboCop 3 (1993), Average Rating: 2.1861480075901327
#
#
# Movie Title: Super Mario Bros. (1993), Average Rating: 2.0479274611398965
#
# Users: ('32439', '12484') Cosine Similarity: 0.9942205873301891
#
# Users: ('68970', '63598') Cosine Similarity: 0.9941988596598869
#
# Users: ('61918', '53223') Cosine Similarity: 0.9941724026247171
#
# Users: ('59215', '25238') Cosine Similarity: 0.9941405190041337
#
# Users: ('51352', '59215') Cosine Similarity: 0.9941348467724345
#
# Users: ('59215', '43471') Cosine Similarity: 0.9941348467724345
#
# Users: ('11639', '32241') Cosine Similarity: 0.9941348467724342
#
# Users: ('65616', '61654') Cosine Similarity: 0.9941348467724341
#
# Users: ('2319', '3593') Cosine Similarity: 0.9941348467724341
#
# Users: ('67586', '52876') Cosine Similarity: 0.9941348467724341
#
# Users: ('11842', '1122') Cosine Similarity: 0.9940854542079095
#
# Users: ('67800', '4877') Cosine Similarity: 0.9940561506727967
#
# Users: ('51352', '47774') Cosine Similarity: 0.994034023300906
#
# Users: ('67438', '65616') Cosine Similarity: 0.9940251572134323
#
# Users: ('25099', '37447') Cosine Similarity: 0.9940150117686348
#
# Users: ('19402', '41631') Cosine Similarity: 0.9939990885479664
#
# Users: ('61654', '4877') Cosine Similarity: 0.9939809379278567
#
# Users: ('42157', '22389') Cosine Similarity: 0.9939022980510657
#
# Users: ('51927', '65905') Cosine Similarity: 0.9938921079824063
#
# Users: ('62444', '67603') Cosine Similarity: 0.9938837346736189
#
# Users: ('65616', '66897') Cosine Similarity: 0.9938837346736189
#
# Users: ('65616', '43471') Cosine Similarity: 0.9938837346736189
#
# Users: ('65616', '6382') Cosine Similarity: 0.9938837346736189
#
# Users: ('59215', '13620') Cosine Similarity: 0.9938837346736189
#
# Users: ('66897', '63598') Cosine Similarity: 0.9938837346736189
#
# Users: ('66897', '3225') Cosine Similarity: 0.9938837346736189
#
# Users: ('25099', '43885') Cosine Similarity: 0.9938837346736189
#
# Users: ('33466', '46084') Cosine Similarity: 0.9938837346736189
#
# Users: ('33466', '30271') Cosine Similarity: 0.9938837346736189
#
# Users: ('63598', '43471') Cosine Similarity: 0.9938837346736189
#
# Users: ('43471', '3225') Cosine Similarity: 0.9938837346736189
#
# Users: ('44701', '41631') Cosine Similarity: 0.9938837346736189
#
# Users: ('17176', '4877') Cosine Similarity: 0.9938837346736189
#
# Users: ('51927', '69434') Cosine Similarity: 0.9938837346736189
#
# Users: ('51440', '47116') Cosine Similarity: 0.9938837346736189
#
# Users: ('47774', '46766') Cosine Similarity: 0.9938837346736189
#
# Users: ('5756', '68490') Cosine Similarity: 0.9938837346736189
#
# Users: ('51352', '11639') Cosine Similarity: 0.9938837346736188
#
# Users: ('67438', '13901') Cosine Similarity: 0.9938837346736188
#
# Users: ('62444', '2319') Cosine Similarity: 0.9938837346736188
#
# Users: ('65616', '4877') Cosine Similarity: 0.9938837346736188
#
# Users: ('65616', '32439') Cosine Similarity: 0.9938837346736188
#
# Users: ('65616', '1122') Cosine Similarity: 0.9938837346736188
#
# Users: ('61654', '22389') Cosine Similarity: 0.9938837346736188
#
# Users: ('61654', '41631') Cosine Similarity: 0.9938837346736188
#
# Users: ('2319', '3225') Cosine Similarity: 0.9938837346736188
#
# Users: ('2319', '52876') Cosine Similarity: 0.9938837346736188
#
# Users: ('59215', '46055') Cosine Similarity: 0.9938837346736188
#
# Users: ('59215', '13901') Cosine Similarity: 0.9938837346736188
#
# Users: ('25099', '41631') Cosine Similarity: 0.9938837346736188
#
# Users: ('25099', '42694') Cosine Similarity: 0.9938837346736188
#
# Users: ('25099', '1122') Cosine Similarity: 0.9938837346736188
#
# Users: ('63598', '48778') Cosine Similarity: 0.9938837346736188
#
# Users: ('63598', '20666') Cosine Similarity: 0.9938837346736188
#
# Users: ('11639', '16516') Cosine Similarity: 0.9938837346736188
#
# Users: ('11639', '1122') Cosine Similarity: 0.9938837346736188
#
# Users: ('11639', '13620') Cosine Similarity: 0.9938837346736188
#
# Users: ('16923', '5756') Cosine Similarity: 0.9938837346736188
#
# Users: ('30271', '1122') Cosine Similarity: 0.9938837346736188
#
# Users: ('67603', '47774') Cosine Similarity: 0.9938837346736188
#
# Users: ('21328', '20666') Cosine Similarity: 0.9938837346736188
#
# Users: ('12612', '51440') Cosine Similarity: 0.9938837346736188
#
# Users: ('37777', '46766') Cosine Similarity: 0.9938837346736188
#
# Users: ('7321', '42694') Cosine Similarity: 0.9938837346736188
#
# Users: ('42694', '46202') Cosine Similarity: 0.9938837346736188
#
# Users: ('67586', '46766') Cosine Similarity: 0.9938837346736188
#
# Users: ('3225', '1122') Cosine Similarity: 0.9938837346736188
#
# Users: ('61863', '37447') Cosine Similarity: 0.9938624437403927
#
# Users: ('46055', '4877') Cosine Similarity: 0.993848322297969
#
# Users: ('62444', '20519') Cosine Similarity: 0.9938329312078087
#
# Users: ('67603', '69434') Cosine Similarity: 0.9938276458179878
#
# Users: ('42694', '69434') Cosine Similarity: 0.9938249838352888
#
# Users: ('67800', '34673') Cosine Similarity: 0.9938160045481543
#
# Users: ('51352', '16516') Cosine Similarity: 0.9938089250137583
#
# Users: ('68970', '67603') Cosine Similarity: 0.9938089250137583
#
# Users: ('11639', '4877') Cosine Similarity: 0.9938089250137583
#
# Users: ('67603', '3593') Cosine Similarity: 0.9938089250137583
#
# Users: ('33466', '12612') Cosine Similarity: 0.9938082266659076
#
# Users: ('68970', '8894') Cosine Similarity: 0.9937900648430849
#
# Users: ('67438', '44266') Cosine Similarity: 0.9937419004615499
#
# Users: ('8894', '20519') Cosine Similarity: 0.9937123853151454
#
# Users: ('67800', '47008') Cosine Similarity: 0.9936607918964554
#
# Users: ('65616', '37777') Cosine Similarity: 0.9935997814080723
#
# Users: ('51352', '52876') Cosine Similarity: 0.9935983409176492
#
# Users: ('63598', '47774') Cosine Similarity: 0.9935983409176492
#
# Users: ('61654', '21328') Cosine Similarity: 0.9935690651280802
#
# Users: ('25099', '67603') Cosine Similarity: 0.9935591240195244
#
# Users: ('11639', '20666') Cosine Similarity: 0.9935591240195244
#
# Users: ('47008', '37447') Cosine Similarity: 0.9934991184909865
#
# Users: ('61654', '52876') Cosine Similarity: 0.9934700592472275
#
# Users: ('67438', '4877') Cosine Similarity: 0.9934156325097109
#
# Users: ('59215', '44701') Cosine Similarity: 0.9933992677987828
#
# Users: ('66262', '61863') Cosine Similarity: 0.9933347483150406
#
# Users: ('67800', '57721') Cosine Similarity: 0.9932918674776086
#
# Users: ('33466', '25238') Cosine Similarity: 0.9932793493858211
#
# Users: ('19402', '12484') Cosine Similarity: 0.9932659166648444
#
# Users: ('67800', '24981') Cosine Similarity: 0.9932179078214068
#
# Users: ('59215', '41561') Cosine Similarity: 0.9931947280652309
#
# Users: ('22389', '25238') Cosine Similarity: 0.9931893081707521
#
# Users: ('62444', '67800') Cosine Similarity: 0.9931190164323375
#
# Users: ('61654', '69434') Cosine Similarity: 0.9931084046135705
#
# Users: ('65280', '47116') Cosine Similarity: 0.9930923628348838
#
# Users: ('37777', '53223') Cosine Similarity: 0.9929921334885683
#
# Users: ('38465', '57721') Cosine Similarity: 0.9929145645409454
#
# Users: ('37777', '57721') Cosine Similarity: 0.9929145645409454
#
# Users: ('38465', '3593') Cosine Similarity: 0.992868342625318
#
# Users: ('51352', '44266') Cosine Similarity: 0.9928511279172315
#
# Users: ('68662', '37777') Cosine Similarity: 0.9928377679927978
#
# Users: ('66262', '59215') Cosine Similarity: 0.9928263549125705
#
# Users: ('67438', '1122') Cosine Similarity: 0.9927833793423579
#
# Users: ('69434', '13620') Cosine Similarity: 0.9927809602765956
#
# Users: ('41631', '3593') Cosine Similarity: 0.9927789747206317
#
# Users: ('66262', '4877') Cosine Similarity: 0.9927525666213401
#
# Users: ('34673', '12612') Cosine Similarity: 0.9927337820337083
#
# Users: ('20519', '28180') Cosine Similarity: 0.9927191833295314
#
# Users: ('41561', '37777') Cosine Similarity: 0.9925772324531892
#
# Users: ('67438', '63598') Cosine Similarity: 0.9925731535768358
#
# Users: ('53223', '28180') Cosine Similarity: 0.9925563742332215
#
# Users: ('13620', '37447') Cosine Similarity: 0.992302227284342
#
# Users: ('61573', '47116') Cosine Similarity: 0.9922778767136679
#
# Users: ('2319', '43885') Cosine Similarity: 0.9922778767136677
#
# Users: ('61863', '28372') Cosine Similarity: 0.9922778767136677
#
# Users: ('12612', '58446') Cosine Similarity: 0.9922778767136675
#
# Users: ('61654', '37777') Cosine Similarity: 0.992245986193717
#
# Users: ('11842', '29829') Cosine Similarity: 0.992245986193717
#
# Users: ('22389', '69434') Cosine Similarity: 0.9922451545282034
#
# Users: ('32439', '3225') Cosine Similarity: 0.9922426389474776
#
# Users: ('30271', '16516') Cosine Similarity: 0.9922418140388011
#
# Users: ('61654', '41561') Cosine Similarity: 0.9922234336909898
#
# Users: ('61918', '69434') Cosine Similarity: 0.9921922342421284
#
# Users: ('61654', '32241') Cosine Similarity: 0.9921707776637603
#
# Users: ('17176', '32439') Cosine Similarity: 0.9921707776637603
#
# Users: ('46766', '13901') Cosine Similarity: 0.9921707776637603
#
# Users: ('51352', '66262') Cosine Similarity: 0.9921586340434404
#
# Users: ('24981', '3593') Cosine Similarity: 0.9921586340434404
#
# Users: ('57721', '46202') Cosine Similarity: 0.9921567416492215
#
# Users: ('62652', '33877') Cosine Similarity: 0.9921259842519686
#
# Users: ('11842', '46055') Cosine Similarity: 0.9921221397784366
#
# Users: ('22389', '47116') Cosine Similarity: 0.9921221397784366
#
# Users: ('47116', '3225') Cosine Similarity: 0.9921221397784366
#
# Users: ('66262', '53223') Cosine Similarity: 0.9920876373626927
#
# Users: ('43471', '3593') Cosine Similarity: 0.9920801195371076
#
# Users: ('2319', '6382') Cosine Similarity: 0.9920615134716334
#
# Users: ('63598', '33877') Cosine Similarity: 0.9920615134716334
#
# Users: ('63598', '13901') Cosine Similarity: 0.9920615134716334
#
# Users: ('67438', '25238') Cosine Similarity: 0.9919370234463435
#
# Users: ('11842', '58446') Cosine Similarity: 0.9919353522139877
#
# Users: ('58446', '5756') Cosine Similarity: 0.9918995010726926
#
# Users: ('68662', '53223') Cosine Similarity: 0.9918899418733107
#
# Users: ('37777', '20666') Cosine Similarity: 0.9918699186991868
#
# Users: ('62652', '53223') Cosine Similarity: 0.9918593620141785
#
# Users: ('59215', '33877') Cosine Similarity: 0.9918365981341757
#
# Users: ('61987', '37777') Cosine Similarity: 0.9918365981341757
#
# Users: ('65616', '17113') Cosine Similarity: 0.9918365981341756
#
# Users: ('57721', '6382') Cosine Similarity: 0.9918365981341756
#
# Users: ('8894', '47116') Cosine Similarity: 0.9918116082351268
#
# Users: ('11639', '65905') Cosine Similarity: 0.9917792471212079
#
# Users: ('61573', '8894') Cosine Similarity: 0.9917710199928012
#
# Users: ('61573', '20519') Cosine Similarity: 0.9917585651927013
#
# Users: ('30271', '68662') Cosine Similarity: 0.9916625347480467
#
# Users: ('59215', '32439') Cosine Similarity: 0.9916476588814594
#
# Users: ('61573', '1122') Cosine Similarity: 0.9916453075518487
#
# Users: ('43471', '53223') Cosine Similarity: 0.9916114825541849
#
# Users: ('38465', '58446') Cosine Similarity: 0.9915440975798361
#
# Users: ('62652', '52876') Cosine Similarity: 0.9914626884538711
#
# Users: ('61654', '11842') Cosine Similarity: 0.9913793103448277
#
# Users: ('61654', '46055') Cosine Similarity: 0.9913793103448277
#
# Users: ('11842', '16923') Cosine Similarity: 0.9913080679277559
#
# Users: ('48778', '12612') Cosine Similarity: 0.9912550060978257
#
# Users: ('61654', '19402') Cosine Similarity: 0.9911924311271048
#
# Users: ('61863', '53223') Cosine Similarity: 0.9911892555667042
#
# Users: ('62652', '12484') Cosine Similarity: 0.991144021188931
#
# Users: ('22389', '13901') Cosine Similarity: 0.991144021188931
#
# Users: ('61573', '29829') Cosine Similarity: 0.9909924304103233
#
# Users: ('61573', '43566') Cosine Similarity: 0.9909924304103233
#
# Users: ('11842', '43471') Cosine Similarity: 0.9909924304103233
#
# Users: ('61987', '20666') Cosine Similarity: 0.9909924304103233
#
# Users: ('29007', '20666') Cosine Similarity: 0.9909924304103233
#
# Users: ('24981', '14931') Cosine Similarity: 0.9909924304103233
#
# Users: ('38465', '13901') Cosine Similarity: 0.9909924304103233
#
# Users: ('32439', '46202') Cosine Similarity: 0.9909924304103233
#
# Users: ('67603', '7321') Cosine Similarity: 0.9909634628664253
#
# Users: ('48778', '69434') Cosine Similarity: 0.9909231273113827
#
# Users: ('16923', '28372') Cosine Similarity: 0.9908673886137244
#
# Users: ('53223', '4877') Cosine Similarity: 0.9908673886137244
#
# Users: ('25099', '33877') Cosine Similarity: 0.9908470001860921
#
# Users: ('51352', '16923') Cosine Similarity: 0.9908301680442991
#
# Users: ('11639', '51669') Cosine Similarity: 0.9908301680442991
#
# Users: ('48778', '53223') Cosine Similarity: 0.990802134645215
#
# Users: ('44701', '43885') Cosine Similarity: 0.9907642967559194
#
# Users: ('62444', '65941') Cosine Similarity: 0.9907388262447921
#
# Users: ('19402', '37777') Cosine Similarity: 0.9907370395414141
#
# Users: ('63598', '44701') Cosine Similarity: 0.9905360646879091
#
# Users: ('61654', '42157') Cosine Similarity: 0.9905126857976426
#
# Users: ('67586', '46202') Cosine Similarity: 0.9904348670716856
#
# Users: ('12612', '47116') Cosine Similarity: 0.9904048953654894
#
# Users: ('65280', '34673') Cosine Similarity: 0.9903879358478949
#
# Users: ('61654', '66262') Cosine Similarity: 0.9903638654290794
#
# Users: ('66262', '11842') Cosine Similarity: 0.990335613572201
#
# Users: ('32439', '1122') Cosine Similarity: 0.99028229600855
#
# Users: ('66262', '25099') Cosine Similarity: 0.9901475429766744
#
# Users: ('61987', '13901') Cosine Similarity: 0.9901475429766744
#
# Users: ('16516', '42694') Cosine Similarity: 0.9901475429766744
#
# Users: ('57721', '69434') Cosine Similarity: 0.9901475429766744
#
# Users: ('61573', '38465') Cosine Similarity: 0.9901475429766743
#
#          85657 function calls in 0.066 seconds
#
#    Ordered by: standard name
#
#    ncalls  tottime  percall  cumtime  percall filename:lineno(function)
#         1    0.008    0.008    0.061    0.061 3755690528.py:458(cosine_similarity)
#         1    0.000    0.000    0.062    0.062 <string>:1(<module>)
#         1    0.000    0.000    0.000    0.000 codecs.py:186(__init__)
#         1    0.000    0.000    0.000    0.000 codecs.py:260(__init__)
#         1    0.000    0.000    0.000    0.000 codecs.py:309(__init__)
#        21    0.000    0.000    0.000    0.000 codecs.py:319(decode)
#         2    0.000    0.000    0.005    0.003 interactiveshell.py:275(_modified_open)
#     10680    0.005    0.000    0.007    0.000 iostream.py:519(_is_master_process)
#     10680    0.002    0.000    0.002    0.000 iostream.py:546(_schedule_flush)
#     10680    0.024    0.000    0.039    0.000 iostream.py:624(write)
#        21    0.000    0.000    0.000    0.000 {built-in method _codecs.utf_8_decode}
#         1    0.004    0.004    0.066    0.066 {built-in method builtins.exec}
#     10680    0.002    0.000    0.002    0.000 {built-in method builtins.isinstance}
#     10680    0.002    0.000    0.002    0.000 {built-in method builtins.len}
#      1068    0.007    0.000    0.045    0.000 {built-in method builtins.print}
#         2    0.005    0.003    0.005    0.003 {built-in method io.open}
#     10680    0.002    0.000    0.002    0.000 {built-in method nt.getpid}
#         1    0.000    0.000    0.000    0.000 {method 'disable' of '_lsprof.Profiler' objects}
#      4354    0.001    0.000    0.001    0.000 {method 'split' of 'str' objects}
#      4354    0.000    0.000    0.000    0.000 {method 'strip' of 'str' objects}
#     10680    0.003    0.000    0.003    0.000 {method 'write' of '_io.StringIO' objects}
#      1068    0.002    0.000    0.002    0.000 {method 'write' of '_io.TextIOWrapper' objects}

# %%
# %%file prof_phase_2.py
import math
import random
from memory_profiler import profile
import gc

###################################################################################################################################################################################
###-----------------------------------------------------------------------------------RATING ---------------------------------------------------------------------------------
###################################################################################################################################################################################
def data_handling_ratings():

    filtered_ratings = dict()
    average_ratings = dict()
    movies = dict()

    with open("movies.dat","r", encoding="utf-8") as Mov:
            for line in Mov:
                data = line.strip().split('::')

                MovieID = data[0]
                Title = data[1]
                
                movies[MovieID] = Title

    with open("ratings.dat","r") as ratings:
        for line in ratings:
            data = line.strip().split('::')

            MovieID = data[1]
            Rating = float(data[2])
            
            if MovieID in average_ratings:
                average_ratings[MovieID]['Total_Rating'] +=Rating
                average_ratings[MovieID]['Count'] += 1
            else:
                average_ratings[MovieID] = {'Total_Rating': Rating, 'Count': 1}

    for MovieID in movies:
        if MovieID in average_ratings.keys():
            Title = movies[MovieID]
            average_rating = average_ratings[MovieID]['Total_Rating']/average_ratings[MovieID]['Count']
            filtered_ratings[Title] = average_rating

    with open("first_user_search_of_ratings.txt", "w", encoding="utf-8") as searched_ratings:
        for Title in filtered_ratings.keys():
            searched_ratings.write(Title +"::"+str(filtered_ratings[Title])+ '\n') 

#-------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
@profile
def find_movies_between_T1_T2(T1, T2, a):
    final_ratings = dict()

    if a == 0:
        data_handling_ratings()

    with open("first_user_search_of_ratings.txt", "r", encoding="utf-8") as searched_ratings:
            for line in searched_ratings:
                data = line.strip().split('::')

                Title = data[0]
                Rating = float(data[1])
                if T1 <= Rating <= T2:
                    final_ratings[Title] = Rating

    for Title in final_ratings:
        print("Movie Title:", Title, "Average Rating:", final_ratings[Title], "\n")

    T1_T2_a = f"rating_{T1}_{T2}.txt"

    with open(T1_T2_a, "w", encoding="utf-8") as new_entry:
        for Title in final_ratings.keys():
            new_entry.write(f"Movie Title: {Title}, Average Rating: {final_ratings[Title]}\n")
    gc.collect
###################################################################################################################################################################################
###-----------------------------------------------------------------------------------TOP MOVIES ---------------------------------------------------------------------------------
###################################################################################################################################################################################

def data_handling_top_movies():

    filtered_ratings = dict()
    average_ratings = dict()
    movies = dict()

    with open("movies.dat","r", encoding="utf-8") as Mov:
        for line in Mov:
            data = line.strip().split('::')

            MovieID = data[0]
            Title = data[1]
            
            movies[MovieID] = Title

    with open("ratings.dat","r") as ratings:
        for line in ratings:
            data = line.strip().split('::')

            MovieID = data[1]
            Rating = float(data[2])
            
            if MovieID in average_ratings:
                average_ratings[MovieID]['Total_Rating'] +=Rating
                average_ratings[MovieID]['Count'] += 1
            else:
                average_ratings[MovieID] = {'Total_Rating': Rating, 'Count': 1}
        
    for MovieID in movies:
        if MovieID in average_ratings.keys():
            Title = movies[MovieID]
            average_rating = average_ratings[MovieID]['Total_Rating']/average_ratings[MovieID]['Count']
            filtered_ratings[Title] = average_rating

    with open("first_top_movies_search.txt", "w", encoding="utf-8") as searched_top_movies:
        for Title in filtered_ratings.keys():
            searched_top_movies.write(Title +"::"+str(filtered_ratings[Title])+ '\n')

#---------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
@profile
def find_top_movies(K, b): 
    filtered_ratings = dict()

    if b == 0:
        data_handling_top_movies()

    with open("first_top_movies_search.txt", "r", encoding="utf-8") as searched_top_movies:
            for line in searched_top_movies:
                data = line.strip().split('::')

                Title = data[0]
                Rating = float(data[1])
                filtered_ratings[Title] = Rating

    sorted_ratings = sorted(filtered_ratings.items(), key=lambda x: x[1], reverse=True)
    top_K_movies = sorted_ratings[:K]
    
    for Title, Average_Rating in top_K_movies:
        print("Movie Title:", Title, "Average Rating:", Average_Rating, "\n")

    Kappa = f"top_movies_{K}.txt"

    with open(Kappa, "w", encoding="utf-8") as new_entry:
        for Title, Average_Rating in top_K_movies:
            new_entry.write(f"Movie Title: {Title}, Average Rating: {Average_Rating}\n")
    gc.collect
###################################################################################################################################################################################
###-----------------------------------------------------------------------------------USER PAIRS ---------------------------------------------------------------------------------
###################################################################################################################################################################################
def handling_user_pairs(K):
    user_pairs = dict()
    filtered_pairs = dict()
    movies = dict()
    MovieIds = []

    with open("movies.dat","r", encoding="utf-8") as Mov:
        for line in Mov:
            data = line.strip().split('::')

            MovieID = data[0]
            Title = data[1]
            
            movies[MovieID] = Title
            MovieIds.append(MovieID)


    with open("ratings.dat","r") as ratings:
        for line in ratings:
            data = line.strip().split('::')

            MovieID = data[1]
            UserID = data[0]
            
            if MovieID in user_pairs:
                if len(user_pairs[MovieID]) == 2:
                    continue;
                else:
                    user_pairs[MovieID].append(int(UserID))    
            else:
                user_pairs[MovieID] = [int(UserID)]

    chosen_movies = random.sample(MovieIds, min(K, len(MovieIds)))
  
    for MovieID in chosen_movies:
        if MovieID in user_pairs.keys():
            Title = movies[MovieID]
            filtered_pairs[Title] = user_pairs[MovieID]
    
    with open("first_user_pairs_search.txt", "w", encoding="utf-8") as searched_user_pairs:
        for Title in filtered_pairs.keys():
            searched_user_pairs.write(Title +"::"+str(filtered_pairs[Title])+ '\n')
#------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
@profile
def find_user_pairs(K, c):
    final_pairs = dict()
    if c == 0:
        handling_user_pairs(K)

    with open("first_user_pairs_search.txt", "r", encoding="utf-8") as searched_user_pairs:
            for line in searched_user_pairs:
                data = line.strip().split('::')

                Title = data[0]
                Pair = data[1]
                final_pairs[Title] = Pair

    for Title in final_pairs:
        print("Movie Title:", Title, "Users Pair:", final_pairs[Title], "\n")

    Kappa = f"user_pairs_{K}.txt"

    with open(Kappa, "w", encoding="utf-8") as new_entry:
        for Title in final_pairs.keys():
            new_entry.write(f"Movie Title: {Title}, Users Pair: {final_pairs[Title]}\n")
    gc.collect
###################################################################################################################################################################################
###-----------------------------------------------------------------------------------ICEBERG ---------------------------------------------------------------------------------
###################################################################################################################################################################################
def handling_iceberg():

    iceberg_movies = dict()
    movies = dict()

    with open("movies.dat","r", encoding="utf-8") as Mov:
        for line in Mov:
            data = line.strip().split('::')

            MovieID = data[0]
            Title = data[1]
            
            movies[MovieID] = Title


    with open("ratings.dat","r") as ratings:
        for line in ratings:
            data = line.strip().split('::')

            MovieID = data[1]
            Rating = float(data[2])
            
            if MovieID in iceberg_movies:
                iceberg_movies[MovieID]['Total_Rating'] +=Rating
                iceberg_movies[MovieID]['Count'] += 1   
            else:
                iceberg_movies[MovieID] = {'Movie': MovieID, 'Total_Rating': Rating, 'Count': 1}

  
    for MovieID in movies:
        if MovieID in iceberg_movies.keys():
            average_rating = iceberg_movies[MovieID]['Total_Rating']/iceberg_movies[MovieID]['Count']
            iceberg_movies[MovieID]['Total_Rating'] = average_rating

    
    with open("first_user_search_of_iceberg.txt", "w", encoding="utf-8") as searched_iceberg:
        for Title in iceberg_movies.keys():
            searched_iceberg.write(Title +"::"+str(iceberg_movies[Title]['Total_Rating'])+"::"+ str(iceberg_movies[Title]['Count'])+ '\n')  

#--------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
@profile
def iceberg(K,T, d):
    final_movies = dict()
    if d==0:
        handling_iceberg()

    with open("first_user_search_of_iceberg.txt", "r", encoding="utf-8") as searched_iceberg:
        for line in searched_iceberg:
            data = line.strip().split('::')

            Title = data[0]
            Rating = float(data[1])
            Count = int(data[2])

            if Count >= K and Rating >= T:
                final_movies[Title] = {'Count': Count, 'Total_Rating': Rating}

    for Title in final_movies:
        print("Movie Title:", Title, "Number of critics:", final_movies[Title]['Count'], "Average Rating:", final_movies[Title]['Total_Rating'], "\n")

    K_T = f"iceberg_{K}_{T}.txt"

    with open(K_T, "w", encoding="utf-8") as new_entry:
        for Title in final_movies.keys():
            new_entry.write(f"Movie Title: {Title}, Average Rating: {final_movies[Title]}\n")
    gc.collect
###################################################################################################################################################################################
###-----------------------------------------------------------------------------------TOP USER---------------------------------------------------------------------------------
###################################################################################################################################################################################
def handling_top_user():
    users = dict()
   
    with open("ratings.dat","r") as ratings:
        for line in ratings:
            data = line.strip().split('::')

            UserID = data[0]
            
            if UserID in users:
                users[UserID]+=1    
            else:
                users[UserID] = 1

    sorted_users = sorted(users.items(), key=lambda x: x[1], reverse=True)

    with open("first_user_search_of_top_user.txt", "w", encoding="utf-8") as searched_top_user:
        for User, Critics in sorted_users:
            searched_top_user.write(User +"::"+str(Critics)+ '\n')
#------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------           
@profile
def top_users(K, e):
    Users = list()
    if e ==0:
        handling_top_user()
    with open("first_user_search_of_top_user.txt", "r", encoding="utf-8") as searched_top_user:
            for line in searched_top_user:
                data = line.strip().split('::')

                User = data[0]
                Critics = data[1]

                Users.append((User,Critics))

    top_K_users = Users[:K]

    for UserID, Critics in top_K_users:
        print("User:", UserID, "Movies:", Critics, "\n")

    Kappa = f"top_user_{K}.txt"

    with open(Kappa, "w", encoding="utf-8") as new_entry:
        for UserID, Critics in top_K_users:
            new_entry.write(f"User: {UserID}, Movies: {Critics}\n")
    gc.collect
###################################################################################################################################################################################
###-----------------------------------------------------------------------------------MOVIE SAMPLE---------------------------------------------------------------------------------
###################################################################################################################################################################################
def handling_movie_sample():
    movies = dict()
    categorised_movies = dict()

    with open("movies.dat","r", encoding="utf-8") as Mov:
        for line in Mov:
            data = line.strip().split('::')

            Categories = data[2].split('|')
            Title = data[1]
                
            movies[Title] = Categories

    for Title in movies:
        for Category in movies[Title]:
            if  Category in categorised_movies.keys():
                categorised_movies[Category].append(Title)
            else: categorised_movies[Category] = [Title]
    with open("first_user_search_of_movie_sample.txt", "w", encoding="utf-8") as searched_movie_sample:
        for Category in categorised_movies:
            movies_str = '|'.join(categorised_movies[Category])
            searched_movie_sample.write(f"{Category}::{movies_str}\n")
#------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
@profile
def movie_sample(S, f):
    final_movies = dict()
    Movies = list()
    if f ==0:
        handling_movie_sample()

    with open("first_user_search_of_movie_sample.txt", "r", encoding="utf-8") as searched_movie_sample:
        for line in searched_movie_sample:
            data = line.strip().split('::')

            Category = data[0]
            Movies = data[1].split('|')
            final_movies[Category] = Movies

    for Category in final_movies:
        size = math.ceil(int((S/100)*len(final_movies[Category])))
        final_movies[Category] = final_movies[Category][:size]
        print("Category:", Category, "Movies:", final_movies[Category], "\n")

    Sigma = f"movie_sample_{S}.txt"

    with open(Sigma, "w", encoding="utf-8") as new_entry:
        for Category in final_movies:
            movies_str = ', '.join(final_movies[Category])
            new_entry.write(f"Category: {Category}, Movies: {movies_str}\n")
    gc.collect

###################################################################################################################################################################################
###-----------------------------------------------------------------------------------COSINE SIMILARITY---------------------------------------------------------------------------------
###################################################################################################################################################################################
def handling_cosine():
    users_with_same_movies = dict()
    users = dict()
    user_movies = dict()
    cosine_users = dict()

    with open("ratings.dat","r") as ratings:
        for line in ratings:
            data = line.strip().split('::')

            UserID = data[0]
            MovieID = data[1]
            Rating = float(data[2])
            
            if UserID not in users:
                users[UserID] = []
            rating_entry = {MovieID: Rating}
            users[UserID].append(rating_entry)

            if UserID not in user_movies:
                user_movies[UserID] = []
            user_movies[UserID].append(MovieID)

    common_user_ids = list(set(users.keys()))
    selected_user_ids = random.sample(common_user_ids, 100)

    trimmed_users = {user_id: users[user_id] for user_id in selected_user_ids}
    trimmed_user_movies = {user_id: user_movies[user_id] for user_id in selected_user_ids}

    for UserID1 in trimmed_user_movies:
        for UserID2 in trimmed_user_movies:
            if UserID1 != UserID2: 
                common_movies = [movie for movie in trimmed_user_movies[UserID1] if movie in trimmed_user_movies[UserID2]]

                if len(common_movies) != 0:
                    if (UserID1, UserID2) not in users_with_same_movies:
                        if (UserID2, UserID1) not in users_with_same_movies:
                            users_with_same_movies[(UserID1, UserID2)] = []

                            for MovieID in common_movies:
                                users_with_same_movies[(UserID1, UserID2)].append(MovieID)
    

    for (UserID1, UserID2) in users_with_same_movies:
        cos_similar = 0
        sum_cos_sim_nominator = 0
        sum_cos_sim_denominator_user1 = 0
        sum_cos_sim_denominator_user2 = 0

        for MovieID in users_with_same_movies[(UserID1, UserID2)]:

            ratings_user1 = {list(movie.keys())[0]: list(movie.values())[0] for movie in trimmed_users[UserID1]}

            rating1 = 0
            for rating_entry in trimmed_users[UserID1]:
                rating1 = ratings_user1.get(MovieID, 0)

            ratings_user2 = {list(movie.keys())[0]: list(movie.values())[0] for movie in trimmed_users[UserID2]}

            rating2 = 0
            for rating_entry in trimmed_users[UserID2]:
                rating2 = ratings_user2.get(MovieID, 0)

            sum_cos_sim_nominator += rating1*rating2
            sum_cos_sim_denominator_user1 += rating1**2
            sum_cos_sim_denominator_user2 += rating2**2

        cos_similar = sum_cos_sim_nominator/(math.sqrt(sum_cos_sim_denominator_user1)*math.sqrt(sum_cos_sim_denominator_user2)) if (math.sqrt(sum_cos_sim_denominator_user1)*math.sqrt(sum_cos_sim_denominator_user2))!=0 else 0

        cosine_users[(UserID1, UserID2)] = cos_similar

    sorted_users = sorted(cosine_users.items(), key=lambda x: x[1], reverse=True)

    with open("first_user_search_of_cosine.txt", "w", encoding="utf-8") as searched_cosine:
        for ((UserID1, UserID2), similarity) in sorted_users:
            searched_cosine.write(f"{UserID1, UserID2}::{similarity}\n")

#-----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
@profile
def cosine_similarity(Thetta, g):
    cosine_users = dict()
    if g==0:
        handling_cosine()

    with open("first_user_search_of_cosine.txt", "r", encoding="utf-8") as searched_cosine:
        for line in searched_cosine:
            data = line.strip().split('::')

            pair = data[0]
            similarity = float(data[1])
            cosine_users[pair] = similarity

    final_cosine_users = dict()
    for pair in cosine_users:
        if cosine_users[pair] >= Thetta:
            final_cosine_users[pair] = cosine_users[pair]

    for pair in final_cosine_users:
        print("Users:", pair, "Cosine Similarity:", final_cosine_users[pair], "\n")

    Cos = f"similar_users_{Thetta}.txt"

    with open(Cos, "w", encoding="utf-8") as new_entry:
        for pair in final_cosine_users:
            new_entry.write(f"Users: {pair}, Similarity: {final_cosine_users[pair]}\n")
    gc.collect
###################################################################################################################################################################################
###-----------------------------------------------------------------------------------DOMINANCE---------------------------------------------------------------------------------
###################################################################################################################################################################################
@profile
def dominance(h):
    if h == 1:
        prints = list()
        with open("dominance.txt", "r", encoding="utf-8") as prev_entry:
                for line in prev_entry:
                    prints.append(line+"\n")
        for i in prints:
            print(i)
        return

    movies_that_are_not_dominated = dict()
    average_ratings = dict()
    movies = dict()

    with open("movies.dat","r", encoding="utf-8") as Mov:
        for line in Mov:
            data = line.strip().split('::')

            MovieID = data[0]
            Title = data[1]
            
            movies[MovieID] = Title

    with open("ratings.dat","r") as ratings:
        for line in ratings:
            data = line.strip().split('::')

            MovieID = data[1]
            Rating = float(data[2])
            
            if MovieID in average_ratings:
                average_ratings[MovieID]['Total_Rating'] +=Rating
                average_ratings[MovieID]['Count'] += 1
            else:
                average_ratings[MovieID] = {'Total_Rating': Rating, 'Count': 1}

    for MovieID in movies:
        if MovieID in average_ratings.keys():
            Title = movies[MovieID]
            average_rating = average_ratings[MovieID]['Total_Rating']/average_ratings[MovieID]['Count']
            count = average_ratings[MovieID]['Count']
            movies_that_are_not_dominated[Title] = [count, average_rating]
            for MovieID2 in movies:
                if MovieID2!=MovieID:
                    if MovieID2 in average_ratings.keys():
                        average_rating2 = average_ratings[MovieID2]['Total_Rating']/average_ratings[MovieID2]['Count']
                        count2 = average_ratings[MovieID2]['Count']
                        if average_rating2 >= average_rating and count2>=count:
                            del movies_that_are_not_dominated[Title]
                            break;

    for Title in movies_that_are_not_dominated:
        count, average_rating = movies_that_are_not_dominated[Title]
        print("Movie Title:", Title, "Average Rating:", average_rating, "Total Votes:", count, "\n") 

    with open("dominance.txt", "w", encoding="utf-8") as dom:
        for Title in movies_that_are_not_dominated:
            count, average_rating = movies_that_are_not_dominated[Title]
            dom.write(f"Movie Title: {Title}, Average Rating: {average_rating}, Total Votes: {count}\n")
    gc.collect
###################################################################################################################################################################################
###-----------------------------------------------------------------------------------CALL PREVIOUS ENTRIES---------------------------------------------------------------------------------
###################################################################################################################################################################################  
@profile
def call_previous_entries(a, b, c):
    prints = list()
    a_b_c = f"{a}_{b}_{c}.txt"
    with open(a_b_c, "r", encoding="utf-8") as prev_entry:
            for line in prev_entry:
                prints.append(line+"\n")
    for i in prints:
        print(i)
    gc.collect

def call_previous_entries2(a, b):
    prints = list()
    a_b = f"{a}_{b}.txt"
    with open(a_b, "r", encoding="utf-8") as prev_entry:
            for line in prev_entry:
                prints.append(line+"\n")
    for i in prints:
        print(i)

def check_if_previous_entry_exists(prev_entries, key, b, c):
    for entry in prev_entries:
        if key in entry:
            if c is None:
                if entry[key] == b:
                    return False
            else:
                if entry[key] == [b,c]:
                   return False       
    return True
###################################################################################################################################################################################
###-----------------------------------------------------------------------------------MAIN---------------------------------------------------------------------------------
###################################################################################################################################################################################
def main():
    a = 0
    b = 0
    c = 0
    d = 0
    e = 0
    f = 0
    g = 0
    h = 0
    k = 0
    previous_entries = list()
    last_10_inputs = dict()
    new_entry = False
    mode = [0, 0, 0]
    while(True):
        print("\nChoose\n\n 1) rating T1 T2: find all movies with rating between T1 and T2\n\n 2) top_movies K: find all movies with rating over K \n\n 3) user_pairs K: find all user pairs that have given rating to the same movie\n\n\
 4) dominance: find users that aren't dominated from other movies\n\n 5) iceberg K T: find movies that have been rated at least K times with average score over T\n\n 6) top_user K: find the K users that have rated the most movies\n\n\
 7) movie_sample S: find a percentage of movies from all categories\n\n 8) similar_users Θ: find users that have similar tastes in movies based on cosine similarity\n\n 9) S to stop\n\n")
        if k == 0:
            mode[0] = "rating"
            mode[1] = "2.0"
            mode[2] = "2.2"
        elif k == 1:
            mode[0] = "rating"
            mode[1] = "2.1"
            mode[2] = "2.2"
        elif k == 2:
            mode[0] = "rating"
            mode[1] = "2.0"
            mode[2] = "2.2"    
        elif k == 3:
            mode[0] = "top_movies"
            mode[1] = "10"
        elif k == 4:
            mode[0] = "top_movies"
            mode[1] = "9"
        elif k == 5:
            mode[0] = "user_pairs"
            mode[1] = "7"
        elif k == 6:
            mode[0] = "user_pairs"
            mode[1] = "2"
        elif k == 7:
            mode[0] = "dominance"
        elif k == 8:
            mode[0] = "dominance"
        elif k == 9:
            mode[0] = "iceberg"
            mode[1] = "100"
            mode[2] = "4"
        elif k == 10:
            mode[0] = "iceberg"
            mode[1] = "95"
            mode[2] = "4"
        elif k == 11:
            mode[0] = "top_user"
            mode[1] = "5"
        elif k == 12:
            mode[0] = "top_user"
            mode[1] = "1"
        elif k == 13:
            mode[0] = "movie_sample"
            mode[1] = "20"
        elif k == 14:
            mode[0] = "movie_sample"
            mode[1] = "15"
        elif k == 15:
            mode[0] = "similar_users"
            mode[1] = "0.97"
        elif k == 16:
            mode[0] = "similar_users"
            mode[1] = "0.97"
        else:
            mode[0] = "S"

        if mode[0] == "S":
            break;
#-----------------------------------------------------------------------------------------------------------------------------------------------------------------
        if mode[0] == "rating":

            new_entry = check_if_previous_entry_exists(previous_entries, mode[0], mode[1], mode[2])
            if(new_entry):
                find_movies_between_T1_T2(float(mode[1]), float(mode[2]), a)
            else:
                call_previous_entries(mode[0], float(mode[1]), float(mode[2]))
            a = 1
            k+=1
#-----------------------------------------------------------------------------------------------------------------------------------------------------------------
        elif mode[0] == "top_movies":

            new_entry = check_if_previous_entry_exists(previous_entries, mode[0], mode[1], None)
            if(new_entry):
                find_top_movies(int(mode[1]), b)
            else:
                call_previous_entries2(mode[0], int(mode[1]))
            b = 1
            k+=1
#-----------------------------------------------------------------------------------------------------------------------------------------------------------------
        elif mode[0]== "user_pairs":

            new_entry = check_if_previous_entry_exists(previous_entries, mode[0], mode[1], None)
            if(new_entry):
                find_user_pairs(int(mode[1]), c)
            else:
                call_previous_entries2(mode[0], int(mode[1]))
            c = 1
            k+=1
#-----------------------------------------------------------------------------------------------------------------------------------------------------------------
        elif mode[0]== "iceberg":

            new_entry = check_if_previous_entry_exists(previous_entries, mode[0], mode[1], mode[2]) 
            if(new_entry):
                iceberg(int(mode[1]), float(mode[2]), d)
            else:
                call_previous_entries(mode[0], int(mode[1]), float(mode[2]))
            d = 1
            k+=1
#-----------------------------------------------------------------------------------------------------------------------------------------------------------------
        elif mode[0]== "top_user":

            new_entry = check_if_previous_entry_exists(previous_entries, mode[0], mode[1], None)
            if(new_entry):
                top_users(int(mode[1]), e)
            else:
                call_previous_entries2(mode[0], int(mode[1]))
            e = 1
            k+=1
#-----------------------------------------------------------------------------------------------------------------------------------------------------------------
        elif mode[0]== "movie_sample":

            new_entry = check_if_previous_entry_exists(previous_entries, mode[0], mode[1], None)
            if(new_entry):
                movie_sample(int(mode[1]), f)
            else:
                call_previous_entries2(mode[0], int(mode[1]))
            f = 1
            k+=1
#-----------------------------------------------------------------------------------------------------------------------------------------------------------------
        elif mode[0]== "similar_users":

            new_entry = check_if_previous_entry_exists(previous_entries, mode[0], mode[1], None)
            if(new_entry):
                cosine_similarity(float(mode[1]), g)
            else:
                call_previous_entries2(mode[0], float(mode[1]))
            g = 1
            k+=1
#-----------------------------------------------------------------------------------------------------------------------------------------------------------------
        elif mode[0]== "dominance":
            dominance(h)
            h = 1
            k+=1
#-----------------------------------------------------------------------------------------------------------------------------------------------------------------
        else : 
            print("not a choice, choose again")
            new_entry = False

        if(new_entry):
            if len(last_10_inputs)<10:
                if len(mode)==2:
                    last_10_inputs[mode[0]] = mode[1]
                elif len(mode)== 3:
                    last_10_inputs[mode[0]] = [mode[1], mode[2]]
            previous_entries.append({mode[0]: last_10_inputs[mode[0]]})
            print(previous_entries)

if __name__ == "__main__":
    main()
# Out:
# Writing prof_phase_2.py

# %%
# !python -m memory_profiler prof_phase_2.py
# Out:
# Choose
#
#  1) rating T1 T2: find all movies with rating between T1 and T2
#
#  2) top_movies K: find all movies with rating over K
#
#  3) user_pairs K: find all user pairs that have given rating to the same movie
#
#  4) dominance: find users that aren't dominated from other movies
#
#  5) iceberg K T: find movies that have been rated at least K times with average score over T
#
#  6) top_user K: find the K users that have rated the most movies
#
#  7) movie_sample S: find a percentage of movies from all categories
#
#  8) similar_users Θ: find users that have similar tastes in movies based on cosine similarity
#
#  9) S to st
# Movie Title: Van Wilder 2: The Rise of Taj (2006) Average Rating: 2.0526315789473686
#
# Movie Title: Happily N'Ever After (2007) Average Rating: 2.1777777777777776
#
# Movie Title: Are We Done Yet? (2007) Average Rating: 2.04
#
# Movie Title: Kickin It Old Skool (2007) Average Rating: 2.2
#
# Movie Title: Delta Farce (2007) Average Rating: 2.0416666666666665
#
# Movie Title: Daddy Day Camp (2007) Average Rating: 2.0972222222222223
#
# Movie Title: Illegal Tender (2007) Average Rating: 2.2
#
# Movie Title: Comebacks, The (2007) Average Rating: 2.1363636363636362
#
# Movie Title: Rails & Ties (2007) Average Rating: 2.0
#
# Movie Title: Welcome Home, Roscoe Jenkins (2008) Average Rating: 2.130434782608696
#
# Movie Title: Klimt (2006) Average Rating: 2.05
#
# Movie Title: Fly Me to the Moon (2008) Average Rating: 2.0625
#
# Movie Title: 100 Feet (2008) Average Rating: 2.0
#
# Movie Title: Moonbase (1998) Average Rating: 2.0
#
# Movie Title: Alone In The Dark II (2008) Average Rating: 2.0833333333333335
#
# Movie Title: Fallout (1998) Average Rating: 2.0
#
# Movie Title: Rockin' in the Rockies (1945) Average Rating: 2.0
#
# Movie Title: Gold Raiders (1951) Average Rating: 2.0
#
# Movie Title: Dirty Dozen: The Deadly Mission (1987) Average Rating: 2.0
#
# Movie Title: Fireproof (2008) Average Rating: 2.0
#
# Movie Title: Guyver, The (1991) Average Rating: 2.0
#
# Movie Title: Ace of Hearts (2008) Average Rating: 2.0
#
# Movie Title: Delgo (2008) Average Rating: 2.0
#
# Movie Title: Double Dynamite (1951) Average Rating: 2.0
#
# Filename: prof_phase_2.py
#
# Line #    Mem usage    Increment  Occurrences   Line Contents
# =============================================================
#     48     50.3 MiB     50.3 MiB           1   @profile
#     49                                         def find_movies_between_T1_T2(T1, T2, a):
#     50     50.3 MiB      0.0 MiB           1       final_ratings = dict()
#     51
#     52     50.3 MiB      0.0 MiB           1       if a == 0:
#     53     52.3 MiB      2.0 MiB           1           data_handling_ratings()
#     54
#     55     52.3 MiB      0.0 MiB           1       with open("first_user_search_of_ratings.txt", "r", encoding="utf-8") as searched_ratings:
#     56     52.3 MiB  -5402.8 MiB       10677               for line in searched_ratings:
#     57     52.3 MiB  -5402.6 MiB       10676                   data = line.strip().split('::')
#     58
#     59     52.3 MiB  -5402.6 MiB       10676                   Title = data[0]
#     60     52.3 MiB  -5402.6 MiB       10676                   Rating = float(data[1])
#     61     52.3 MiB  -5402.6 MiB       10676                   if T1 <= Rating <= T2:
#     62     52.3 MiB   -139.7 MiB         272                       final_ratings[Title] = Rating
#     63
#     64     51.8 MiB     -0.5 MiB         273       for Title in final_ratings:
#     65     51.8 MiB      0.0 MiB         272           print("Movie Title:", Title, "Average Rating:", final_ratings[Title], "\n")
#     66
#     67     51.8 MiB      0.0 MiB           1       T1_T2_a = f"rating_{T1}_{T2}.txt"
#     68
#     69     51.8 MiB      0.0 MiB           1       with open(T1_T2_a, "w", encoding="utf-8") as new_entry:
#     70     51.8 MiB      0.0 MiB         273           for Title in final_ratings.keys():
#     71     51.8 MiB      0.0 MiB         272               new_entry.write(f"Movie Title: {Title}, Average Rating: {final_ratings[Title]}\n")
#     72     51.8 MiB      0.0 MiB           1       gc.collect
#
#
# [{'rating': ['2.0', '2.2']}]
#
# Choose
#
#  1) rating T1 T2: find all movies with rating between T1 and T2
#
#  2) top_movies K: find all movies with rating over K
#
#  3) user_pairs K: find all user pairs that have given rating to the same movie
#
#  4) dominance: find users that aren't dominated from other movies
#
#  5) iceberg K T: find movies that have been rated at least K times with average score over T
#
#  6) top_user K: find the K users that have rated the most movies
#
#  7) movie_sample S: find a percentage of movies from all categories
#
#  8) similar_users Θ: find users that have similar tastes in movies based on cosine similarity
#
#  9) S to st
#
# Movie Title: Sidekicks (1992) Average Rating: 2.1216216216216215
#
# Movie Title: Sound of Thunder, A (2005) Average Rating: 2.1129032258064515
#
# Movie Title: Daddy's Dyin'... Who's Got the Will? (1990) Average Rating: 2.2
#
# Movie Title: Man Trouble (1992) Average Rating: 2.1875
#
# Movie Title: Rebound (2005) Average Rating: 2.1375
#
# Movie Title: Three Stooges Meet Hercules, The (1962) Average Rating: 2.1166666666666667
#
# Movie Title: Venom (2005) Average Rating: 2.1973684210526314
#
# Movie Title: HellBent (2004) Average Rating: 2.1666666666666665
#
# Movie Title: Basic Instinct 2 (2006) Average Rating: 2.1366459627329193
#
# Movie Title: Zoom (2006) Average Rating: 2.1818181818181817
#
# Movie Title: Material Girls (2006) Average Rating: 2.1818181818181817
#
# Movie Title: Happily N'Ever After (2007) Average Rating: 2.1777777777777776
#
# Movie Title: Kickin It Old Skool (2007) Average Rating: 2.2
#
# Movie Title: Illegal Tender (2007) Average Rating: 2.2
#
# Movie Title: Comebacks, The (2007) Average Rating: 2.1363636363636362
#
# Movie Title: Welcome Home, Roscoe Jenkins (2008) Average Rating: 2.130434782608696
#
# Filename: prof_phase_2.py
#
# Line #    Mem usage    Increment  Occurrences   Line Contents
# =============================================================
#     48     51.8 MiB     51.8 MiB           1   @profile
#     49                                         def find_movies_between_T1_T2(T1, T2, a):
#     50     51.8 MiB      0.0 MiB           1       final_ratings = dict()
#     51
#     52     51.8 MiB      0.0 MiB           1       if a == 0:
#     53                                                 data_handling_ratings()
#     54
#     55     51.8 MiB      0.0 MiB           1       with open("first_user_search_of_ratings.txt", "r", encoding="utf-8") as searched_ratings:
#     56     51.8 MiB    -23.0 MiB       10677               for line in searched_ratings:
#     57     51.8 MiB    -23.0 MiB       10676                   data = line.strip().split('::')
#     58
#     59     51.8 MiB    -23.0 MiB       10676                   Title = data[0]
#     60     51.8 MiB    -23.0 MiB       10676                   Rating = float(data[1])
#     61     51.8 MiB    -23.0 MiB       10676                   if T1 <= Rating <= T2:
#     62     51.8 MiB     -0.2 MiB         137                       final_ratings[Title] = Rating
#     63
#     64     51.8 MiB      0.0 MiB         138       for Title in final_ratings:
#     65     51.8 MiB      0.0 MiB         137           print("Movie Title:", Title, "Average Rating:", final_ratings[Title], "\n")
#     66
#     67     51.8 MiB      0.0 MiB           1       T1_T2_a = f"rating_{T1}_{T2}.txt"
#     68
#     69     51.8 MiB      0.0 MiB           1       with open(T1_T2_a, "w", encoding="utf-8") as new_entry:
#     70     51.8 MiB      0.0 MiB         138           for Title in final_ratings.keys():
#     71     51.8 MiB      0.0 MiB         137               new_entry.write(f"Movie Title: {Title}, Average Rating: {final_ratings[Title]}\n")
#     72     51.8 MiB      0.0 MiB           1       gc.collect
#
#
# [{'rating': ['2.0', '2.2']}, {'rating': ['2.1', '2.2']}]
#
# Choose
#
#  1) rating T1 T2: find all movies with rating between T1 and T2
#
#  2) top_movies K: find all movies with rating over K
#
#  3) user_pairs K: find all user pairs that have given rating to the same movie
#
#  4) dominance: find users that aren't dominated from other movies
#
#  5) iceberg K T: find movies that have been rated at least K times with average score over T
#
#  6) top_user K: find the K users that have rated the most movies
#
#  7) movie_sample S: find a percentage of movies from all categories
#
#  8) similar_users Θ: find users that have similar tastes in movies based on cosine similarity
#
#  9) S to st
#
# Users: ('1672', '13524') Cosine Similarity: 0.9731236802019037
#
# Users: ('727', '38398') Cosine Similarity: 0.9731236802019037
#
# Users: ('9162', '727') Cosine Similarity: 0.9731217906395252
#
# Users: ('41166', '6972') Cosine Similarity: 0.9731167547549421
#
# Users: ('27259', '54058') Cosine Similarity: 0.9731034373319217
#
# Users: ('27259', '59410') Cosine Similarity: 0.9730802874900094
#
# Users: ('20963', '24485') Cosine Similarity: 0.9730539376455716
#
# Users: ('21022', '34593') Cosine Similarity: 0.9730219780624271
#
# Users: ('21396', '45474') Cosine Similarity: 0.9730153838790352
#
# Users: ('63263', '64935') Cosine Similarity: 0.972927230941373
#
# Users: ('71327', '59410') Cosine Similarity: 0.9729156620674699
#
# Users: ('49642', '21022') Cosine Similarity: 0.9728785944694599
#
# Users: ('61655', '5568') Cosine Similarity: 0.9728275170889845
#
# Users: ('45474', '44664') Cosine Similarity: 0.9728145923283282
#
# Users: ('15516', '70891') Cosine Similarity: 0.9727954093804385
#
# Users: ('71327', '2735') Cosine Similarity: 0.9727175863162579
#
# Users: ('51893', '3543') Cosine Similarity: 0.97271627218678
#
# Users: ('20963', '22037') Cosine Similarity: 0.9727053253046577
#
# Users: ('20199', '45916') Cosine Similarity: 0.9726358458198423
#
# Users: ('37192', '37238') Cosine Similarity: 0.9725875896263422
#
# Users: ('16945', '67378') Cosine Similarity: 0.9725602748849053
#
# Users: ('27259', '37192') Cosine Similarity: 0.9725468222964365
#
# Users: ('60604', '21022') Cosine Similarity: 0.9725290781677294
#
# Users: ('58314', '67625') Cosine Similarity: 0.972511496915214
#
# Users: ('63285', '24485') Cosine Similarity: 0.9724944956571704
#
# Users: ('33435', '21083') Cosine Similarity: 0.9724868464662947
#
# Users: ('59385', '13524') Cosine Similarity: 0.9724780735002044
#
# Users: ('38398', '34593') Cosine Similarity: 0.9724756873487549
#
# Users: ('27259', '7919') Cosine Similarity: 0.9724598336099635
#
# Users: ('2210', '7919') Cosine Similarity: 0.9723948051233302
#
# Users: ('56056', '41163') Cosine Similarity: 0.9723384127711279
#
# Users: ('37192', '3543') Cosine Similarity: 0.9722789099119717
#
# Users: ('24351', '21083') Cosine Similarity: 0.9722718241315028
#
# Users: ('24351', '38398') Cosine Similarity: 0.9722660787654418
#
# Users: ('51022', '67625') Cosine Similarity: 0.9722288444463424
#
# Users: ('60604', '34593') Cosine Similarity: 0.9721979932571096
#
# Users: ('7919', '41163') Cosine Similarity: 0.9721959242779332
#
# Users: ('42251', '45474') Cosine Similarity: 0.9721952665815835
#
# Users: ('1479', '67378') Cosine Similarity: 0.9721704239678957
#
# Users: ('59385', '6972') Cosine Similarity: 0.9721428114724995
#
# Users: ('41166', '42251') Cosine Similarity: 0.9721032696247311
#
# Users: ('33736', '7919') Cosine Similarity: 0.9720919041839932
#
# Users: ('41794', '2735') Cosine Similarity: 0.9720848086744405
#
# Users: ('63285', '60604') Cosine Similarity: 0.9720321639555793
#
# Users: ('59410', '63694') Cosine Similarity: 0.9720316848725463
#
# Users: ('63285', '16945') Cosine Similarity: 0.9720305316686494
#
# Users: ('6250', '16606') Cosine Similarity: 0.9720261761577622
#
# Users: ('66362', '34194') Cosine Similarity: 0.9720153444196413
#
# Users: ('41166', '67984') Cosine Similarity: 0.9719985880238883
#
# Users: ('6972', '21083') Cosine Similarity: 0.9718702921035733
#
# Users: ('727', '45474') Cosine Similarity: 0.9718675624237363
#
# Users: ('63285', '17972') Cosine Similarity: 0.9718379692455908
#
# Users: ('41166', '22037') Cosine Similarity: 0.9718281395019259
#
# Users: ('71327', '34194') Cosine Similarity: 0.9718253158075499
#
# Users: ('22047', '21022') Cosine Similarity: 0.9718016397998394
#
# Users: ('51893', '67378') Cosine Similarity: 0.9717974294586496
#
# Users: ('1672', '7919') Cosine Similarity: 0.9717900843246653
#
# Users: ('24485', '3543') Cosine Similarity: 0.971788524510477
#
# Users: ('36763', '45474') Cosine Similarity: 0.9717686082763095
#
# Users: ('24351', '33435') Cosine Similarity: 0.9717650047720582
#
# Users: ('37192', '21022') Cosine Similarity: 0.9717293386239705
#
# Users: ('24351', '44884') Cosine Similarity: 0.9717004068499038
#
# Users: ('6250', '29451') Cosine Similarity: 0.9716745940542652
#
# Users: ('49642', '2735') Cosine Similarity: 0.9716737089854944
#
# Users: ('24351', '16945') Cosine Similarity: 0.971665968315492
#
# Users: ('6250', '53378') Cosine Similarity: 0.9716358990847527
#
# Users: ('61655', '33435') Cosine Similarity: 0.9715365547505717
#
# Users: ('66362', '56691') Cosine Similarity: 0.9715365547505717
#
# Users: ('63263', '54907') Cosine Similarity: 0.9715359303093549
#
# Users: ('60604', '29451') Cosine Similarity: 0.9715359303093549
#
# Users: ('6972', '34593') Cosine Similarity: 0.9715096351104202
#
# Users: ('60604', '45474') Cosine Similarity: 0.9714869604145544
#
# Users: ('66362', '52202') Cosine Similarity: 0.9714744769467644
#
# Users: ('41166', '67625') Cosine Similarity: 0.9714648781286124
#
# Users: ('59385', '53378') Cosine Similarity: 0.9714612663708427
#
# Users: ('50611', '30520') Cosine Similarity: 0.9714521595249114
#
# Users: ('16945', '36668') Cosine Similarity: 0.9714415217278836
#
# Users: ('1479', '16606') Cosine Similarity: 0.971424327743986
#
# Users: ('1479', '58352') Cosine Similarity: 0.9714112211624895
#
# Users: ('59410', '36763') Cosine Similarity: 0.9713999796896219
#
# Users: ('37238', '22037') Cosine Similarity: 0.9713963605701827
#
# Users: ('53378', '33340') Cosine Similarity: 0.971370686543044
#
# Users: ('61655', '9514') Cosine Similarity: 0.9713237285143654
#
# Users: ('51893', '59410') Cosine Similarity: 0.9713237285143653
#
# Users: ('16945', '22037') Cosine Similarity: 0.9712760879619441
#
# Users: ('56691', '48795') Cosine Similarity: 0.9712490515150611
#
# Users: ('66362', '7919') Cosine Similarity: 0.9712222441820441
#
# Users: ('17972', '22037') Cosine Similarity: 0.9712021188413074
#
# Users: ('27259', '33340') Cosine Similarity: 0.9711988616562822
#
# Users: ('1479', '21022') Cosine Similarity: 0.9711666999116016
#
# Users: ('66362', '49642') Cosine Similarity: 0.9711392863566775
#
# Users: ('41794', '70891') Cosine Similarity: 0.9710933128295253
#
# Users: ('70891', '67984') Cosine Similarity: 0.9710893767651763
#
# Users: ('34593', '58352') Cosine Similarity: 0.9710890481594013
#
# Users: ('727', '34593') Cosine Similarity: 0.9710883681767524
#
# Users: ('6250', '54058') Cosine Similarity: 0.9710870119824907
#
# Users: ('63694', '8543') Cosine Similarity: 0.9710834400425721
#
# Users: ('34593', '44664') Cosine Similarity: 0.9710814985656443
#
# Users: ('24351', '65716') Cosine Similarity: 0.9710762092858352
#
# Users: ('59385', '27259') Cosine Similarity: 0.9710661131947725
#
# Users: ('32586', '48276') Cosine Similarity: 0.9710607611177229
#
# Users: ('67984', '48276') Cosine Similarity: 0.9710607611177228
#
# Users: ('11264', '67378') Cosine Similarity: 0.9710083124552245
#
# Users: ('9162', '58352') Cosine Similarity: 0.9709981800007341
#
# Users: ('56056', '22037') Cosine Similarity: 0.9709810046371303
#
# Users: ('64935', '38398') Cosine Similarity: 0.9709596232223343
#
# Users: ('59385', '67984') Cosine Similarity: 0.9708842743907417
#
# Users: ('65716', '64935') Cosine Similarity: 0.97086085825942
#
# Users: ('727', '70064') Cosine Similarity: 0.9708478019470685
#
# Users: ('2735', '63694') Cosine Similarity: 0.9708436760877173
#
# Users: ('22047', '21083') Cosine Similarity: 0.9708310895411734
#
# Users: ('71327', '3543') Cosine Similarity: 0.9708176966760071
#
# Users: ('45916', '7919') Cosine Similarity: 0.970803371251903
#
# Users: ('33435', '16945') Cosine Similarity: 0.970774282351878
#
# Users: ('67625', '33340') Cosine Similarity: 0.9707707576035467
#
# Users: ('51640', '6250') Cosine Similarity: 0.9707390852573137
#
# Users: ('61655', '44884') Cosine Similarity: 0.9707253433941511
#
# Users: ('24351', '71327') Cosine Similarity: 0.9707197941566387
#
# Users: ('6250', '36668') Cosine Similarity: 0.9706494108305246
#
# Users: ('36763', '54058') Cosine Similarity: 0.9706494108305246
#
# Users: ('24485', '37238') Cosine Similarity: 0.9706270091027809
#
# Users: ('47716', '45474') Cosine Similarity: 0.9706210182933296
#
# Users: ('60287', '36668') Cosine Similarity: 0.9706095888071584
#
# Users: ('49642', '41163') Cosine Similarity: 0.9705882352941178
#
# Users: ('67378', '70064') Cosine Similarity: 0.9705882352941176
#
# Users: ('53378', '67625') Cosine Similarity: 0.9705882352941176
#
# Users: ('20963', '8543') Cosine Similarity: 0.9705798469313762
#
# Users: ('37192', '2735') Cosine Similarity: 0.9705425889768071
#
# Users: ('51022', '22047') Cosine Similarity: 0.9705329439877403
#
# Users: ('70064', '70891') Cosine Similarity: 0.9704949588309457
#
# Users: ('51022', '38398') Cosine Similarity: 0.970490723608115
#
# Users: ('42251', '41163') Cosine Similarity: 0.9704833011638263
#
# Users: ('16945', '48276') Cosine Similarity: 0.9704498214678878
#
# Users: ('51022', '9162') Cosine Similarity: 0.9704337904987346
#
# Users: ('51893', '44884') Cosine Similarity: 0.9704123064469983
#
# Users: ('1479', '33340') Cosine Similarity: 0.9704079073803574
#
# Users: ('56056', '59385') Cosine Similarity: 0.9704038925427317
#
# Users: ('51893', '51640') Cosine Similarity: 0.9703836816232826
#
# Users: ('63694', '29451') Cosine Similarity: 0.9703671201172771
#
# Users: ('62200', '45474') Cosine Similarity: 0.9703591373922879
#
# Users: ('65716', '45474') Cosine Similarity: 0.9703534204184571
#
# Users: ('3543', '70064') Cosine Similarity: 0.9703190597004535
#
# Users: ('45916', '17972') Cosine Similarity: 0.970306706000141
#
# Users: ('58314', '49642') Cosine Similarity: 0.9701918700087334
#
# Users: ('59385', '70064') Cosine Similarity: 0.9701790336292929
#
# Users: ('56691', '34194') Cosine Similarity: 0.9701588944723796
#
# Users: ('55566', '32586') Cosine Similarity: 0.9701456617788421
#
# Users: ('27259', '20199') Cosine Similarity: 0.970142500145332
#
# Users: ('34194', '20199') Cosine Similarity: 0.970142500145332
#
# Users: ('2735', '21005') Cosine Similarity: 0.970142500145332
#
# Users: ('67378', '30520') Cosine Similarity: 0.970142500145332
#
# Users: ('44884', '21083') Cosine Similarity: 0.970142500145332
#
# Users: ('5568', '36763') Cosine Similarity: 0.970142500145332
#
# Users: ('50611', '52202') Cosine Similarity: 0.970142500145332
#
# Users: ('51893', '20199') Cosine Similarity: 0.9701425001453319
#
# Users: ('20963', '41794') Cosine Similarity: 0.9701425001453319
#
# Users: ('47716', '62200') Cosine Similarity: 0.9701425001453319
#
# Users: ('41166', '41794') Cosine Similarity: 0.9701425001453319
#
# Users: ('33435', '41794') Cosine Similarity: 0.9701425001453319
#
# Users: ('33435', '27259') Cosine Similarity: 0.9701425001453319
#
# Users: ('58314', '33736') Cosine Similarity: 0.9701425001453319
#
# Users: ('15231', '42251') Cosine Similarity: 0.9701425001453319
#
# Users: ('56691', '13524') Cosine Similarity: 0.9701425001453319
#
# Users: ('34194', '67625') Cosine Similarity: 0.9701425001453319
#
# Users: ('3543', '42251') Cosine Similarity: 0.9701425001453319
#
# Users: ('3543', '54058') Cosine Similarity: 0.9701425001453319
#
# Users: ('49642', '13524') Cosine Similarity: 0.9701425001453319
#
# Users: ('49642', '9514') Cosine Similarity: 0.9701425001453319
#
# Users: ('727', '67625') Cosine Similarity: 0.9701425001453319
#
# Users: ('60124', '21083') Cosine Similarity: 0.9701425001453319
#
# Users: ('20199', '54058') Cosine Similarity: 0.9701425001453319
#
# Users: ('13524', '30520') Cosine Similarity: 0.9701425001453319
#
# Users: ('62200', '21396') Cosine Similarity: 0.9701425001453319
#
# Users: ('51640', '44884') Cosine Similarity: 0.9701425001453319
#
# Users: ('19584', '69410') Cosine Similarity: 0.9701425001453319
#
# Users: ('21022', '42251') Cosine Similarity: 0.9701425001453319
#
# Users: ('42251', '54058') Cosine Similarity: 0.9701425001453319
#
# Users: ('1845', '44664') Cosine Similarity: 0.9701425001453318
#
# Users: ('6972', '6250') Cosine Similarity: 0.9701232785213583
#
# Users: ('37238', '41163') Cosine Similarity: 0.970117948423136
#
# Users: ('21022', '41163') Cosine Similarity: 0.9701088140570165
#
# Users: ('48907', '17972') Cosine Similarity: 0.9700980088375216
#
# Users: ('19584', '36763') Cosine Similarity: 0.9700434403094537
#
# Users: ('20963', '727') Cosine Similarity: 0.970035329315476
#
# Users: ('59385', '1479') Cosine Similarity: 0.9700313548902283
#
# Users: ('63285', '21022') Cosine Similarity: 0.9700129022466818
#
# Users: ('34593', '45474') Cosine Similarity: 0.970000221186897
#
# Filename: prof_phase_2.py
#
# Line #    Mem usage    Increment  Occurrences   Line Contents
# =============================================================
#    464     15.9 MiB     15.9 MiB           1   @profile
#    465                                         def cosine_similarity(Thetta, g):
#    466     15.9 MiB      0.0 MiB           1       cosine_users = dict()
#    467     15.9 MiB      0.0 MiB           1       if g==0:
#    468                                                 handling_cosine()
#    469
#    470     15.9 MiB      0.0 MiB           1       with open("first_user_search_of_cosine.txt", "r", encoding="utf-8") as searched_cosine:
#    471     15.9 MiB      0.0 MiB        4163           for line in searched_cosine:
#    472     15.9 MiB      0.0 MiB        4162               data = line.strip().split('::')
#    473
#    474     15.9 MiB      0.0 MiB        4162               pair = data[0]
#    475     15.9 MiB      0.0 MiB        4162               similarity = float(data[1])
#    476     15.9 MiB      0.0 MiB        4162               cosine_users[pair] = similarity
#    477
#    478     15.9 MiB      0.0 MiB           1       final_cosine_users = dict()
#    479     15.9 MiB    -87.2 MiB        4163       for pair in cosine_users:
#    480     15.9 MiB    -87.2 MiB        4162           if cosine_users[pair] >= Thetta:
#    481     15.9 MiB      0.0 MiB        2233               final_cosine_users[pair] = cosine_users[pair]
#    482
#    483     15.8 MiB     -0.1 MiB        2234       for pair in final_cosine_users:
#    484     15.8 MiB      0.0 MiB        2233           print("Users:", pair, "Cosine Similarity:", final_cosine_users[pair], "\n")
#    485
#    486     15.8 MiB      0.0 MiB           1       Cos = f"similar_users_{Thetta}.txt"
#    487
#    488     15.8 MiB      0.0 MiB           1       with open(Cos, "w", encoding="utf-8") as new_entry:
#    489     15.9 MiB      0.0 MiB        2234           for pair in final_cosine_users:
#    490     15.9 MiB      0.1 MiB        2233               new_entry.write(f"Users: {pair}, Similarity: {final_cosine_users[pair]}\n")
#    491     15.9 MiB      0.0 MiB           1       gc.collect
#
#
# [{'rating': ['2.0', '2.2']}, {'rating': ['2.1', '2.2']}, {'top_movies': ['10', '2.2']}, {'top_movies': ['9', '2.2']}, {'user_pairs': ['7', '2.2']}, {'user_pairs': ['2', '2.2']}, {'dominance': ['2', '2.2']}, {'dominance': ['2', '2.2']}, {'iceberg': ['100', '4']}, {'iceberg': ['95', '4']}, {'top_user': ['5', '4']}, {'top_user': ['1', '4']}, {'movie_sample': ['20', '4']}, {'movie_sample': ['15', '4']}, {'similar_users': ['0.97', '4']}, {'similar_users': ['0.97', '4']}]
#
# Choose
#
#  1) rating T1 T2: find all movies with rating between T1 and T2
#
#  2) top_movies K: find all movies with rating over K
#
#  3) user_pairs K: find all user pairs that have given rating to the same movie
#
#  4) dominance: find users that aren't dominated from other movies
#
#  5) iceberg K T: find movies that have been rated at least K times with average score over T
#
#  6) top_user K: find the K users that have rated the most movies
#
#  7) movie_sample S: find a percentage of movies from all categories
#
#  8) similar_users Θ: find users that have similar tastes in movies based on cosine similarity
#
#  9) S to stop
