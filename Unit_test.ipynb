# %%
# %%file Unit_testing_phase.py
import math
import random

###################################################################################################################################################################################
###-----------------------------------------------------------------------------------RATING ---------------------------------------------------------------------------------
###################################################################################################################################################################################

def data_handling_ratings():

    filtered_ratings = dict()
    average_ratings = dict()
    movies = dict()

    with open("movies.dat","r", encoding="utf-8") as Mov:
            for line in Mov:
                data = line.strip().split('::')

                MovieID = data[0]
                Title = data[1]
                
                movies[MovieID] = Title

    with open("ratings.dat","r") as ratings:
        for line in ratings:
            data = line.strip().split('::')

            MovieID = data[1]
            Rating = float(data[2])
            
            if MovieID in average_ratings:
                average_ratings[MovieID]['Total_Rating'] +=Rating
                average_ratings[MovieID]['Count'] += 1
            else:
                average_ratings[MovieID] = {'Total_Rating': Rating, 'Count': 1}

    for MovieID in movies:
        if MovieID in average_ratings.keys():
            Title = movies[MovieID]
            average_rating = average_ratings[MovieID]['Total_Rating']/average_ratings[MovieID]['Count']
            filtered_ratings[Title] = average_rating

    with open("first_user_search_of_ratings.txt", "w", encoding="utf-8") as searched_ratings:
        for Title in filtered_ratings.keys():
            searched_ratings.write(Title +"::"+str(filtered_ratings[Title])+ '\n') 
#-------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------

def find_movies_between_T1_T2(T1, T2, a):
    final_ratings = dict()

    if a == 0:
        data_handling_ratings()

    with open("first_user_search_of_ratings.txt", "r", encoding="utf-8") as searched_ratings:
            for line in searched_ratings:
                data = line.strip().split('::')

                Title = data[0]
                Rating = float(data[1])
                if T1 <= Rating <= T2:
                    final_ratings[Title] = Rating

    for Title in final_ratings:
        print("Movie Title:", Title, "Average Rating:", final_ratings[Title], "\n")

    T1_T2_a = f"rating_{T1}_{T2}.txt"

    with open(T1_T2_a, "w", encoding="utf-8") as new_entry:
        for Title in final_ratings.keys():
            new_entry.write(f"Movie Title: {Title}, Average Rating: {final_ratings[Title]}\n")   
    
    returning_variable = ""
    with open(T1_T2_a, "r", encoding="utf-8") as returning_file:
        returning_variable = returning_file.read()
    return returning_variable

###################################################################################################################################################################################
###-----------------------------------------------------------------------------------TOP MOVIES ---------------------------------------------------------------------------------
###################################################################################################################################################################################

def data_handling_top_movies():

    filtered_ratings = dict()
    average_ratings = dict()
    movies = dict()

    with open("movies.dat","r", encoding="utf-8") as Mov:
        for line in Mov:
            data = line.strip().split('::')

            MovieID = data[0]
            Title = data[1]
            
            movies[MovieID] = Title

    with open("ratings.dat","r") as ratings:
        for line in ratings:
            data = line.strip().split('::')

            MovieID = data[1]
            Rating = float(data[2])
            
            if MovieID in average_ratings:
                average_ratings[MovieID]['Total_Rating'] +=Rating
                average_ratings[MovieID]['Count'] += 1
            else:
                average_ratings[MovieID] = {'Total_Rating': Rating, 'Count': 1}
        
    for MovieID in movies:
        if MovieID in average_ratings.keys():
            Title = movies[MovieID]
            average_rating = average_ratings[MovieID]['Total_Rating']/average_ratings[MovieID]['Count']
            filtered_ratings[Title] = average_rating

    with open("first_top_movies_search.txt", "w", encoding="utf-8") as searched_top_movies:
        for Title in filtered_ratings.keys():
            searched_top_movies.write(Title +"::"+str(filtered_ratings[Title])+ '\n')

#---------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------

def find_top_movies(K, b): 
    filtered_ratings = dict()

    if b == 0:
        data_handling_top_movies()

    with open("first_top_movies_search.txt", "r", encoding="utf-8") as searched_top_movies:
            for line in searched_top_movies:
                data = line.strip().split('::')

                Title = data[0]
                Rating = float(data[1])
                filtered_ratings[Title] = Rating

    sorted_ratings = sorted(filtered_ratings.items(), key=lambda x: x[1], reverse=True)
    top_K_movies = sorted_ratings[:K]
    
    for Title, Average_Rating in top_K_movies:
        print("Movie Title:", Title, "Average Rating:", Average_Rating, "\n")

    Kappa = f"top_movies_{K}.txt"

    with open(Kappa, "w", encoding="utf-8") as new_entry:
        for Title, Average_Rating in top_K_movies:
            new_entry.write(f"Movie Title: {Title}, Average Rating: {Average_Rating}\n")

    returning_variable = ""
    with open(Kappa, "r", encoding="utf-8") as returning_file:
        returning_variable = returning_file.read()
    return returning_variable

###################################################################################################################################################################################
###-----------------------------------------------------------------------------------USER PAIRS ---------------------------------------------------------------------------------
###################################################################################################################################################################################
def handling_user_pairs(K):
    user_pairs = dict()
    filtered_pairs = dict()
    movies = dict()
    MovieIds = []

    with open("movies.dat","r", encoding="utf-8") as Mov:
        for line in Mov:
            data = line.strip().split('::')

            MovieID = data[0]
            Title = data[1]
            
            movies[MovieID] = Title
            MovieIds.append(MovieID)


    with open("ratings.dat","r") as ratings:
        for line in ratings:
            data = line.strip().split('::')

            MovieID = data[1]
            UserID = data[0]
            
            if MovieID in user_pairs:
                if len(user_pairs[MovieID]) == 2:
                    continue;
                else:
                    user_pairs[MovieID].append(int(UserID))    
            else:
                user_pairs[MovieID] = [int(UserID)]

    chosen_movies = random.sample(MovieIds, min(K, len(MovieIds)))
  
    for MovieID in chosen_movies:
        if MovieID in user_pairs.keys():
            Title = movies[MovieID]
            filtered_pairs[Title] = user_pairs[MovieID]
    
    with open("first_user_pairs_search.txt", "w", encoding="utf-8") as searched_user_pairs:
        for Title in filtered_pairs.keys():
            searched_user_pairs.write(Title +"::"+str(filtered_pairs[Title])+ '\n')
#------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
def find_user_pairs(K, c):
    final_pairs = dict()
    if c == 0:
        handling_user_pairs(K)

    with open("first_user_pairs_search.txt", "r", encoding="utf-8") as searched_user_pairs:
            for line in searched_user_pairs:
                data = line.strip().split('::')

                Title = data[0]
                Pair = data[1]
                final_pairs[Title] = Pair

    for Title in final_pairs:
        print("Movie Title:", Title, "Users Pair:", final_pairs[Title], "\n")

    Kappa = f"user_pairs_{K}.txt"

    with open(Kappa, "w", encoding="utf-8") as new_entry:
        for Title in final_pairs.keys():
            new_entry.write(f"Movie Title: {Title}, Users Pair: {final_pairs[Title]}\n")

    returning_variable = ""
    with open(Kappa, "r", encoding="utf-8") as returning_file:
        returning_variable = returning_file.read()
    return returning_variable

###################################################################################################################################################################################
###-----------------------------------------------------------------------------------ICEBERG ---------------------------------------------------------------------------------
###################################################################################################################################################################################
def handling_iceberg():

    iceberg_movies = dict()
    movies = dict()

    with open("movies.dat","r", encoding="utf-8") as Mov:
        for line in Mov:
            data = line.strip().split('::')

            MovieID = data[0]
            Title = data[1]
            
            movies[MovieID] = Title


    with open("ratings.dat","r") as ratings:
        for line in ratings:
            data = line.strip().split('::')

            MovieID = data[1]
            Rating = float(data[2])
            
            if MovieID in iceberg_movies:
                iceberg_movies[MovieID]['Total_Rating'] +=Rating
                iceberg_movies[MovieID]['Count'] += 1   
            else:
                iceberg_movies[MovieID] = {'Movie': MovieID, 'Total_Rating': Rating, 'Count': 1}

  
    for MovieID in movies:
        if MovieID in iceberg_movies.keys():
            average_rating = iceberg_movies[MovieID]['Total_Rating']/iceberg_movies[MovieID]['Count']
            iceberg_movies[MovieID]['Total_Rating'] = average_rating

    
    with open("first_user_search_of_iceberg.txt", "w", encoding="utf-8") as searched_iceberg:
        for Title in iceberg_movies.keys():
            searched_iceberg.write(Title +"::"+str(iceberg_movies[Title]['Total_Rating'])+"::"+ str(iceberg_movies[Title]['Count'])+ '\n')  

#--------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------

def iceberg(K,T, d):
    final_movies = dict()
    if d==0:
        handling_iceberg()

    with open("first_user_search_of_iceberg.txt", "r", encoding="utf-8") as searched_iceberg:
        for line in searched_iceberg:
            data = line.strip().split('::')

            Title = data[0]
            Rating = float(data[1])
            Count = int(data[2])

            if Count >= K and Rating >= T:
                final_movies[Title] = {'Count': Count, 'Total_Rating': Rating}

    for Title in final_movies:
        print("Movie Title:", Title, "Number of critics:", final_movies[Title]['Count'], "Average Rating:", final_movies[Title]['Total_Rating'], "\n")

    K_T = f"iceberg_{K}_{T}.txt"

    with open(K_T, "w", encoding="utf-8") as new_entry:
        for Title in final_movies.keys():
            new_entry.write(f"Movie Title: {Title}, Average Rating: {final_movies[Title]}\n")

    returning_variable = ""
    with open(K_T, "r", encoding="utf-8") as returning_file:
        returning_variable = returning_file.read()
    return returning_variable

###################################################################################################################################################################################
###-----------------------------------------------------------------------------------TOP USER---------------------------------------------------------------------------------
###################################################################################################################################################################################
def handling_top_user():
    users = dict()
   
    with open("ratings.dat","r") as ratings:
        for line in ratings:
            data = line.strip().split('::')

            UserID = data[0]
            
            if UserID in users:
                users[UserID]+=1    
            else:
                users[UserID] = 1

    sorted_users = sorted(users.items(), key=lambda x: x[1], reverse=True)

    with open("first_user_search_of_top_user.txt", "w", encoding="utf-8") as searched_top_user:
        for User, Critics in sorted_users:
            searched_top_user.write(User +"::"+str(Critics)+ '\n')
#------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------           
def top_users(K, e):
    Users = list()
    if e ==0:
        handling_top_user()
    with open("first_user_search_of_top_user.txt", "r", encoding="utf-8") as searched_top_user:
            for line in searched_top_user:
                data = line.strip().split('::')

                User = data[0]
                Critics = data[1]

                Users.append((User,Critics))

    top_K_users = Users[:K]

    for UserID, Critics in top_K_users:
        print("User:", UserID, "Movies:", Critics, "\n")

    Kappa = f"top_user_{K}.txt"

    with open(Kappa, "w", encoding="utf-8") as new_entry:
        for UserID, Critics in top_K_users:
            new_entry.write(f"User: {UserID}, Movies: {Critics}\n")

    returning_variable = ""
    with open(Kappa, "r", encoding="utf-8") as returning_file:
        returning_variable = returning_file.read()
    return returning_variable
###################################################################################################################################################################################
###-----------------------------------------------------------------------------------MOVIE SAMPLE---------------------------------------------------------------------------------
###################################################################################################################################################################################
def handling_movie_sample():
    movies = dict()
    categorised_movies = dict()

    with open("movies.dat","r", encoding="utf-8") as Mov:
        for line in Mov:
            data = line.strip().split('::')

            Categories = data[2].split('|')
            Title = data[1]
                
            movies[Title] = Categories

    for Title in movies:
        for Category in movies[Title]:
            if  Category in categorised_movies.keys():
                categorised_movies[Category].append(Title)
            else: categorised_movies[Category] = [Title]
    with open("first_user_search_of_movie_sample.txt", "w", encoding="utf-8") as searched_movie_sample:
        for Category in categorised_movies:
            movies_str = '|'.join(categorised_movies[Category])
            searched_movie_sample.write(f"{Category}::{movies_str}\n")
#------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
def movie_sample(S, f):
    final_movies = dict()
    Movies = list()
    if f ==0:
        handling_movie_sample()

    with open("first_user_search_of_movie_sample.txt", "r", encoding="utf-8") as searched_movie_sample:
        for line in searched_movie_sample:
            data = line.strip().split('::')

            Category = data[0]
            Movies = data[1].split('|')
            final_movies[Category] = Movies

    for Category in final_movies:
        size = math.ceil(int((S/100)*len(final_movies[Category])))
        final_movies[Category] = final_movies[Category][:size]
        print("Category:", Category, "Movies:", final_movies[Category], "\n")

    Sigma = f"movie_sample_{S}.txt"

    with open(Sigma, "w", encoding="utf-8") as new_entry:
        for Category in final_movies:
            movies_str = ', '.join(final_movies[Category])
            new_entry.write(f"Category: {Category}, Movies: {movies_str}\n")

###################################################################################################################################################################################
###-----------------------------------------------------------------------------------COSINE SIMILARITY---------------------------------------------------------------------------------
###################################################################################################################################################################################
def handling_cosine():
    users_with_same_movies = dict()
    users = dict()
    user_movies = dict()
    cosine_users = dict()

    with open("ratings.dat","r") as ratings:
        for line in ratings:
            data = line.strip().split('::')

            UserID = data[0]
            MovieID = data[1]
            Rating = float(data[2])
            
            if UserID not in users:
                users[UserID] = []
            rating_entry = {MovieID: Rating}
            users[UserID].append(rating_entry)

            if UserID not in user_movies:
                user_movies[UserID] = []
            user_movies[UserID].append(MovieID)

    common_user_ids = list(set(users.keys()))
    selected_user_ids = random.sample(common_user_ids, 100)

    trimmed_users = {user_id: users[user_id] for user_id in selected_user_ids}
    trimmed_user_movies = {user_id: user_movies[user_id] for user_id in selected_user_ids}

    for UserID1 in trimmed_user_movies:
        for UserID2 in trimmed_user_movies:
            if UserID1 != UserID2: 
                common_movies = [movie for movie in trimmed_user_movies[UserID1] if movie in trimmed_user_movies[UserID2]]

                if len(common_movies) != 0:
                    if (UserID1, UserID2) not in users_with_same_movies:
                        if (UserID2, UserID1) not in users_with_same_movies:
                            users_with_same_movies[(UserID1, UserID2)] = []

                            for MovieID in common_movies:
                                users_with_same_movies[(UserID1, UserID2)].append(MovieID)
    

    for (UserID1, UserID2) in users_with_same_movies:
        cos_similar = 0
        sum_cos_sim_nominator = 0
        sum_cos_sim_denominator_user1 = 0
        sum_cos_sim_denominator_user2 = 0

        for MovieID in users_with_same_movies[(UserID1, UserID2)]:

            ratings_user1 = {list(movie.keys())[0]: list(movie.values())[0] for movie in trimmed_users[UserID1]}

            rating1 = 0
            for rating_entry in trimmed_users[UserID1]:
                rating1 = ratings_user1.get(MovieID, 0)

            ratings_user2 = {list(movie.keys())[0]: list(movie.values())[0] for movie in trimmed_users[UserID2]}

            rating2 = 0
            for rating_entry in trimmed_users[UserID2]:
                rating2 = ratings_user2.get(MovieID, 0)

            sum_cos_sim_nominator += rating1*rating2
            sum_cos_sim_denominator_user1 += rating1**2
            sum_cos_sim_denominator_user2 += rating2**2

        cos_similar = sum_cos_sim_nominator/(math.sqrt(sum_cos_sim_denominator_user1)*math.sqrt(sum_cos_sim_denominator_user2)) if (math.sqrt(sum_cos_sim_denominator_user1)*math.sqrt(sum_cos_sim_denominator_user2))!=0 else 0

        cosine_users[(UserID1, UserID2)] = cos_similar

    sorted_users = sorted(cosine_users.items(), key=lambda x: x[1], reverse=True)

    with open("first_user_search_of_cosine.txt", "w", encoding="utf-8") as searched_cosine:
        for ((UserID1, UserID2), similarity) in sorted_users:
            searched_cosine.write(f"{UserID1, UserID2}::{similarity}\n")

#-----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
def cosine_similarity(Thetta, g):
    cosine_users = dict()
    if g==0:
        handling_cosine()

    with open("first_user_search_of_cosine.txt", "r", encoding="utf-8") as searched_cosine:
        for line in searched_cosine:
            data = line.strip().split('::')

            pair = data[0]
            similarity = float(data[1])
            cosine_users[pair] = similarity

    final_cosine_users = dict()
    for pair in cosine_users:
        if cosine_users[pair] >= Thetta:
            final_cosine_users[pair] = cosine_users[pair]

    for pair in final_cosine_users:
        print("Users:", pair, "Cosine Similarity:", final_cosine_users[pair], "\n")

    Cos = f"similar_users_{Thetta}.txt"

    with open(Cos, "w", encoding="utf-8") as new_entry:
        for pair in final_cosine_users:
            new_entry.write(f"Users: {pair}, Similarity: {final_cosine_users[pair]}\n")
###################################################################################################################################################################################
###-----------------------------------------------------------------------------------DOMINANCE---------------------------------------------------------------------------------
###################################################################################################################################################################################
def dominance(h):
    if h == 1:
        prints = list()
        with open("dominance.txt", "r", encoding="utf-8") as prev_entry:
                for line in prev_entry:
                    prints.append(line+"\n")
        for i in prints:
            print(i)
        
        returning_variable = ""
        with open("dominance.txt", "r", encoding="utf-8") as returning_file:
            returning_variable = returning_file.read()
        return returning_variable

    movies_that_are_not_dominated = dict()
    average_ratings = dict()
    movies = dict()

    with open("movies.dat","r", encoding="utf-8") as Mov:
        for line in Mov:
            data = line.strip().split('::')

            MovieID = data[0]
            Title = data[1]
            
            movies[MovieID] = Title

    with open("ratings.dat","r") as ratings:
        for line in ratings:
            data = line.strip().split('::')

            MovieID = data[1]
            Rating = float(data[2])
            
            if MovieID in average_ratings:
                average_ratings[MovieID]['Total_Rating'] +=Rating
                average_ratings[MovieID]['Count'] += 1
            else:
                average_ratings[MovieID] = {'Total_Rating': Rating, 'Count': 1}

    for MovieID in movies:
        if MovieID in average_ratings.keys():
            Title = movies[MovieID]
            average_rating = average_ratings[MovieID]['Total_Rating']/average_ratings[MovieID]['Count']
            count = average_ratings[MovieID]['Count']
            movies_that_are_not_dominated[Title] = [count, average_rating]
            for MovieID2 in movies:
                if MovieID2!=MovieID:
                    if MovieID2 in average_ratings.keys():
                        average_rating2 = average_ratings[MovieID2]['Total_Rating']/average_ratings[MovieID2]['Count']
                        count2 = average_ratings[MovieID2]['Count']
                        if average_rating2 >= average_rating and count2>=count:
                            del movies_that_are_not_dominated[Title]
                            break;

    for Title in movies_that_are_not_dominated:
        count, average_rating = movies_that_are_not_dominated[Title]
        print("Movie Title:", Title, "Average Rating:", average_rating, "Total Votes:", count, "\n") 

    with open("dominance.txt", "w", encoding="utf-8") as dom:
        for Title in movies_that_are_not_dominated:
            count, average_rating = movies_that_are_not_dominated[Title]
            dom.write(f"Movie Title: {Title}, Average Rating: {average_rating}, Total Votes: {count}\n")

    returning_variable = ""
    with open("dominance.txt", "r", encoding="utf-8") as returning_file:
        returning_variable = returning_file.read()
    return returning_variable
###################################################################################################################################################################################
###-----------------------------------------------------------------------------------CALL PREVIOUS ENTRIES---------------------------------------------------------------------------------
###################################################################################################################################################################################  
def call_previous_entries(a, b, c):
    prints = list()
    a_b_c = f"{a}_{b}_{c}.txt"
    with open(a_b_c, "r", encoding="utf-8") as prev_entry:
            for line in prev_entry:
                prints.append(line+"\n")
    for i in prints:
        print(i)

    returning_variable = ""
    with open("a_b_c", "r", encoding="utf-8") as returning_file:
        returning_variable = returning_file.read()
    return returning_variable

def call_previous_entries2(a, b):
    prints = list()
    a_b = f"{a}_{b}.txt"
    with open(a_b, "r", encoding="utf-8") as prev_entry:
            for line in prev_entry:
                prints.append(line+"\n")
    for i in prints:
        print(i)

def check_if_previous_entry_exists(prev_entries, key, b, c):
    for entry in prev_entries:
        print(entry,"\n\n")
        if key in entry:
            if c is None:
                if entry[key] == b:
                    return False
            else:
                if entry[key] == [b,c]:
                   return False       
    return True
###################################################################################################################################################################################
###-----------------------------------------------------------------------------------MAIN---------------------------------------------------------------------------------
###################################################################################################################################################################################
def main():
    a = 0
    b = 0
    c = 0
    d = 0
    e = 0
    f = 0
    g = 0
    h = 0
    previous_entries = list()
    last_10_inputs = dict()
    new_entry = False
    while(True):
        print("\nChoose\n\n 1) rating T1 T2: find all movies with rating between T1 and T2\n\n 2) top_movies K: find all movies with rating over K \n\n 3) user_pairs K: find all user pairs that have given rating to the same movie\n\n\
 4) dominance: find users that aren't dominated from other movies\n\n 5) iceberg K T: find movies that have been rated at least K times with average score over T\n\n 6) top_user K: find the K users that have rated the most movies\n\n\
 7) movie_sample S: find a percentage of movies from all categories\n\n 8) similar_users Θ: find users that have similar tastes in movies based on cosine similarity\n\n 9) S to stop\n\n")
        mode = [i for i in input(" ").split(' ')]

        if mode[0] == "S":
            break;
#-----------------------------------------------------------------------------------------------------------------------------------------------------------------
        if mode[0] == "rating":

            new_entry = check_if_previous_entry_exists(previous_entries, mode[0], mode[1], mode[2])
            if(new_entry):
                find_movies_between_T1_T2(float(mode[1]), float(mode[2]), a)
            else:
                call_previous_entries(mode[0], float(mode[1]), float(mode[2]))
            a = 1
#-----------------------------------------------------------------------------------------------------------------------------------------------------------------
        elif mode[0] == "top_movies":

            new_entry = check_if_previous_entry_exists(previous_entries, mode[0], mode[1], None)
            if(new_entry):
                find_top_movies(int(mode[1]), b)
            else:
                call_previous_entries2(mode[0], int(mode[1]))
            b = 1
#-----------------------------------------------------------------------------------------------------------------------------------------------------------------
        elif mode[0]== "user_pairs":

            new_entry = check_if_previous_entry_exists(previous_entries, mode[0], mode[1], None)
            if(new_entry):
                find_user_pairs(int(mode[1]), c)
            else:
                call_previous_entries2(mode[0], int(mode[1]))
            c = 1
#-----------------------------------------------------------------------------------------------------------------------------------------------------------------
        elif mode[0]== "iceberg":

            new_entry = check_if_previous_entry_exists(previous_entries, mode[0], mode[1], mode[2]) 
            if(new_entry):
                iceberg(int(mode[1]), float(mode[2]), d)
            else:
                call_previous_entries(mode[0], int(mode[1]), float(mode[2]))
                d = 1
#-----------------------------------------------------------------------------------------------------------------------------------------------------------------
        elif mode[0]== "top_user":

            new_entry = check_if_previous_entry_exists(previous_entries, mode[0], mode[1], None)
            if(new_entry):
                top_users(int(mode[1]), e)
            else:
                call_previous_entries2(mode[0], int(mode[1]))
            e = 1
#-----------------------------------------------------------------------------------------------------------------------------------------------------------------
        elif mode[0]== "movie_sample":

            new_entry = check_if_previous_entry_exists(previous_entries, mode[0], mode[1], None)
            if(new_entry):
                movie_sample(int(mode[1]), f)
            else:
                call_previous_entries2(mode[0], int(mode[1]))
            f = 1
#-----------------------------------------------------------------------------------------------------------------------------------------------------------------
        elif mode[0]== "similar_users":

            new_entry = check_if_previous_entry_exists(previous_entries, mode[0], mode[1], None)
            if(new_entry):
                cosine_similarity(float(mode[1]), g)
            else:
                call_previous_entries2(mode[0], float(mode[1]))
            g = 1
#-----------------------------------------------------------------------------------------------------------------------------------------------------------------
        elif mode[0]== "dominance":
            dominance(h)
            h = 1
#-----------------------------------------------------------------------------------------------------------------------------------------------------------------
        else : 
            print("not a choice, choose again")
            new_entry = False

        if(new_entry):
            if len(last_10_inputs)<10:
                if len(mode)==2:
                    last_10_inputs[mode[0]] = mode[1]
                elif len(mode)== 3:
                    last_10_inputs[mode[0]] = [mode[1], mode[2]]
            previous_entries.append({mode[0]: last_10_inputs[mode[0]]})

if __name__ == "__main__":
    main()
# Out:
# Overwriting Unit_testing_phase.py

# %%
# %%file test.py
import unittest
from Unit_testing_phase import find_movies_between_T1_T2, find_top_movies, find_user_pairs, dominance, iceberg, top_users



class Test_find_movies_between_T1_T2(unittest.TestCase):
    def test_check_outcome(self):
        with open("rating_4.9_5.0.txt", "r", encoding="utf-8") as searched_ratings:
            self.assertEqual(find_movies_between_T1_T2(4.9, 5.0, 0), searched_ratings.read())



class Test_find_top_movies(unittest.TestCase):
    def test_check_outcome(self):
        with open("top_movies_1.txt", "r", encoding="utf-8") as searched_ratings:
            self.assertEqual(find_top_movies(1, 0), searched_ratings.read())



class Test_find_user_pairs(unittest.TestCase):
    def test_check_outcome(self):
        with open("user_pairs_1.txt", "r", encoding="utf-8") as searched_ratings:
            self.assertEqual(find_user_pairs(1, 0), searched_ratings.read())



class Test_dominance(unittest.TestCase):
    def test_check_outcome(self):
        with open("dominance.txt", "r", encoding="utf-8") as searched_ratings:
            self.assertEqual(dominance(0), searched_ratings.read())



class Test_top_users(unittest.TestCase):
    def test_check_outcome(self):
        with open("top_user_1.txt", "r", encoding="utf-8") as searched_ratings:
            self.assertEqual(top_users(1, 0), searched_ratings.read())



class Test_iceberg(unittest.TestCase):
    def test_check_outcome(self):
        with open("iceberg_100_4.0.txt", "r", encoding="utf-8") as searched_ratings:
            self.assertEqual(iceberg(100, 4.0,0), searched_ratings.read())

if __name__ == "__main__":
    unittest.main()
# Out:
# Overwriting test.py

# %%
# !python test.py
# Out:
# Movie Title: Pulp Fiction (1994) Average Rating: 4.157425998164295 Total Votes: 34864
#
# Movie Title: Shawshank Redemption, The (1994) Average Rating: 4.457238321660348 Total Votes: 31126
#
# Movie Title: Silence of the Lambs, The (1991) Average Rating: 4.2041998336699535 Total Votes: 33668
#
# Movie Title: More (1998) Average Rating: 4.75 Total Votes: 8
#
# Movie Title: Satan's Tango (Sátántangó) (1994) Average Rating: 5.0 Total Votes: 2
#
# Movie Title: Satan's Tango (Sátántangó) (1994) Average Rating: 5.0
#
# Movie Title: Shadows of Forgotten Ancestors (1964) Average Rating: 5.0
#
# Movie Title: Fighting Elegy (Kenka erejii) (1966) Average Rating: 5.0
#
# Movie Title: Sun Alley (Sonnenallee) (1999) Average Rating: 5.0
#
# Movie Title: Blue Light, The (Das Blaue Licht) (1932) Average Rating: 5.0
#
# Movie Title: Satan's Tango (Sátántangó) (1994) Average Rating: 5.0
#
# Movie Title: Julien Donkey-Boy (1999) Users Pair: [854, 2219]
#
# Movie Title: 356 Number of critics: 34457 Average Rating: 4.0135821458629595
#
# Movie Title: 110 Number of critics: 29154 Average Rating: 4.0823900665431845
#
# Movie Title: 260 Number of critics: 28566 Average Rating: 4.2202093397745575
#
# Movie Title: 858 Number of critics: 19814 Average Rating: 4.415085293227011
#
# Movie Title: 213 Number of critics: 1143 Average Rating: 4.059492563429571
#
# Movie Title: 1148 Number of critics: 7932 Average Rating: 4.275907715582451
#
# Movie Title: 1252 Number of critics: 8211 Average Rating: 4.242479600535867
#
# Movie Title: 1276 Number of critics: 6049 Average Rating: 4.135228963465035
#
# Movie Title: 1288 Number of critics: 8786 Average Rating: 4.071249715456408
#
# Movie Title: 5952 Number of critics: 14389 Average Rating: 4.120404475641115
#
# Movie Title: 7153 Number of critics: 12366 Average Rating: 4.155264434740417
#
# Movie Title: 28 Number of critics: 1828 Average Rating: 4.076039387308534
#
# Movie Title: 47 Number of critics: 22521 Average Rating: 4.031237511655788
#
# Movie Title: 58 Number of critics: 6951 Average Rating: 4.011293339087901
#
# Movie Title: 111 Number of critics: 12865 Average Rating: 4.132102603964244
#
# Movie Title: 232 Number of critics: 3843 Average Rating: 4.064532916991934
#
# Movie Title: 306 Number of critics: 4055 Average Rating: 4.1366214549938345
#
# Movie Title: 307 Number of critics: 3675 Average Rating: 4.013333333333334
#
# Movie Title: 326 Number of critics: 804 Average Rating: 4.1038557213930345
#
# Movie Title: 527 Number of critics: 25777 Average Rating: 4.363482949916592
#
# Movie Title: 541 Number of critics: 15471 Average Rating: 4.151573912481417
#
# Movie Title: 593 Number of critics: 33668 Average Rating: 4.2041998336699535
#
# Movie Title: 608 Number of critics: 23794 Average Rating: 4.133352946120871
#
# Movie Title: 778 Number of critics: 11791 Average Rating: 4.011534221016029
#
# Movie Title: 903 Number of critics: 7491 Average Rating: 4.157856093979442
#
# Movie Title: 912 Number of critics: 12507 Average Rating: 4.319740945070761
#
# Movie Title: 919 Number of critics: 12851 Average Rating: 4.002918060851296
#
# Movie Title: 923 Number of critics: 9605 Average Rating: 4.183550234252993
#
# Movie Title: 926 Number of critics: 2530 Average Rating: 4.243675889328063
#
# Movie Title: 969 Number of critics: 5852 Average Rating: 4.125085440874915
#
# Movie Title: 1041 Number of critics: 3461 Average Rating: 4.068332851776943
#
# Movie Title: 1046 Number of critics: 730 Average Rating: 4.028082191780822
#
# Movie Title: 1104 Number of critics: 3364 Average Rating: 4.071046373365042
#
# Movie Title: 1172 Number of critics: 4698 Average Rating: 4.189761600681141
#
# Movie Title: 1199 Number of critics: 7357 Average Rating: 4.04492320239228
#
# Movie Title: 1206 Number of critics: 11925 Average Rating: 4.005157232704403
#
# Movie Title: 1207 Number of critics: 7812 Average Rating: 4.228430619559652
#
# Movie Title: 1219 Number of critics: 10384 Average Rating: 4.093990755007704
#
# Movie Title: 1221 Number of critics: 13281 Average Rating: 4.303215119343423
#
# Movie Title: 1225 Number of critics: 11118 Average Rating: 4.096060442525634
#
# Movie Title: 1230 Number of critics: 8405 Average Rating: 4.104223676383105
#
# Movie Title: 1235 Number of critics: 4060 Average Rating: 4.03731527093596
#
# Movie Title: 1244 Number of critics: 4238 Average Rating: 4.100873053327041
#
# Movie Title: 1247 Number of critics: 9150 Average Rating: 4.102896174863388
#
# Movie Title: 1258 Number of critics: 11423 Average Rating: 4.003895649128951
#
# Movie Title: 1280 Number of critics: 1824 Average Rating: 4.183662280701754
#
# Movie Title: 1300 Number of critics: 2173 Average Rating: 4.022549470777727
#
# Movie Title: 457 Number of critics: 28951 Average Rating: 4.006925494801561
#
# Movie Title: 1193 Number of critics: 14435 Average Rating: 4.292379632836855
#
# Movie Title: 1196 Number of critics: 23091 Average Rating: 4.1943614395218916
#
# Movie Title: 1197 Number of critics: 16520 Average Rating: 4.194158595641646
#
# Movie Title: 1198 Number of critics: 21803 Average Rating: 4.261317249919736
#
# Movie Title: 1264 Number of critics: 1633 Average Rating: 4.045315370483772
#
# Movie Title: 1304 Number of critics: 8880 Average Rating: 4.06204954954955
#
# Movie Title: 2028 Number of critics: 18924 Average Rating: 4.082699217924329
#
# Movie Title: 2571 Number of critics: 23229 Average Rating: 4.2051315166386845
#
# Movie Title: 50 Number of critics: 24037 Average Rating: 4.367142322253193
#
# Movie Title: 599 Number of critics: 1750 Average Rating: 4.031142857142857
#
# Movie Title: 800 Number of critics: 4529 Average Rating: 4.077279752704792
#
# Movie Title: 899 Number of critics: 5249 Average Rating: 4.129548485425795
#
# Movie Title: 904 Number of critics: 8825 Average Rating: 4.316543909348442
#
# Movie Title: 908 Number of critics: 8402 Average Rating: 4.261366341347299
#
# Movie Title: 913 Number of critics: 6637 Average Rating: 4.242278137712822
#
# Movie Title: 930 Number of critics: 2705 Average Rating: 4.219038817005545
#
# Movie Title: 942 Number of critics: 1478 Average Rating: 4.129905277401894
#
# Movie Title: 951 Number of critics: 2084 Average Rating: 4.21521113243762
#
# Movie Title: 954 Number of critics: 2955 Average Rating: 4.061082910321489
#
# Movie Title: 1086 Number of critics: 2988 Average Rating: 4.0471887550200805
#
# Movie Title: 1212 Number of critics: 3265 Average Rating: 4.313629402756509
#
# Movie Title: 1234 Number of critics: 8179 Average Rating: 4.188225944491991
#
# Movie Title: 1248 Number of critics: 2665 Average Rating: 4.203939962476547
#
# Movie Title: 1254 Number of critics: 2891 Average Rating: 4.186440677966102
#
# Movie Title: 1256 Number of critics: 3053 Average Rating: 4.1562397641663935
#
# Movie Title: 1260 Number of critics: 2143 Average Rating: 4.2662155856276245
#
# Movie Title: 1283 Number of critics: 2805 Average Rating: 4.107843137254902
#
# Movie Title: 1284 Number of critics: 2980 Average Rating: 4.267953020134228
#
# Movie Title: 1617 Number of critics: 15018 Average Rating: 4.0943867359169
#
# Movie Title: 2186 Number of critics: 2665 Average Rating: 4.196998123827392
#
# Movie Title: 2203 Number of critics: 1154 Average Rating: 4.195407279029463
#
# Movie Title: 2762 Number of critics: 19400 Average Rating: 4.108376288659794
#
# Movie Title: 2804 Number of critics: 7065 Average Rating: 4.089101203113942
#
# Movie Title: 2936 Number of critics: 754 Average Rating: 4.115384615384615
#
# Movie Title: 3334 Number of critics: 1575 Average Rating: 4.02952380952381
#
# Movie Title: 3365 Number of critics: 1098 Average Rating: 4.002276867030965
#
# Movie Title: 3435 Number of critics: 2403 Average Rating: 4.315439034540158
#
# Movie Title: 3467 Number of critics: 883 Average Rating: 4.019818799546999
#
# Movie Title: 3730 Number of critics: 1904 Average Rating: 4.116071428571429
#
# Movie Title: 4226 Number of critics: 12891 Average Rating: 4.209332092157319
#
# Movie Title: 4432 Number of critics: 390 Average Rating: 4.1179487179487175
#
# Movie Title: 5017 Number of critics: 291 Average Rating: 4.0446735395189
#
# Movie Title: 6273 Number of critics: 146 Average Rating: 4.1506849315068495
#
# Movie Title: 290 Number of critics: 2408 Average Rating: 4.020348837209302
#
# Movie Title: 293 Number of critics: 13042 Average Rating: 4.010236160098144
#
# Movie Title: 678 Number of critics: 1462 Average Rating: 4.125512995896033
#
# Movie Title: 1089 Number of critics: 13428 Average Rating: 4.091636878165028
#
# Movie Title: 1136 Number of critics: 16242 Average Rating: 4.20613224972294
#
# Movie Title: 1200 Number of critics: 14167 Average Rating: 4.004764593774264
#
# Movie Title: 1204 Number of critics: 6773 Average Rating: 4.209582164476598
#
# Movie Title: 1208 Number of critics: 11688 Average Rating: 4.11490417522245
#
# Movie Title: 1214 Number of critics: 15843 Average Rating: 4.037903174903743
#
# Movie Title: 1253 Number of critics: 3239 Average Rating: 4.01065143562828
#
# Movie Title: 1262 Number of critics: 5597 Average Rating: 4.175808468822583
#
# Movie Title: 1291 Number of critics: 16145 Average Rating: 4.0143388045834625
#
# Movie Title: 1358 Number of critics: 7733 Average Rating: 4.049980602612181
#
# Movie Title: 1704 Number of critics: 13865 Average Rating: 4.011395600432745
#
# Movie Title: 2329 Number of critics: 9573 Average Rating: 4.148438316097357
#
# Movie Title: 2858 Number of critics: 22120 Average Rating: 4.189195298372513
#
# Movie Title: 2959 Number of critics: 16334 Average Rating: 4.190033059875107
#
# Movie Title: 4011 Number of critics: 7456 Average Rating: 4.011131974248927
#
# Movie Title: 4878 Number of critics: 7225 Average Rating: 4.045674740484429
#
# Movie Title: 4993 Number of critics: 15938 Average Rating: 4.161218471577362
#
# Movie Title: 3429 Number of critics: 1381 Average Rating: 4.204199855177408
#
# Movie Title: 7361 Number of critics: 8393 Average Rating: 4.130525437864887
#
# Movie Title: 26131 Number of critics: 491 Average Rating: 4.117107942973523
#
# Movie Title: 296 Number of critics: 34864 Average Rating: 4.157425998164295
#
# Movie Title: 1131 Number of critics: 1842 Average Rating: 4.195168295331162
#
# Movie Title: 1132 Number of critics: 1782 Average Rating: 4.13692480359147
#
# Movie Title: 1211 Number of critics: 1994 Average Rating: 4.035606820461384
#
# Movie Title: 1213 Number of critics: 13188 Average Rating: 4.186684865028814
#
# Movie Title: 1228 Number of critics: 5023 Average Rating: 4.126119848695998
#
# Movie Title: 1233 Number of critics: 7507 Average Rating: 4.16930864526442
#
# Movie Title: 1273 Number of critics: 1419 Average Rating: 4.031712473572939
#
# Movie Title: 1293 Number of critics: 5140 Average Rating: 4.042801556420233
#
# Movie Title: 2931 Number of critics: 160 Average Rating: 4.071875
#
# Movie Title: 750 Number of critics: 11774 Average Rating: 4.298072023101749
#
# Movie Title: 1203 Number of critics: 5365 Average Rating: 4.2381174277726
#
# Movie Title: 953 Number of critics: 7485 Average Rating: 4.073213092852371
#
# Movie Title: 1066 Number of critics: 815 Average Rating: 4.043558282208589
#
# Movie Title: 1175 Number of critics: 3560 Average Rating: 4.031039325842697
#
# Movie Title: 2360 Number of critics: 1103 Average Rating: 4.191296464188577
#
# Movie Title: 965 Number of critics: 1949 Average Rating: 4.065674704976911
#
# Movie Title: 3634 Number of critics: 482 Average Rating: 4.08402489626556
#
# Movie Title: 318 Number of critics: 31126 Average Rating: 4.457238321660348
#
# Movie Title: 1222 Number of critics: 10898 Average Rating: 4.024729308129932
#
# Movie Title: 1242 Number of critics: 6882 Average Rating: 4.023031095611741
#
# Movie Title: 1250 Number of critics: 7021 Average Rating: 4.144993590656601
#
# Movie Title: 1259 Number of critics: 11510 Average Rating: 4.007906168549088
#
# Movie Title: 1299 Number of critics: 4123 Average Rating: 4.150012127091923
#
# Movie Title: 3811 Number of critics: 1011 Average Rating: 4.115727002967359
#
# Movie Title: 246 Number of critics: 6438 Average Rating: 4.05824790307549
#
# Movie Title: 720 Number of critics: 4356 Average Rating: 4.22979797979798
#
# Movie Title: 916 Number of critics: 3033 Average Rating: 4.117375535773162
#
# Movie Title: 922 Number of critics: 3255 Average Rating: 4.321966205837174
#
# Movie Title: 955 Number of critics: 2421 Average Rating: 4.070218917802561
#
# Movie Title: 1201 Number of critics: 7107 Average Rating: 4.102293513437456
#
# Movie Title: 1223 Number of critics: 3947 Average Rating: 4.159994932860401
#
# Movie Title: 1224 Number of critics: 2762 Average Rating: 4.139753801593049
#
# Movie Title: 1278 Number of critics: 8297 Average Rating: 4.020308545257322
#
# Movie Title: 2019 Number of critics: 5751 Average Rating: 4.314119283602851
#
# Movie Title: 745 Number of critics: 6332 Average Rating: 4.274952621604548
#
# Movie Title: 3949 Number of critics: 5778 Average Rating: 4.037642782969886
#
# Movie Title: 3983 Number of critics: 1702 Average Rating: 4.0887191539365455
#
# Movie Title: 1272 Number of critics: 4428 Average Rating: 4.107046070460704
#
# Movie Title: 1209 Number of critics: 1902 Average Rating: 4.1511566771819135
#
# Movie Title: 3000 Number of critics: 4125 Average Rating: 4.059515151515152
#
# Movie Title: 2692 Number of critics: 8936 Average Rating: 4.060765443151298
#
# Movie Title: 3362 Number of critics: 3478 Average Rating: 4.011069580218517
#
# Movie Title: 5782 Number of critics: 1825 Average Rating: 4.10931506849315
#
# Movie Title: 4973 Number of critics: 9681 Average Rating: 4.246875322797232
#
# Movie Title: 30749 Number of critics: 3181 Average Rating: 4.10609871109714
#
# Movie Title: 48394 Number of critics: 2980 Average Rating: 4.075671140939598
#
# Movie Title: 56367 Number of critics: 2482 Average Rating: 4.0
#
# Movie Title: 1147 Number of critics: 2151 Average Rating: 4.178056717805672
#
# Movie Title: 898 Number of critics: 3534 Average Rating: 4.211799660441426
#
# Movie Title: 910 Number of critics: 5816 Average Rating: 4.108923658872077
#
# Movie Title: 162 Number of critics: 3599 Average Rating: 4.00958599611003
#
# Movie Title: 602 Number of critics: 208 Average Rating: 4.0625
#
# Movie Title: 994 Number of critics: 3227 Average Rating: 4.0319181902696
#
# Movie Title: 2324 Number of critics: 8842 Average Rating: 4.172755032798009
#
# Movie Title: 1269 Number of critics: 3717 Average Rating: 4.074656981436642
#
# Movie Title: 905 Number of critics: 2286 Average Rating: 4.197287839020123
#
# Movie Title: 906 Number of critics: 1134 Average Rating: 4.0476190476190474
#
# Movie Title: 909 Number of critics: 2679 Average Rating: 4.052258305337813
#
# Movie Title: 911 Number of critics: 2137 Average Rating: 4.087505849321479
#
# Movie Title: 928 Number of critics: 2547 Average Rating: 4.149784059678052
#
# Movie Title: 933 Number of critics: 2631 Average Rating: 4.043709616115545
#
# Movie Title: 945 Number of critics: 1246 Average Rating: 4.069422150882825
#
# Movie Title: 947 Number of critics: 947 Average Rating: 4.113516367476241
#
# Movie Title: 950 Number of critics: 1857 Average Rating: 4.222670974690361
#
# Movie Title: 1178 Number of critics: 1778 Average Rating: 4.306805399325085
#
# Movie Title: 1238 Number of critics: 1907 Average Rating: 4.003408495018354
#
# Movie Title: 1719 Number of critics: 2302 Average Rating: 4.011946133796698
#
# Movie Title: 1939 Number of critics: 1010 Average Rating: 4.154950495049505
#
# Movie Title: 1945 Number of critics: 2990 Average Rating: 4.210367892976588
#
# Movie Title: 2066 Number of critics: 553 Average Rating: 4.17631103074141
#
# Movie Title: 2208 Number of critics: 1156 Average Rating: 4.132352941176471
#
# Movie Title: 2612 Number of critics: 607 Average Rating: 4.0
#
# Movie Title: 2788 Number of critics: 2997 Average Rating: 4.022355689022356
#
# Movie Title: 2940 Number of critics: 547 Average Rating: 4.004570383912249
#
# Movie Title: 2973 Number of critics: 2237 Average Rating: 4.018998658918194
#
# Movie Title: 3022 Number of critics: 1112 Average Rating: 4.257643884892087
#
# Movie Title: 3037 Number of critics: 2380 Average Rating: 4.001470588235295
#
# Movie Title: 3088 Number of critics: 1800 Average Rating: 4.0175
#
# Movie Title: 3095 Number of critics: 2025 Average Rating: 4.050864197530864
#
# Movie Title: 3097 Number of critics: 867 Average Rating: 4.014994232987313
#
# Movie Title: 3152 Number of critics: 1553 Average Rating: 4.022858982614295
#
# Movie Title: 3307 Number of critics: 1210 Average Rating: 4.216942148760331
#
# Movie Title: 3504 Number of critics: 2573 Average Rating: 4.031480761756704
#
# Movie Title: 3629 Number of critics: 1025 Average Rating: 4.115609756097561
#
# Movie Title: 3683 Number of critics: 2592 Average Rating: 4.089699074074074
#
# Movie Title: 3801 Number of critics: 846 Average Rating: 4.1046099290780145
#
# Movie Title: 3819 Number of critics: 930 Average Rating: 4.153225806451613
#
# Movie Title: 4037 Number of critics: 1083 Average Rating: 4.0055401662049865
#
# Movie Title: 4914 Number of critics: 707 Average Rating: 4.016973125884017
#
# Movie Title: 4920 Number of critics: 233 Average Rating: 4.017167381974249
#
# Movie Title: 5120 Number of critics: 626 Average Rating: 4.0
#
# Movie Title: 6787 Number of critics: 1939 Average Rating: 4.063434760185663
#
# Movie Title: 7215 Number of critics: 433 Average Rating: 4.07852193995381
#
# Movie Title: 4235 Number of critics: 2495 Average Rating: 4.013426853707415
#
# Movie Title: 1217 Number of critics: 2627 Average Rating: 4.205557670346403
#
# Movie Title: 1281 Number of critics: 1809 Average Rating: 4.065229408512991
#
# Movie Title: 2010 Number of critics: 2733 Average Rating: 4.01719721917307
#
# Movie Title: 2351 Number of critics: 588 Average Rating: 4.155612244897959
#
# Movie Title: 2726 Number of critics: 1050 Average Rating: 4.126190476190477
#
# Movie Title: 2731 Number of critics: 1330 Average Rating: 4.207894736842105
#
# Movie Title: 2935 Number of critics: 751 Average Rating: 4.195739014647137
#
# Movie Title: 3030 Number of critics: 1693 Average Rating: 4.277613703484938
#
# Movie Title: 3089 Number of critics: 1477 Average Rating: 4.206838185511171
#
# Movie Title: 3134 Number of critics: 842 Average Rating: 4.216745843230404
#
# Movie Title: 3462 Number of critics: 1663 Average Rating: 4.184906794948888
#
# Movie Title: 3468 Number of critics: 2075 Average Rating: 4.153012048192771
#
# Movie Title: 5008 Number of critics: 687 Average Rating: 4.16448326055313
#
# Movie Title: 5291 Number of critics: 1591 Average Rating: 4.248271527341295
#
# Movie Title: 5304 Number of critics: 213 Average Rating: 4.030516431924883
#
# Movie Title: 6254 Number of critics: 271 Average Rating: 4.016605166051661
#
# Movie Title: 6611 Number of critics: 143 Average Rating: 4.055944055944056
#
# Movie Title: 6643 Number of critics: 242 Average Rating: 4.074380165289257
#
# Movie Title: 6650 Number of critics: 372 Average Rating: 4.176075268817204
#
# Movie Title: 6783 Number of critics: 331 Average Rating: 4.1299093655589125
#
# Movie Title: 6985 Number of critics: 300 Average Rating: 4.083333333333333
#
# Movie Title: 7013 Number of critics: 579 Average Rating: 4.089810017271157
#
# Movie Title: 7091 Number of critics: 429 Average Rating: 4.012820512820513
#
# Movie Title: 7116 Number of critics: 426 Average Rating: 4.012910798122066
#
# Movie Title: 7132 Number of critics: 713 Average Rating: 4.061711079943899
#
# Movie Title: 7234 Number of critics: 377 Average Rating: 4.111405835543766
#
# Movie Title: 7327 Number of critics: 353 Average Rating: 4.152974504249292
#
# Movie Title: 7700 Number of critics: 261 Average Rating: 4.14367816091954
#
# Movie Title: 7706 Number of critics: 448 Average Rating: 4.016741071428571
#
# Movie Title: 8125 Number of critics: 165 Average Rating: 4.0606060606060606
#
# Movie Title: 8199 Number of critics: 141 Average Rating: 4.01063829787234
#
# Movie Title: 8228 Number of critics: 1226 Average Rating: 4.108075040783034
#
# Movie Title: 8620 Number of critics: 127 Average Rating: 4.031496062992126
#
# Movie Title: 48516 Number of critics: 4145 Average Rating: 4.09686369119421
#
# Movie Title: 1251 Number of critics: 1554 Average Rating: 4.074002574002574
#
# Movie Title: 1267 Number of critics: 5120 Average Rating: 4.16796875
#
# Movie Title: 1952 Number of critics: 3460 Average Rating: 4.03771676300578
#
# Movie Title: 2132 Number of critics: 1668 Average Rating: 4.094124700239808
#
# Movie Title: 2920 Number of critics: 553 Average Rating: 4.208860759493671
#
# Movie Title: 581 Number of critics: 1156 Average Rating: 4.012975778546712
#
# Movie Title: 1292 Number of critics: 3535 Average Rating: 4.003818953323904
#
# Movie Title: 1949 Number of critics: 1159 Average Rating: 4.151423641069888
#
# Movie Title: 1303 Number of critics: 2029 Average Rating: 4.068260226712666
#
# Movie Title: 2859 Number of critics: 1184 Average Rating: 4.130912162162162
#
# Movie Title: 3035 Number of critics: 1508 Average Rating: 4.064655172413793
#
# Movie Title: 3470 Number of critics: 462 Average Rating: 4.095238095238095
#
# Movie Title: 4427 Number of critics: 868 Average Rating: 4.091013824884793
#
# Movie Title: 2357 Number of critics: 1396 Average Rating: 4.141117478510028
#
# Movie Title: 5995 Number of critics: 4212 Average Rating: 4.0754985754985755
#
# Movie Title: 8491 Number of critics: 293 Average Rating: 4.039249146757679
#
# Movie Title: 53123 Number of critics: 525 Average Rating: 4.025714285714286
#
# Movie Title: 55820 Number of critics: 2411 Average Rating: 4.020116134384073
#
# Movie Title: 59315 Number of critics: 2013 Average Rating: 4.000993541977149
#
# Movie Title: 1218 Number of critics: 1614 Average Rating: 4.101920693928129
#
# Movie Title: 3359 Number of critics: 1753 Average Rating: 4.040501996577296
#
# Movie Title: 82 Number of critics: 1585 Average Rating: 4.028391167192429
#
# Movie Title: 1189 Number of critics: 1521 Average Rating: 4.16370808678501
#
# Movie Title: 3090 Number of critics: 694 Average Rating: 4.118876080691643
#
# Movie Title: 3265 Number of critics: 1501 Average Rating: 4.012325116588941
#
# Movie Title: 5932 Number of critics: 122 Average Rating: 4.061475409836065
#
# Movie Title: 6235 Number of critics: 482 Average Rating: 4.039419087136929
#
# Movie Title: 6791 Number of critics: 584 Average Rating: 4.017979452054795
#
# Movie Title: 7156 Number of critics: 1173 Average Rating: 4.124893435635124
#
# Movie Title: 5618 Number of critics: 4835 Average Rating: 4.186452947259566
#
# Movie Title: 6350 Number of critics: 1167 Average Rating: 4.057840616966581
#
# Movie Title: 31658 Number of critics: 1494 Average Rating: 4.0244310575635875
#
# Movie Title: 214 Number of critics: 574 Average Rating: 4.084494773519164
#
# Movie Title: 1927 Number of critics: 1439 Average Rating: 4.014940931202224
#
# Movie Title: 6016 Number of critics: 4370 Average Rating: 4.261899313501144
#
# Movie Title: 1950 Number of critics: 1884 Average Rating: 4.08651804670913
#
# Movie Title: 3077 Number of critics: 569 Average Rating: 4.1203866432337435
#
# Movie Title: 3196 Number of critics: 1588 Average Rating: 4.136964735516373
#
# Movie Title: 5690 Number of critics: 1141 Average Rating: 4.11262050832603
#
# Movie Title: 363 Number of critics: 385 Average Rating: 4.068831168831169
#
# Movie Title: 1237 Number of critics: 1980 Average Rating: 4.094949494949495
#
# Movie Title: 2925 Number of critics: 422 Average Rating: 4.138625592417061
#
# Movie Title: 632 Number of critics: 195 Average Rating: 4.005128205128205
#
# Movie Title: 1236 Number of critics: 556 Average Rating: 4.070143884892087
#
# Movie Title: 1361 Number of critics: 873 Average Rating: 4.097365406643757
#
# Movie Title: 1446 Number of critics: 1383 Average Rating: 4.022053506869125
#
# Movie Title: 3083 Number of critics: 2215 Average Rating: 4.029345372460496
#
# Movie Title: 2905 Number of critics: 589 Average Rating: 4.131578947368421
#
# Movie Title: 4783 Number of critics: 340 Average Rating: 4.030882352941177
#
# Movie Title: 5498 Number of critics: 190 Average Rating: 4.089473684210526
#
# Movie Title: 5971 Number of critics: 1623 Average Rating: 4.138940234134319
#
# Movie Title: 6023 Number of critics: 179 Average Rating: 4.0474860335195535
#
# Movie Title: 7099 Number of critics: 958 Average Rating: 4.087682672233821
#
# Movie Title: 7256 Number of critics: 888 Average Rating: 4.100225225225225
#
# Movie Title: 7766 Number of critics: 453 Average Rating: 4.140176600441501
#
# Movie Title: 7925 Number of critics: 440 Average Rating: 4.0125
#
# Movie Title: 8580 Number of critics: 194 Average Rating: 4.002577319587629
#
# Movie Title: 665 Number of critics: 578 Average Rating: 4.000865051903114
#
# Movie Title: 2843 Number of critics: 545 Average Rating: 4.0715596330275226
#
# Movie Title: 3091 Number of critics: 701 Average Rating: 4.09700427960057
#
# Movie Title: 4144 Number of critics: 916 Average Rating: 4.056768558951965
#
# Movie Title: 5059 Number of critics: 137 Average Rating: 4.032846715328467
#
# Movie Title: 6331 Number of critics: 1520 Average Rating: 4.035526315789474
#
# Movie Title: 8014 Number of critics: 600 Average Rating: 4.02
#
# Movie Title: 27773 Number of critics: 1709 Average Rating: 4.073142188414278
#
# Movie Title: 8477 Number of critics: 241 Average Rating: 4.08298755186722
#
# Movie Title: 60069 Number of critics: 1389 Average Rating: 4.133189344852412
#
# Movie Title: 5147 Number of critics: 692 Average Rating: 4.144508670520231
#
# Movie Title: 6669 Number of critics: 482 Average Rating: 4.175311203319502
#
# Movie Title: 7478 Number of critics: 212 Average Rating: 4.033018867924528
#
# Movie Title: 7762 Number of critics: 142 Average Rating: 4.183098591549296
#
# Movie Title: 1537 Number of critics: 2199 Average Rating: 4.067530695770805
#
# Movie Title: 5878 Number of critics: 1604 Average Rating: 4.0208852867830425
#
# Movie Title: 936 Number of critics: 813 Average Rating: 4.071955719557195
#
# Movie Title: 3741 Number of critics: 1038 Average Rating: 4.059730250481696
#
# Movie Title: 27611 Number of critics: 168 Average Rating: 4.068452380952381
#
# Movie Title: 58559 Number of critics: 2598 Average Rating: 4.294842186297152
#
# Movie Title: 7096 Number of critics: 131 Average Rating: 4.049618320610687
#
# Movie Title: 38304 Number of critics: 276 Average Rating: 4.072463768115942
#
# Movie Title: 7396 Number of critics: 192 Average Rating: 4.078125
#
# Movie Title: 668 Number of critics: 406 Average Rating: 4.227832512315271
#
# Movie Title: 670 Number of critics: 423 Average Rating: 4.211583924349882
#
# Movie Title: 1111 Number of critics: 1002 Average Rating: 4.014471057884232
#
# Movie Title: 4298 Number of critics: 337 Average Rating: 4.129080118694362
#
# Movie Title: 4928 Number of critics: 273 Average Rating: 4.0989010989010985
#
# Movie Title: 5333 Number of critics: 139 Average Rating: 4.003597122302159
#
# Movie Title: 5385 Number of critics: 458 Average Rating: 4.045851528384279
#
# Movie Title: 6433 Number of critics: 180 Average Rating: 4.016666666666667
#
# Movie Title: 6918 Number of critics: 182 Average Rating: 4.085164835164835
#
# Movie Title: 6935 Number of critics: 106 Average Rating: 4.037735849056604
#
# Movie Title: 7043 Number of critics: 112 Average Rating: 4.004464285714286
#
# Movie Title: 7135 Number of critics: 213 Average Rating: 4.007042253521127
#
# Movie Title: 7820 Number of critics: 176 Average Rating: 4.059659090909091
#
# Movie Title: 7926 Number of critics: 229 Average Rating: 4.137554585152839
#
# Movie Title: 7941 Number of critics: 134 Average Rating: 4.07089552238806
#
# Movie Title: 27727 Number of critics: 220 Average Rating: 4.006818181818182
#
# Movie Title: 27815 Number of critics: 376 Average Rating: 4.006648936170213
#
# Movie Title: 7566 Number of critics: 300 Average Rating: 4.088333333333333
#
# Movie Title: 7587 Number of critics: 251 Average Rating: 4.043824701195219
#
# Movie Title: 25750 Number of critics: 131 Average Rating: 4.1106870229007635
#
# Movie Title: 44555 Number of critics: 1230 Average Rating: 4.297154471544715
#
# Movie Title: 55814 Number of critics: 338 Average Rating: 4.019230769230769
#
# Movie Title: 1900 Number of critics: 369 Average Rating: 4.016260162601626
#
# Movie Title: 26082 Number of critics: 124 Average Rating: 4.157258064516129
#
# Movie Title: 3469 Number of critics: 1028 Average Rating: 4.134727626459144
#
# Movie Title: 37240 Number of critics: 371 Average Rating: 4.05256064690027
#
# Movie Title: 31410 Number of critics: 1360 Average Rating: 4.01875
#
# Movie Title: 556 Number of critics: 732 Average Rating: 4.004098360655738
#
# Movie Title: 3677 Number of critics: 592 Average Rating: 4.01097972972973
#
# Movie Title: 2330 Number of critics: 487 Average Rating: 4.137577002053388
#
# Movie Title: 7088 Number of critics: 204 Average Rating: 4.019607843137255
#
# Movie Title: 3038 Number of critics: 300 Average Rating: 4.18
#
# Movie Title: 6375 Number of critics: 128 Average Rating: 4.0546875
#
# Movie Title: 2937 Number of critics: 502 Average Rating: 4.161354581673307
#
# Movie Title: 7767 Number of critics: 159 Average Rating: 4.122641509433962
#
# Movie Title: 26150 Number of critics: 188 Average Rating: 4.007978723404255
#
# Movie Title: 63082 Number of critics: 108 Average Rating: 4.199074074074074
#
# Movie Title: 3789 Number of critics: 358 Average Rating: 4.051675977653631
#
# Movie Title: 26614 Number of critics: 269 Average Rating: 4.048327137546468
#
# Movie Title: 26729 Number of critics: 322 Average Rating: 4.091614906832298
#
# Movie Title: 4194 Number of critics: 106 Average Rating: 4.033018867924528
#
# Movie Title: 8582 Number of critics: 218 Average Rating: 4.043577981651376
#
# Movie Title: 8656 Number of critics: 190 Average Rating: 4.094736842105263
#
# Movie Title: 5825 Number of critics: 127 Average Rating: 4.161417322834645
#
# User: 59269 Movies: 7359
# ......
# ----------------------------------------------------------------------
# Ran 6 tests in 56.455s
#
# OK
